# %% [markdown]
# ### 날씨 예측
# - date: 날짜
# - precipitation: 강수량 (물이 비, 진눈깨비, 눈, 우박, 이슬비 등 지표면과 열린 수역에 떨어지는 모든 형태)
# - temp_max: 최대 온도
# - temp_min: 최저 온도
# - wind: 풍속
# - weather: 날씨
# > drizzle(건조), rain(비), sun(맑음), snow(눈), fog(안개)

# %%
import pandas as pd

w_df = pd.read_csv('./datasets/seattle-weather.csv', low_memory=False)
w_df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
w_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %% [markdown]
# #### 데이터 전처리

# %%
w_df.drop(labels=['date'], axis=1, inplace=True)
w_df
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7  drizzle
# 1              10.9      10.6       2.8   4.5     rain
# 2               0.8      11.7       7.2   2.3     rain
# 3              20.3      12.2       5.6   4.7     rain
# 4               1.3       8.9       2.8   6.1     rain
# ...             ...       ...       ...   ...      ...
# 1456            8.6       4.4       1.7   2.9     rain
# 1457            1.5       5.0       1.7   1.3     rain
# 1458            0.0       7.2       0.6   2.6      fog
# 1459            0.0       5.6      -1.0   3.4      sun
# 1460            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %% [markdown]
# date는 없어도 되는 feature이므로 삭제하였다.

# %%
w_df.isna().sum()
# Out:
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
w_df.duplicated().sum()
# Out:
# 8

# %%
w_df.drop_duplicates(inplace=True)

# %%
w_df.reset_index(drop=True)
w_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 결측치는 없었으며, 중복 행은 삭제하였다.

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
w_df['weather'] = encoder.fit_transform(w_df['weather'].tolist())

# %%
w_df.weather.value_counts()
# Out:
# weather
# 2    641
# 4    632
# 1    101
# 0     53
# 3     26
# Name: count, dtype: int64

# %% [markdown]
# 타겟 데이터 라벨 인코딩을 진행하였다.

# %% [markdown]
# #### 🤔 이 데이터세트의 feature들의 비중은 어떻게 되며, 어떤 샘플링 방식을 사용하여 비중을 맞출 수 있을까?

# %%
w_df.hist(figsize=(10, 10))
# Out:
# array([[<Axes: title={'center': 'precipitation'}>,
#         <Axes: title={'center': 'temp_max'}>],
#        [<Axes: title={'center': 'temp_min'}>,
#         <Axes: title={'center': 'wind'}>],
#        [<Axes: title={'center': 'weather'}>, <Axes: >]], dtype=object)

# %%
w_df.weather.value_counts()
# Out:
# weather
# 2    641
# 4    632
# 1    101
# 0     53
# 3     26
# Name: count, dtype: int64

# %% [markdown]
# 👉 타겟 데이터의 2, 4에 비해 0, 1, 3의 비중이 낮다.
# 방법1: 0, 1, 3인 행을 제거한 후, 오버 샘플링하기
# 방법2: 언더 샘플링하기
#
# 2가지 방법 중 어떤 것을 선택하여 훈련할 지는 각 모델의 오차 행렬과 정확도를 알아본 뒤 결정한다.

# %%
w_df.describe().T
# Out:
#                 count       mean       std  min   25%   50%   75%   max
# precipitation  1453.0   3.046111  6.694776  0.0   0.0   0.0   3.0  55.9
# temp_max       1453.0  16.415967  7.346066 -1.6  10.6  15.6  22.2  35.6
# temp_min       1453.0   8.224639  5.019831 -7.1   4.4   8.3  12.2  18.3
# wind           1453.0   3.243634  1.440298  0.4   2.2   3.0   4.1   9.5
# weather        1453.0   2.745354  1.191042  0.0   2.0   2.0   4.0   4.0

# %% [markdown]
# 👉 precipitation(강수량)의 mean값과 50%값의 차이가 크다. -> 이상치 제거가 필요하다.
# 이외의 feature들은 두 수치의 차이가 거의 없기 때문에 이상치 제거 과정이 필요없다.

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()
std_pre_w = std.fit_transform(w_df.iloc[:, :-1])

# %%
std_pre_w_df = pd.DataFrame(std_pre_w, columns=w_df.iloc[:, :-1].columns)
std_pre_w_df['weather'] = w_df.weather
std_pre_w_df
# Out:
#       precipitation  temp_max  temp_min      wind  weather
# 0         -0.455155 -0.492401 -0.642601  1.011504      0.0
# 1          1.173541 -0.791984 -1.081014  0.872596      2.0
# 2         -0.335618 -0.642193 -0.204188 -0.655391      2.0
# 3          2.578104 -0.574106 -0.523034  1.011504      2.0
# 4         -0.260907 -1.023480 -1.081014  1.983860      2.0
# ...             ...       ...       ...       ...      ...
# 1448       0.829871 -1.636264 -1.300220 -0.238667      1.0
# 1449      -0.231023 -1.554560 -1.300220 -1.349931      2.0
# 1450      -0.455155 -1.254976 -1.519426 -0.447029      2.0
# 1451      -0.455155 -1.472855 -1.838272  0.108603      2.0
# 1452      -0.455155 -1.472855 -2.057478  0.178056      2.0
#
# [1453 rows x 5 columns]

# %%
print(f"{std_pre_w_df[~std_pre_w_df['precipitation'].between(-1.96, 1.96)].shape[0]}건")
# Out:
# 79건

# %%
# 이상치 제거
std_pre_w_df.drop(
        std_pre_w_df[~std_pre_w_df['precipitation'].between(-1.96, 1.96)].index, 
        axis=0, 
        inplace=True)

print(f"{std_pre_w_df[~std_pre_w_df['precipitation'].between(-1.96, 1.96)].shape[0]}건")
# Out:
# 0건

# %%
w_df = w_df.iloc[std_pre_w_df.index].reset_index(drop=True)
w_df
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7        0
# 1              10.9      10.6       2.8   4.5        2
# 2               0.8      11.7       7.2   2.3        2
# 3               1.3       8.9       2.8   6.1        2
# 4               2.5       4.4       2.2   2.2        2
# ...             ...       ...       ...   ...      ...
# 1369            8.6       4.4       1.7   2.9        2
# 1370            1.5       5.0       1.7   1.3        2
# 1371            0.0       7.2       0.6   2.6        1
# 1372            0.0       5.6      -1.0   3.4        4
# 1373            0.0       5.6      -2.1   3.5        4
#
# [1374 rows x 5 columns]

# %%
w_df.precipitation.hist()
# Out:
# <Axes: >

# %% [markdown]
# 👉 이상치 제거 후에 치우쳐진 수치가 조금은 나아졌다.

# %% [markdown]
# #### 🤔 이 데이터 세트의 feature들의 상관관계는 어떠할까? 제거할만한 feature가 있을까?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = w_df.corr()
fig = plt.figure(figsize=(7, 5))
heatmap = sns.heatmap(corr, cmap="Oranges")
heatmap.set_title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %% [markdown]
# 👉 독립 변수들간의 상관관계
# 1. 최소 온도 - 최대 온도
# 2. 강수량 - 바람

# %%
corr[['weather']].sort_values(by="weather", ascending=False)[1:]
# Out:
#                 weather
# temp_max       0.316406
# temp_min       0.160025
# wind          -0.036010
# precipitation -0.311669

# %% [markdown]
# 👉 타겟 데이터와 독립변수간의 상관관계
# wind는 거의 영향을 미치지 않는다.
# 모델을 훈련한 뒤에 importance를 알아내어 훈련 시의 wind 중요도도 낮다면 제거해도 될 것 같다.

# %% [markdown]
# ### 🆕 DTC

# %%
pre_w_df = w_df.copy()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# DecisionTreeClassifier 모델 초기화
dtc = DecisionTreeClassifier()

# features와 targets 설정
features, targets = pre_w_df.iloc[:, :-1], pre_w_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test =\
train_test_split(features, targets, test_size=0.2, random_state=124)

# 모델 훈련
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz

export_graphviz(
    dtc, 
    out_file='./images/weather_dtc01.dot', 
    class_names=encoder.classes_, 
    feature_names=features.columns, 
    impurity=True,
    filled=True
)

# %%
import graphviz

with open('./images/weather_dtc01.dot') as f:
    weather_dtc01 = f.read()

weather_dtc01_graph = graphviz.Source(weather_dtc01)

# %%
weather_dtc01_graph.render(filename="weather_dtc01", directory="./images", format="png")
# Out:
# 'images\\weather_dtc01.png'

# %% [markdown]
# <img src='./images/weather_dtc01.png'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
plt.scatter(features.iloc[:, 0], features.iloc[:, 2], c=targets)

# %%
import numpy as np

# Classifier의 Decision Boundary를 시각화 하는 함수
def visualize_boundary(model, X, y):
    fig,ax = plt.subplots()
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y, s=25, cmap='rainbow', edgecolor='k',
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start , xlim_end = ax.get_xlim()
    ylim_start , ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 . 
    model.fit(X.values, y)
    # meshgrid 형태인 모든 좌표값으로 예측 수행. 
    xx, yy = np.meshgrid(np.linspace(xlim_start,xlim_end, num=200),np.linspace(ylim_start,ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf() 를 이용하여 class boundary 를 visualization 수행. 
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap='rainbow',
                           zorder=1)

# %%
features_0_2 = features.iloc[:, [0, 2]] 
visualize_boundary(dtc, features_0_2, targets)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction, average='macro')
    recall = recall_score(y_test , prediction, average='macro')
    f1 = f1_score(y_test, prediction, average='macro')
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
# 가장 중요한 두 개의 특성을 선택하여 새로운 데이터프레임 생성
X_test_selected_features = X_test[['precipitation', 'temp_min']]

# 새로운 데이터프레임을 사용하여 예측
prediction = dtc.predict(X_test_selected_features)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
get_evaluation(y_test, prediction, dtc, X_test_selected_features)
# Out:
# 오차 행렬
# [[  2   0   0   0   3]
#  [  0   0   0   0  26]
#  [  0   0 104   0   7]
#  [  0   0   0   7   0]
#  [  0   0   0   0 126]]
# 정확도: 0.8691, 정밀도: 0.7556, 재현율: 0.6674, F1: 0.6828
# ################################################################################
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
pre_w_df.weather.value_counts()
# Out:
# weather
# 4    632
# 2    566
# 1    101
# 0     53
# 3     22
# Name: count, dtype: int64

# %% [markdown]
# #### 1 Cycle
# 전체적인 수치만 보았을 때, 나쁘지 않은 것 같지만 오차행렬을 보면 타겟이 0, 1, 3일때의 데이터가 너무 적었다.
# 따라서 0, 3인 행을 삭제하고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 Score  |
# |--------|---------|---------|---------|---------|
# | 1 Cycle| 0.8691  | 0.7556  | 0.6674  | 0.6828  |

# %%
pre_w_df = w_df.copy()

# %%
pre_w_df = pre_w_df[(pre_w_df['weather'] == 2) | (pre_w_df['weather'] == 4) | (pre_w_df['weather'] == 1)]
pre_w_df = pre_w_df.reset_index(drop=True)
pre_w_df
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0              10.9      10.6       2.8   4.5        2
# 1               0.8      11.7       7.2   2.3        2
# 2               1.3       8.9       2.8   6.1        2
# 3               2.5       4.4       2.2   2.2        2
# 4               0.0       7.2       2.8   2.3        2
# ...             ...       ...       ...   ...      ...
# 1294            8.6       4.4       1.7   2.9        2
# 1295            1.5       5.0       1.7   1.3        2
# 1296            0.0       7.2       0.6   2.6        1
# 1297            0.0       5.6      -1.0   3.4        4
# 1298            0.0       5.6      -2.1   3.5        4
#
# [1299 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# DecisionTreeClassifier 모델 초기화
dtc = DecisionTreeClassifier()

# features와 targets 설정
features, targets = pre_w_df.iloc[:, :-1], pre_w_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test =\
train_test_split(features, targets, test_size=0.2, random_state=124)

# 모델 훈련
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
features_0_2 = features.iloc[:, [0, 2]] 
visualize_boundary(dtc, features_0_2, targets)

# %%
# 가장 중요한 두 개의 특성을 선택하여 새로운 데이터프레임 생성
X_test_selected_features = X_test[['precipitation', 'temp_min']]

# 새로운 데이터프레임을 사용하여 예측
prediction = dtc.predict(X_test_selected_features)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
get_evaluation(y_test, prediction, dtc, X_test_selected_features)
# Out:
# 오차 행렬
# [[  0   0  23]
#  [  0 106  11]
#  [  0   0 120]]
# 정확도: 0.8692, 정밀도: 0.5931, 재현율: 0.6353, F1: 0.6089
# ################################################################################
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
pre_w_df.weather.value_counts()
# Out:
# weather
# 4    632
# 2    566
# 1    101
# Name: count, dtype: int64

# %% [markdown]
# #### 2 Cycle
# 0, 3인 행을 삭제하였으나 1인 데이터는 여전히 부족하여 예측율이 낮았다.
# 1인 데이터에 맞춰 언더샘플링을 해보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 Score  |
# |--------|---------|---------|---------|---------|
# | 1 Cycle| 0.8691  | 0.7556  | 0.6674  | 0.6828  |
# | 2 Cycle| 0.8692  | 0.5931  | 0.6353  | 0.6089  |

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# DecisionTreeClassifier 모델 초기화
dtc = DecisionTreeClassifier()

# 언더 샘플링
under_w_dfs = []

weather_samples = pre_w_df[pre_w_df.weather == 2].sample(101, random_state=124)
under_w_dfs.append(weather_samples)
weather_samples = pre_w_df[pre_w_df.weather == 4].sample(101, random_state=124)
under_w_dfs.append(weather_samples)
weather_samples = pre_w_df[pre_w_df.weather == 1].sample(101, random_state=124)
under_w_dfs.append(weather_samples)

under_w_df = pd.concat(under_w_dfs).reset_index(drop=True)

# features와 targets 설정
features, targets = under_w_df.iloc[:, :-1], under_w_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test =\
train_test_split(features, targets, test_size=0.2, random_state=124)

# 모델 훈련
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
under_w_df.weather.value_counts()
# Out:
# weather
# 2    101
# 4    101
# 1    101
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
features_0_3 = features.iloc[:, [0, 3]] 
visualize_boundary(dtc, features_0_3, targets)

# %%
# 가장 중요한 두 개의 특성을 선택하여 새로운 데이터프레임 생성
X_test_selected_features = X_test[['precipitation', 'wind']]

# 새로운 데이터프레임을 사용하여 예측
prediction = dtc.predict(X_test_selected_features)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
get_evaluation(y_test, prediction, dtc, X_test_selected_features)
# Out:
# 오차 행렬
# [[13  0  4]
#  [ 2 20  2]
#  [ 4  0 16]]
# 정확도: 0.8033, 정밀도: 0.8038, 재현율: 0.7993, F1: 0.7977
# ################################################################################
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# #### 3 Cycle (Last)
# 1인 데이터에 맞춰 언더샘플링을 한 후 훈련한 결과, 정확도는 줄었지만 나머지 수치들은 상승했다.
# 전체적으로 0.8정도의 성능을 가지는 모델임을 확인했다.
# 다음으로는 SVC 방식으로 훈련을 진행해보고자 한다.
#
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 Score  |
# |--------|---------|---------|---------|---------|
# | 1 Cycle| 0.8691  | 0.7556  | 0.6674  | 0.6828  |
# | 2 Cycle| 0.8692  | 0.5931  | 0.6353  | 0.6089  |
# | 3 Cycle| 0.8033  | 0.8038  | 0.7993  | 0.7977  |

# %% [markdown]
# ### 🆕 SVC

# %%
pre_w_df = w_df.copy()

# %%
pre_w_df
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7        0
# 1              10.9      10.6       2.8   4.5        2
# 2               0.8      11.7       7.2   2.3        2
# 3               1.3       8.9       2.8   6.1        2
# 4               2.5       4.4       2.2   2.2        2
# ...             ...       ...       ...   ...      ...
# 1369            8.6       4.4       1.7   2.9        2
# 1370            1.5       5.0       1.7   1.3        2
# 1371            0.0       7.2       0.6   2.6        1
# 1372            0.0       5.6      -1.0   3.4        4
# 1373            0.0       5.6      -2.1   3.5        4
#
# [1374 rows x 5 columns]

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.svm import SVC

# 데이터 분할
features, targets = pre_w_df.iloc[:, :-1], pre_w_df.iloc[:, -1]
X_train, X_test, y_train, y_test = \
    train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# SVC 모델 초기화
svc = SVC(probability=True)

# 그리드 서치를 위한 매개 변수 그리드 설정
parameters = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'gamma': [0.001, 0.01, 0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf']
}

# 그리드 서치 수행
g_svc = GridSearchCV(svc, param_grid=parameters, cv=5, refit=True, return_train_score=True)
g_svc.fit(X_train, y_train)

# %%
result_df = pd.DataFrame(g_svc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
print(result_df['params'][68])
display(result_df)

# %%
svc = g_svc.best_estimator_
prediction = svc.predict(X_test)

# %%
get_evaluation(y_test, prediction, svc, X_test)

# %% [markdown]
# #### 1 Cycle
# 파이프라인 구축이나 데이터 비중 맞추기 없이 훈련을 진행하였더니,
# 다음 cycle에서는 standard scaler를 이용하여 파이프라인 구축을 하여 훈련을 진행해보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 Score  |
# |--------|---------|---------|---------|---------|
# | 1 Cycle| 0.8691  | 0.7556  | 0.6674  | 0.6828  |

# %%
pre_w_df = w_df.copy()

# %%
pre_w_df
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7        0
# 1              10.9      10.6       2.8   4.5        2
# 2               0.8      11.7       7.2   2.3        2
# 3               1.3       8.9       2.8   6.1        2
# 4               2.5       4.4       2.2   2.2        2
# ...             ...       ...       ...   ...      ...
# 1369            8.6       4.4       1.7   2.9        2
# 1370            1.5       5.0       1.7   1.3        2
# 1371            0.0       7.2       0.6   2.6        1
# 1372            0.0       5.6      -1.0   3.4        4
# 1373            0.0       5.6      -2.1   3.5        4
#
# [1374 rows x 5 columns]

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

features, targets = pre_w_df.iloc[:, :-1], pre_w_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# SMOTE를 사용하여 데이터 오버샘플링
smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(features, targets)

parameters = {
    'svc__C': [0.001, 0.01, 0.1, 1, 10, 100],
    'svc__gamma': [0.001, 0.01, 0.1, 1, 10, 100],
    'svc__kernel': ['linear', 'rbf']
}

svc = SVC(probability=True)

# 1. 파이프라인 구축
svc_pipe = Pipeline([('standard_scaler', StandardScaler()), ('svc', svc)])

# 2. GridSearchCV
g_svc = GridSearchCV(svc_pipe, param_grid=parameters, cv=5, refit=True, return_train_score=True)

# 3. 훈련
g_svc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('svc', SVC(probability=True))]),
#              param_grid={'svc__C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'svc__gamma': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'svc__kernel': ['linear', 'rbf']},
#              return_train_score=True)

# %%
result_df = pd.DataFrame(g_svc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
print(result_df['params'][69])
display(result_df)
# Out:
# {'svc__C': 100, 'svc__gamma': 10, 'svc__kernel': 'linear'}
#                                                params  mean_test_score  \
# 0   {'svc__C': 0.001, 'svc__gamma': 0.001, 'svc__k...         0.462025
# 1   {'svc__C': 0.001, 'svc__gamma': 0.001, 'svc__k...         0.338291
# 2   {'svc__C': 0.001, 'svc__gamma': 0.01, 'svc__ke...         0.462025
# 3   {'svc__C': 0.001, 'svc__gamma': 0.01, 'svc__ke...         0.340823
# 4   {'svc__C': 0.001, 'svc__gamma': 0.1, 'svc__ker...         0.462025
# ..                                                ...              ...
# 67  {'svc__C': 100, 'svc__gamma': 1, 'svc__kernel'...         0.780380
# 68  {'svc__C': 100, 'svc__gamma': 10, 'svc__kernel...         0.618671
# 69  {'svc__C': 100, 'svc__gamma': 10, 'svc__kernel...         0.805380
# 70  {'svc__C': 100, 'svc__gamma': 100, 'svc__kerne...         0.618671
# 71  {'svc__C': 100, 'svc__gamma': 100, 'svc__kerne...         0.739241
#
#     rank_test_score
# 0                55
# ...

# %%
svc = g_svc.best_estimator_
prediction = svc.predict(X_test)

# %%
get_evaluation(y_test, prediction, svc, X_test)
# Out:
# 오차 행렬
# [[ 11   0   0   0   0]
#  [  0  20   0   0   0]
#  [  0   1 111   0   1]
#  [  0   0   0   4   0]
#  [ 18   8   0   0 101]]
# 정확도: 0.8982, 정밀도: 0.8118, 재현율: 0.9555, F1: 0.8479
# ################################################################################
