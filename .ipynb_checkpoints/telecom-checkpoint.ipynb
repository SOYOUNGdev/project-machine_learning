# %% [markdown]
# ### 통신 고객 이탈 예측
# - customer_id: 각 고객의 고유 식별자입니다.
# - telecom_partner: 고객과 연결된 통신 파트너입니다.
# - gender: 고객의 성별입니다.
# - age: 고객의 나이입니다.
# - state: 고객이 위치한 인도의 주입니다.
# - city: 고객이 위치한 도시입니다.
# - pincode: 고객 위치의 핀코드입니다.
# - date_of_registration: 고객이 통신 파트너에 등록한 날짜입니다.
# - num_dependents: 고객의 부양가족(예: 자녀) 수입니다.
# - estimate_salary: 고객의 예상 급여입니다.
# - call_made: 고객이 통화한 횟수입니다.
# - sms_sent: 고객이 보낸 SMS 메시지 수입니다.
# - data_used: 고객이 사용한 데이터의 양입니다.
# #### 타겟
# - churn: 고객이 이탈했는지 여부를 나타내는 이진 변수입니다(1 = 이탈, 0 = 이탈하지 않음).

# %%
import pandas as pd

t_df = pd.read_csv('./datasets/telecom_churn.csv')
t_df
# Out:
#         customer_id telecom_partner gender  age              state       city  \
# 0                 1    Reliance Jio      F   25          Karnataka    Kolkata
# 1                 2    Reliance Jio      F   55            Mizoram     Mumbai
# 2                 3        Vodafone      F   57  Arunachal Pradesh      Delhi
# 3                 4            BSNL      M   46         Tamil Nadu    Kolkata
# 4                 5            BSNL      F   26            Tripura      Delhi
# ...             ...             ...    ...  ...                ...        ...
# 243548       243549          Airtel      F   28            Mizoram    Kolkata
# 243549       243550    Reliance Jio      F   52              Assam    Kolkata
# 243550       243551    Reliance Jio      M   59            Tripura    Kolkata
# 243551       243552            BSNL      M   49     Madhya Pradesh    Kolkata
# 243552       243553            BSNL      F   37          Telangana  Hyderabad
#
# ...

# %%
t_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243553 entries, 0 to 243552
# Data columns (total 14 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   customer_id           243553 non-null  int64
#  1   telecom_partner       243553 non-null  object
#  2   gender                243553 non-null  object
#  3   age                   243553 non-null  int64
#  4   state                 243553 non-null  object
#  5   city                  243553 non-null  object
#  6   pincode               243553 non-null  int64
#  7   date_of_registration  243553 non-null  object
#  8   num_dependents        243553 non-null  int64
#  9   estimated_salary      243553 non-null  int64
#  10  calls_made            243553 non-null  int64
#  11  sms_sent              243553 non-null  int64
#  12  data_used             243553 non-null  int64
#  13  churn                 243553 non-null  int64
# dtypes: int64(9), object(5)
# ...

# %% [markdown]
# ### 데이터 전처리

# %%
columns = ['customer_id', 'pincode', 'gender']
t_df.drop(labels=columns, axis=1, inplace=True)
t_df
# Out:
#        telecom_partner  age              state       city  \
# 0         Reliance Jio   25          Karnataka    Kolkata
# 1         Reliance Jio   55            Mizoram     Mumbai
# 2             Vodafone   57  Arunachal Pradesh      Delhi
# 3                 BSNL   46         Tamil Nadu    Kolkata
# 4                 BSNL   26            Tripura      Delhi
# ...                ...  ...                ...        ...
# 243548          Airtel   28            Mizoram    Kolkata
# 243549    Reliance Jio   52              Assam    Kolkata
# 243550    Reliance Jio   59            Tripura    Kolkata
# 243551            BSNL   49     Madhya Pradesh    Kolkata
# 243552            BSNL   37          Telangana  Hyderabad
#
#        date_of_registration  num_dependents  estimated_salary  calls_made  \
# 0                2020-01-01               4            124962          44
# 1                2020-01-01               2            130556          62
# ...

# %%
t_df['date_of_registration'].astype
# Out:
# <bound method NDFrame.astype of 0         2020-01-01
# 1         2020-01-01
# 2         2020-01-01
# 3         2020-01-01
# 4         2020-01-01
#              ...
# 243548    2023-05-03
# 243549    2023-05-03
# 243550    2023-05-03
# 243551    2023-05-03
# 243552    2023-05-04
# Name: date_of_registration, Length: 243553, dtype: object>

# %%
# 오늘 - 가입 날짜 -> 가입된 기간으로 변경
from datetime import datetime

# 오늘 날짜를 가져오기
today_date = datetime.today()
# 판다스의 Timestamp 객체로 변환
today = pd.Timestamp(today_date)

# 'date_of_registration' 열의 값을 판다스 Timestamp로 변환
t_df['date_of_registration'] = pd.to_datetime(t_df['date_of_registration'])

# 가입된 기간(일수)으로 변경
t_df['membership_duration'] = (today - t_df['date_of_registration']).dt.days

# %%
t_df.drop(labels=['date_of_registration'], axis=1, inplace=True)
t_df
# Out:
#        telecom_partner  age              state       city  num_dependents  \
# 0         Reliance Jio   25          Karnataka    Kolkata               4
# 1         Reliance Jio   55            Mizoram     Mumbai               2
# 2             Vodafone   57  Arunachal Pradesh      Delhi               0
# 3                 BSNL   46         Tamil Nadu    Kolkata               1
# 4                 BSNL   26            Tripura      Delhi               2
# ...                ...  ...                ...        ...             ...
# 243548          Airtel   28            Mizoram    Kolkata               3
# 243549    Reliance Jio   52              Assam    Kolkata               0
# 243550    Reliance Jio   59            Tripura    Kolkata               4
# 243551            BSNL   49     Madhya Pradesh    Kolkata               2
# 243552            BSNL   37          Telangana  Hyderabad               0
#
#         estimated_salary  calls_made  sms_sent  data_used  churn  \
# ...

# %%
t_df.isna().sum()
# Out:
# telecom_partner        0
# age                    0
# state                  0
# city                   0
# num_dependents         0
# estimated_salary       0
# calls_made             0
# sms_sent               0
# data_used              0
# churn                  0
# membership_duration    0
# dtype: int64

# %%
t_df.duplicated().sum()
# Out:
# 0

# %%
t_df['telecom_partner'].value_counts()
# Out:
# telecom_partner
# Reliance Jio    61123
# Airtel          60905
# Vodafone        60802
# BSNL            60723
# Name: count, dtype: int64

# %%
t_df['city'].value_counts()
# Out:
# city
# Chennai      40749
# Hyderabad    40698
# Kolkata      40661
# Bangalore    40603
# Delhi        40456
# Mumbai       40386
# Name: count, dtype: int64

# %%
# Label Encoding
from sklearn.preprocessing import LabelEncoder

columns = ['telecom_partner', 'state', 'city']

encoders = {}

for column in columns:
    encoder = LabelEncoder()
    t_df[column] = encoder.fit_transform(t_df[column].tolist())
    encoders[column] = encoder
    print(f'{column}: {encoder.classes_}')
# Out:
# telecom_partner: ['Airtel' 'BSNL' 'Reliance Jio' 'Vodafone']
# state: ['Andhra Pradesh' 'Arunachal Pradesh' 'Assam' 'Bihar' 'Chhattisgarh' 'Goa'
#  'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jharkhand' 'Karnataka' 'Kerala'
#  'Madhya Pradesh' 'Maharashtra' 'Manipur' 'Meghalaya' 'Mizoram' 'Nagaland'
#  'Odisha' 'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana' 'Tripura'
#  'Uttar Pradesh' 'Uttarakhand' 'West Bengal']
# city: ['Bangalore' 'Chennai' 'Delhi' 'Hyderabad' 'Kolkata' 'Mumbai']

# %%
# churn 열을 맨 끝으로 이동
t_df = t_df[['telecom_partner', 'age', 'state', 'city',	'num_dependents', 'estimated_salary', 'calls_made', 'sms_sent', 'data_used', 'membership_duration', 'churn']]

# %%
t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 243548                0   28     16     4               3            130580
# 243549                2   52      2     4               0             82393
# 243550                2   59     24     4               4             51298
# 243551                1   49     12     4               2             83981
# 243552                1   37     23     3               0            144297
#
# ...

# %% [markdown]
# ### 🆕 DTC

# %%
pre_t_df = t_df.copy()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# DecisionTreeClassifier 모델 초기화
dtc = DecisionTreeClassifier()

# features와 targets 설정
features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test =\
train_test_split(features, targets, test_size=0.2, random_state=124)

# 모델 훈련
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz

export_graphviz(
    dtc, 
    out_file='./images/telecom_dtc01.dot', 
    class_names=class_names, 
    feature_names=feature_names, 
    impurity=True,
    filled=True
)

# %%
import graphviz

with open('./images/telecom_dtc01.dot') as f:
    telecom_dtc01 = f.read()

telecom_dtc01_graph = graphviz.Source(weather_dtc01)

# %%
# telecom_dtc01_graph.render(filename="telecom_dtc01", directory="./images", format="png")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# 데이터를 샘플링하여 일부만 시각화
sample_indices = np.random.choice(len(features), 1000, replace=False)  # 데이터에서 무작위로 1000개의 샘플 선택
sample_features = features.iloc[sample_indices]
sample_targets = targets[sample_indices]

# 시각화
plt.scatter(sample_features.iloc[:, 5], sample_features.iloc[:, 8], c=sample_targets)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Scatter Plot')

# 클러스터링 수행
kmeans = KMeans(n_clusters=3)
kmeans.fit(sample_features)
cluster_labels = kmeans.predict(sample_features)

# 클러스터 중심 시각화 (선택 사항)
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=100, c='red', label='Centroids')

plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt

# Classifier의 Decision Boundary를 시각화하는 함수
def visualize_boundary(model, X, y):
    fig, ax = plt.subplots()
    
    # 데이터를 샘플링하여 일부만 시각화
    sample_indices = np.random.choice(len(X), 1000, replace=False)
    sample_X = X.iloc[sample_indices]
    sample_y = y[sample_indices]
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(sample_X.iloc[:, 0], sample_X.iloc[:, 1], c=sample_y, s=5, cmap='rainbow', edgecolor='k', clim=(sample_y.min(), sample_y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start, xlim_end = ax.get_xlim()
    ylim_start, ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 
    model.fit(sample_X.values, sample_y)
    
    # meshgrid 형태인 모든 좌표값으로 예측 수행 
    xx, yy = np.meshgrid(np.linspace(xlim_start, xlim_end, num=200), np.linspace(ylim_start, ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf()를 이용하여 class boundary를 visualization 수행 
    n_classes = len(np.unique(sample_y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3, levels=np.arange(n_classes + 1) - 0.5, cmap='rainbow', zorder=1)
    
    plt.show()

# %%
features_5_8 = features.iloc[:, [5, 8]] 
visualize_boundary(dtc, features_5_8, targets)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# DecisionTreeClassifier 모델 초기화
dtc = DecisionTreeClassifier(min_samples_leaf=20)

# features와 targets 설정
features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test =\
train_test_split(features, targets, test_size=0.2, random_state=124)

# 모델 훈련
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=20)

# %%
features_5_8 = features.iloc[:, [5, 8]] 
visualize_boundary(dtc, features_5_8, targets)

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.tree import DecisionTreeClassifier

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# stratify: 데이터 분리 시 타겟 데이터의 분포 비율에 맞춰서 나눠준다.
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, stratify=targets, random_state=124)

dtc = DecisionTreeClassifier()
parameters = {'max_depth': [15, 16, 17, 18], 'min_samples_split': [12, 13, 14]}

g_dtc = GridSearchCV(dtc, param_grid=parameters, cv=5, refit=True, return_train_score=True)

# 교차 검증 진행
g_dtc.fit(X_train, y_train)

pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
# Out:
#                                         params  mean_test_score  \
# 0   {'max_depth': 15, 'min_samples_split': 12}         0.790148
# 1   {'max_depth': 15, 'min_samples_split': 13}         0.790309
# 2   {'max_depth': 15, 'min_samples_split': 14}         0.790283
# 3   {'max_depth': 16, 'min_samples_split': 12}         0.787563
# 4   {'max_depth': 16, 'min_samples_split': 13}         0.787697
# 5   {'max_depth': 16, 'min_samples_split': 14}         0.787879
# 6   {'max_depth': 17, 'min_samples_split': 12}         0.784847
# 7   {'max_depth': 17, 'min_samples_split': 13}         0.785169
# 8   {'max_depth': 17, 'min_samples_split': 14}         0.785205
# 9   {'max_depth': 18, 'min_samples_split': 12}         0.781303
# 10  {'max_depth': 18, 'min_samples_split': 13}         0.781567
# 11  {'max_depth': 18, 'min_samples_split': 14}         0.781598
#
#     rank_test_score
# 0                 3
# 1                 1
# 2                 2
# 3                 6
# 4                 5
# ...

# %%
from sklearn.metrics import accuracy_score

dtc = g_dtc.best_estimator_
prediction = dtc.predict(X_test)

print(f'정확도: {np.round(accuracy_score(y_test, prediction) * 100, 4)}%')
# Out:
# 정확도: 78.8459%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# 타겟 데이터와 예측 객체를 전달받는다.
def get_evaluation(y_test, prediction, classifier=None, X_test=None):
#     오차 행렬
    confusion = confusion_matrix(y_test, prediction)
#     정확도
    accuracy = accuracy_score(y_test , prediction)
#     정밀도
    precision = precision_score(y_test , prediction)
#     재현율
    recall = recall_score(y_test , prediction)
#     F1 score
    f1 = f1_score(y_test, prediction)
#     ROC-AUC
    roc_auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
get_evaluation(y_test, prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[37856   715]
#  [ 9491   184]]
# 정확도: 0.7885, 정밀도: 0.2047, 재현율: 0.0190, F1: 0.0348, ROC-AUC: 0.5002
# ################################################################################

# %% [markdown]
# #### 1 Cycle
# 정밀도와 재현율 F1 Score가 너무 낮고, ROC-AUC가 0.5 인것으로보아 무작위에 가까운 성능을 보였다. 이상치를 제거하고 비중을 맞춰보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.7885  | 0.2047  | 0.0190  | 0.0348   | 0.5002   |

# %%
# 이상치 제거
features = std_pre_t_df.iloc[:, :-1]
for column in features.columns:
    std_pre_t_df.drop(
        std_pre_t_df[~std_pre_t_df[column].between(-1.96, 1.96)].index, 
        axis=0, 
        inplace=True)
    
for column in features.columns:
    print(f'{column}: {std_pre_t_df[~std_pre_t_df[column].between(-1.96, 1.96)].shape[0]}건')
# Out:
# telecom_partner: 0건
# age: 0건
# state: 0건
# city: 0건
# num_dependents: 0건
# estimated_salary: 0건
# calls_made: 0건
# sms_sent: 0건
# data_used: 0건
# membership_duration: 0건

# %%
pre_t_df = pre_t_df.iloc[std_pre_t_df.index].reset_index(drop=True)
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 241225                0   28     16     4               3            130580
# 241226                2   52      2     4               0             82393
# 241227                2   59     24     4               4             51298
# 241228                1   49     12     4               2             83981
# 241229                1   37     23     3               0            144297
#
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# DecisionTreeClassifier 모델 초기화
dtc = DecisionTreeClassifier()

# features와 targets 설정
features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test =\
train_test_split(features, targets, test_size=0.2, random_state=124)

# SMOTE를 사용하여 데이터 오버샘플링
smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# 모델 훈련
dtc.fit(X_train_over, y_train_over)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# 데이터를 샘플링하여 일부만 시각화
sample_indices = np.random.choice(len(features), 1000, replace=False)  # 데이터에서 무작위로 1000개의 샘플 선택
sample_features = features.iloc[sample_indices]
sample_targets = targets[sample_indices]

# 시각화
plt.scatter(sample_features.iloc[:, 5], sample_features.iloc[:, 8], c=sample_targets)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Scatter Plot')

# 클러스터링 수행
kmeans = KMeans(n_clusters=3)
kmeans.fit(sample_features)
cluster_labels = kmeans.predict(sample_features)

# 클러스터 중심 시각화 (선택 사항)
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=100, c='red', label='Centroids')

plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt

# Classifier의 Decision Boundary를 시각화하는 함수
def visualize_boundary(model, X, y):
    fig, ax = plt.subplots()
    
    # 데이터를 샘플링하여 일부만 시각화
    sample_indices = np.random.choice(len(X), 1000, replace=False)
    sample_X = X.iloc[sample_indices]
    sample_y = y[sample_indices]
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(sample_X.iloc[:, 0], sample_X.iloc[:, 1], c=sample_y, s=5, cmap='rainbow', edgecolor='k', clim=(sample_y.min(), sample_y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start, xlim_end = ax.get_xlim()
    ylim_start, ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 
    model.fit(sample_X.values, sample_y)
    
    # meshgrid 형태인 모든 좌표값으로 예측 수행 
    xx, yy = np.meshgrid(np.linspace(xlim_start, xlim_end, num=200), np.linspace(ylim_start, ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf()를 이용하여 class boundary를 visualization 수행 
    n_classes = len(np.unique(sample_y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3, levels=np.arange(n_classes + 1) - 0.5, cmap='rainbow', zorder=1)
    
    plt.show()

# %%
features_5_8 = features.iloc[:, [5, 8]] 
visualize_boundary(dtc, features_5_8, targets)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# DecisionTreeClassifier 모델 초기화
dtc = DecisionTreeClassifier(min_samples_leaf=20)

# features와 targets 설정
features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test =\
train_test_split(features, targets, test_size=0.2, random_state=124)

# SMOTE를 사용하여 데이터 오버샘플링
smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# 모델 훈련
dtc.fit(X_train_over, y_train_over)
# Out:
# DecisionTreeClassifier(min_samples_leaf=20)

# %%
features_5_8 = features.iloc[:, [5, 8]] 
visualize_boundary(dtc, features_5_8, targets)

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.tree import DecisionTreeClassifier

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# stratify: 데이터 분리 시 타겟 데이터의 분포 비율에 맞춰서 나눠준다.
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, stratify=targets, random_state=124)

dtc = DecisionTreeClassifier()
parameters = {'max_depth': [15, 16, 17, 18], 'min_samples_split': [12, 13, 14]}

g_dtc = GridSearchCV(dtc, param_grid=parameters, cv=5, refit=True, return_train_score=True)

# 교차 검증 진행
g_dtc.fit(X_train, y_train)

pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
# Out:
#                                         params  mean_test_score  \
# 0   {'max_depth': 15, 'min_samples_split': 12}         0.790154
# 1   {'max_depth': 15, 'min_samples_split': 13}         0.790314
# 2   {'max_depth': 15, 'min_samples_split': 14}         0.790361
# 3   {'max_depth': 16, 'min_samples_split': 12}         0.787557
# 4   {'max_depth': 16, 'min_samples_split': 13}         0.787785
# 5   {'max_depth': 16, 'min_samples_split': 14}         0.787801
# 6   {'max_depth': 17, 'min_samples_split': 12}         0.784858
# 7   {'max_depth': 17, 'min_samples_split': 13}         0.785107
# 8   {'max_depth': 17, 'min_samples_split': 14}         0.785148
# 9   {'max_depth': 18, 'min_samples_split': 12}         0.781215
# 10  {'max_depth': 18, 'min_samples_split': 13}         0.781453
# 11  {'max_depth': 18, 'min_samples_split': 14}         0.781681
#
#     rank_test_score
# 0                 3
# 1                 2
# 2                 1
# 3                 6
# 4                 5
# ...

# %%
from sklearn.metrics import accuracy_score

dtc = g_dtc.best_estimator_
prediction = dtc.predict(X_test)

print(f'정확도: {np.round(accuracy_score(y_test, prediction) * 100, 4)}%')
# Out:
# 정확도: 78.8459%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# 타겟 데이터와 예측 객체를 전달받는다.
def get_evaluation(y_test, prediction, classifier=None, X_test=None):
#     오차 행렬
    confusion = confusion_matrix(y_test, prediction)
#     정확도
    accuracy = accuracy_score(y_test , prediction)
#     정밀도
    precision = precision_score(y_test , prediction)
#     재현율
    recall = recall_score(y_test , prediction)
#     F1 score
    f1 = f1_score(y_test, prediction)
#     ROC-AUC
    roc_auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
get_evaluation(y_test, prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[37856   715]
#  [ 9491   184]]
# 정확도: 0.7885, 정밀도: 0.2047, 재현율: 0.0190, F1: 0.0348, ROC-AUC: 0.5002
# ################################################################################

# %%
print(y_train.value_counts())
y_train_over.value_counts()
# Out:
# churn
# 0    154283
# 1     38701
# Name: count, dtype: int64
# churn
# 1    154408
# 0    154408
# Name: count, dtype: int64

# %% [markdown]
# #### 2 Cycle
# 변화가 없다. 전체 스케일링을 진행해보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.7885  | 0.2047  | 0.0190  | 0.0348   | 0.5002   |
# | 2 Cycle| 0.7885  | 0.2047  | 0.0190  | 0.0348   | 0.5002   |

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# StandardScaler를 사용하여 스케일링하는 파이프라인 구축
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # 피쳐들을 스케일링하는 스케일러
    ('dtc', DecisionTreeClassifier())  # 의사결정나무 분류기
])

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=124)

# SMOTE를 사용하여 데이터 오버샘플링
smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# 파이프라인으로 모델 훈련
pipeline.fit(X_train_over, y_train_over)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('dtc', DecisionTreeClassifier())])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
plt.scatter(features.iloc[:, 5], features.iloc[:, 8], c=targets, s=5)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Classifier의 Decision Boundary를 시각화하는 함수
def visualize_boundary(model, X, y):
    fig, ax = plt.subplots()
    
    # 데이터를 샘플링하여 일부만 시각화
    sample_indices = np.random.choice(len(X), 1000, replace=False)
    sample_X = X.iloc[sample_indices]
    sample_y = y[sample_indices]
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(sample_X.iloc[:, 0], sample_X.iloc[:, 1], c=sample_y, s=5, cmap='rainbow', edgecolor='k', clim=(sample_y.min(), sample_y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start, xlim_end = ax.get_xlim()
    ylim_start, ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 
    model.fit(sample_X.values, sample_y)
    
    # meshgrid 형태인 모든 좌표값으로 예측 수행 
    xx, yy = np.meshgrid(np.linspace(xlim_start, xlim_end, num=200), np.linspace(ylim_start, ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf()를 이용하여 class boundary를 visualization 수행 
    n_classes = len(np.unique(sample_y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3, levels=np.arange(n_classes + 1) - 0.5, cmap='rainbow', zorder=1)
    
    plt.show()

# %%
features_5_8 = features.iloc[:, [5, 8]] 
visualize_boundary(dtc, features_5_8, targets)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# StandardScaler를 사용하여 스케일링하는 파이프라인 구축
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('dtc', DecisionTreeClassifier(min_samples_leaf=20)) 
])

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=124)

# SMOTE를 사용하여 데이터 오버샘플링
smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# 파이프라인으로 모델 훈련
pipeline.fit(X_train_over, y_train_over)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('dtc', DecisionTreeClassifier(min_samples_leaf=20))])

# %%
features_5_8 = features.iloc[:, [5, 8]] 
visualize_boundary(dtc, features_5_8, targets)

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.tree import DecisionTreeClassifier

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# stratify: 데이터 분리 시 타겟 데이터의 분포 비율에 맞춰서 나눠준다.
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, stratify=targets, random_state=124)

dtc = DecisionTreeClassifier()
parameters = {'max_depth': [15, 16, 17, 18], 'min_samples_split': [12, 13, 14]}

g_dtc = GridSearchCV(dtc, param_grid=parameters, cv=5, refit=True, return_train_score=True)

# 교차 검증 진행
g_dtc.fit(X_train, y_train)

pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
# Out:
#                                         params  mean_test_score  \
# 0   {'max_depth': 15, 'min_samples_split': 12}         0.790174
# 1   {'max_depth': 15, 'min_samples_split': 13}         0.790293
# 2   {'max_depth': 15, 'min_samples_split': 14}         0.790356
# 3   {'max_depth': 16, 'min_samples_split': 12}         0.787532
# 4   {'max_depth': 16, 'min_samples_split': 13}         0.787703
# 5   {'max_depth': 16, 'min_samples_split': 14}         0.787796
# 6   {'max_depth': 17, 'min_samples_split': 12}         0.784915
# 7   {'max_depth': 17, 'min_samples_split': 13}         0.785039
# 8   {'max_depth': 17, 'min_samples_split': 14}         0.785236
# 9   {'max_depth': 18, 'min_samples_split': 12}         0.781376
# 10  {'max_depth': 18, 'min_samples_split': 13}         0.781593
# 11  {'max_depth': 18, 'min_samples_split': 14}         0.781547
#
#     rank_test_score
# 0                 3
# 1                 2
# 2                 1
# 3                 6
# 4                 5
# ...

# %%
from sklearn.metrics import accuracy_score

dtc = g_dtc.best_estimator_
prediction = dtc.predict(X_test)

print(f'정확도: {np.round(accuracy_score(y_test, prediction) * 100, 4)}%')
# Out:
# 정확도: 78.8729%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# 타겟 데이터와 예측 객체를 전달받는다.
def get_evaluation(y_test, prediction, classifier=None, X_test=None):
#     오차 행렬
    confusion = confusion_matrix(y_test, prediction)
#     정확도
    accuracy = accuracy_score(y_test , prediction)
#     정밀도
    precision = precision_score(y_test , prediction)
#     재현율
    recall = recall_score(y_test , prediction)
#     F1 score
    f1 = f1_score(y_test, prediction)
#     ROC-AUC
    roc_auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
get_evaluation(y_test, prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[37870   701]
#  [ 9492   183]]
# 정확도: 0.7887, 정밀도: 0.2070, 재현율: 0.0189, F1: 0.0347, ROC-AUC: 0.5004
# ################################################################################

# %% [markdown]
# #### Last Cycle
# 전체 분포를 맞추기 위해 PipeLine을 구축하였지만, 변화가 정말 미미했다.
# KNN 방법을 사용하여 모델을 훈련하고자한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.7885  | 0.2047  | 0.0190  | 0.0348   | 0.5002   |
# | 2 Cycle| 0.7885  | 0.2047  | 0.0190  | 0.0348   | 0.5002   |
# | 3 Cycle| 0.7887  | 0.2070  | 0.0189  | 0.0347   | 0.5004   |

# %% [markdown]
# ### 🆕 KNN

# %%
pre_t_df = t_df.copy()

# %%
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 243548                0   28     16     4               3            130580
# 243549                2   52      2     4               0             82393
# 243550                2   59     24     4               4             51298
# 243551                1   49     12     4               2             83981
# 243552                1   37     23     3               0            144297
#
# ...

# %%
# 이상치 제거
features = std_pre_t_df.iloc[:, :-1]
for column in features.columns:
    std_pre_t_df.drop(
        std_pre_t_df[~std_pre_t_df[column].between(-1.96, 1.96)].index, 
        axis=0, 
        inplace=True)
    
for column in features.columns:
    print(f'{column}: {std_pre_t_df[~std_pre_t_df[column].between(-1.96, 1.96)].shape[0]}건')
# Out:
# telecom_partner: 0건
# age: 0건
# state: 0건
# city: 0건
# num_dependents: 0건
# estimated_salary: 0건
# calls_made: 0건
# sms_sent: 0건
# data_used: 0건
# membership_duration: 0건

# %%
pre_t_df = pre_t_df.iloc[std_pre_t_df.index].reset_index(drop=True)
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 241225                0   28     16     4               3            130580
# 241226                2   52      2     4               0             82393
# 241227                2   59     24     4               4             51298
# 241228                1   49     12     4               2             83981
# 241229                1   37     23     3               0            144297
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = pre_t_df.corr()
fig = plt.figure(figsize=(7, 5))
heatmap = sns.heatmap(corr, cmap="Oranges")
heatmap.set_title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
corr[['churn']].sort_values(by="churn", ascending=False)[1:]
# Out:
#                         churn
# city                 0.003264
# calls_made           0.001776
# age                  0.001148
# data_used            0.000303
# state               -0.000672
# membership_duration -0.001882
# num_dependents      -0.002573
# telecom_partner     -0.002905
# sms_sent            -0.003248
# estimated_salary    -0.003327

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neighbors import KNeighborsClassifier

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

features_resampled, targets_resampled = smote.fit_resample(features, targets)
knn_c = KNeighborsClassifier()

parameters = {
    'n_neighbors': [3, 5, 7]
}

g_knn_c = GridSearchCV(knn_c, param_grid=parameters, cv=5, refit=True, return_train_score=True)
g_knn_c.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7]}, return_train_score=True)

# %%
result_df = pd.DataFrame(g_knn_c.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                params  mean_test_score  rank_test_score
# 0  {'n_neighbors': 3}         0.737512                3
# 1  {'n_neighbors': 5}         0.765162                2
# 2  {'n_neighbors': 7}         0.779370                1

# %%
knn_c = g_knn_c.best_estimator_
prediction = knn_c.predict(X_test)

# %%
get_evaluation(y_test, prediction, knn_c, X_test)
# Out:
# 오차 행렬
# [[37259  1312]
#  [ 9363   312]]
# 정확도: 0.7787, 정밀도: 0.1921, 재현율: 0.0322, F1: 0.0552, ROC-AUC: 0.4991
# ################################################################################

# %% [markdown]
# #### 1 Cycle
# 정확도에 비해 정밀도, 재현율, F1 Score가 너무 낮게 나왔다. 전체 스케일링을 진행해보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.7787  | 0.1921  | 0.0322  | 0.0522   | 0.4991   |

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline

# 데이터 불러오기
features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# 훈련 데이터와 테스트 데이터로 분할
X_train, X_test, y_train, y_test = train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# SMOTE를 사용하여 데이터 오버샘플링
smote = SMOTE(random_state=124)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# 파이프라인 정의
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

# 하이퍼파라미터 그리드 설정
parameters = {'knn__n_neighbors': [3, 5, 7]}

# GridSearchCV 객체 초기화
g_knn_c = GridSearchCV(pipeline, param_grid=parameters, cv=5, refit=True, return_train_score=True)

# 모델 훈련
g_knn_c.fit(X_train_resampled, y_train_resampled)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('knn', KNeighborsClassifier())]),
#              param_grid={'knn__n_neighbors': [3, 5, 7]},
#              return_train_score=True)

# %%
result_df = pd.DataFrame(g_knn_c.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                     params  mean_test_score  rank_test_score
# 0  {'knn__n_neighbors': 3}         0.691538                1
# 1  {'knn__n_neighbors': 5}         0.684885                2
# 2  {'knn__n_neighbors': 7}         0.681935                3

# %%
knn_c = g_knn_c.best_estimator_
prediction = knn_c.predict(X_test)

# %%
get_evaluation(y_test, prediction, knn_c, X_test)
# Out:
# 오차 행렬
# [[22507 16064]
#  [ 5649  4026]]
# 정확도: 0.5500, 정밀도: 0.2004, 재현율: 0.4161, F1: 0.2705, ROC-AUC: 0.4998
# ################################################################################

# %% [markdown]
# #### 2 Cycle
# 전체 스케일링을 정확도를 제외한 다른 성능이 올랐으나, 전체적으로 여전히 낮은 성능을 볼 수 있었다.
# 다음으로는 배깅(Random Forest)방법을 이용하여 훈련시키고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.7787  | 0.1921  | 0.0322  | 0.0522   | 0.4991   |
# | 2 Cycle| 0.5500  | 0.2004  | 0.4161  | 0.2705   | 0.4998   |

# %%
pre_t_df.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'telecom_partner'}>,
#         <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'state'}>],
#        [<Axes: title={'center': 'city'}>,
#         <Axes: title={'center': 'num_dependents'}>,
#         <Axes: title={'center': 'estimated_salary'}>],
#        [<Axes: title={'center': 'calls_made'}>,
#         <Axes: title={'center': 'sms_sent'}>,
#         <Axes: title={'center': 'data_used'}>],
#        [<Axes: title={'center': 'membership_duration'}>,
#         <Axes: title={'center': 'churn'}>, <Axes: >]], dtype=object)

# %%
y_train_resampled.value_counts()
# Out:
# churn
# 0    154283
# 1    154283
# Name: count, dtype: int64

# %% [markdown]
# ### 🆕 배깅(Random Forest)

# %%
pre_t_df = t_df.copy()

# %%
pre_t_df.churn.value_counts()
# Out:
# churn
# 0    194726
# 1     48827
# Name: count, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier

# 0인 클래스만 샘플링하여 새로운 데이터프레임 생성
churn0 = pre_t_df[pre_t_df.churn == 0].sample(48827, random_state=124)
churn1 = pre_t_df[pre_t_df.churn == 1].sample(48827, random_state=124)
under_t_df = pd.concat([churn0, churn1]).reset_index(drop=True)

# features와 targets 설정
features, targets = under_t_df.iloc[:, :-1], under_t_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

parameters = {
    'max_depth': [3, 4, 5],
    'min_samples_split': [6, 12, 18, 24]
}

rfc = RandomForestClassifier(n_estimators=100)

g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=5, n_jobs=-1)

# 모델 훈련
g_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 4, 5],
#                          'min_samples_split': [6, 12, 18, 24]})

# %%
under_t_df.churn.value_counts()
# Out:
# churn
# 0    48827
# 1    48827
# Name: count, dtype: int64

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                      params  mean_test_score  rank_test_score
# 0  {'max_depth': 2, 'min_samples_split': 2}         0.502541                1
# 1  {'max_depth': 2, 'min_samples_split': 3}         0.501363                2

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)

# %%
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[5418 4316]
#  [5367 4430]]
# 정확도: 0.5042, 정밀도: 0.5065, 재현율: 0.4522, F1: 0.4778, ROC-AUC: 0.5044
# ################################################################################

# %% [markdown]
# #### 1 Cycle
# 언더 샘플링을 통해 타겟 데이터의 비중을 맞춘 뒤 훈련을 진행한 결과, 모델의 성능이 낮게 나왔다.
# 오버 샘플링을 해보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.5042  | 0.5065  | 0.4522  | 0.4778   | 0.5044   |

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# features와 targets 설정
features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=124)

# SMOTE를 사용하여 데이터 오버샘플링
smote = SMOTE(random_state=124)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

parameters = {
     'max_depth': [3, 4, 5],
    'min_samples_split': [6, 12, 18, 24]
}

rfc = RandomForestClassifier(n_estimators=100)

g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=5, n_jobs=-1)

# 모델 훈련
g_rfc.fit(X_train_resampled, y_train_resampled)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 4, 5],
#                          'min_samples_split': [6, 12, 18, 24]})

# %%
y_train_resampled.value_counts()
# Out:
# churn
# 0    155771
# 1    155771
# Name: count, dtype: int64

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                        params  mean_test_score  \
# 0    {'max_depth': 3, 'min_samples_split': 6}         0.654763
# 1   {'max_depth': 3, 'min_samples_split': 12}         0.653630
# 2   {'max_depth': 3, 'min_samples_split': 18}         0.655764
# 3   {'max_depth': 3, 'min_samples_split': 24}         0.654773
# 4    {'max_depth': 4, 'min_samples_split': 6}         0.660274
# 5   {'max_depth': 4, 'min_samples_split': 12}         0.657851
# 6   {'max_depth': 4, 'min_samples_split': 18}         0.659857
# 7   {'max_depth': 4, 'min_samples_split': 24}         0.659745
# 8    {'max_depth': 5, 'min_samples_split': 6}         0.662393
# 9   {'max_depth': 5, 'min_samples_split': 12}         0.661703
# 10  {'max_depth': 5, 'min_samples_split': 18}         0.662085
# 11  {'max_depth': 5, 'min_samples_split': 24}         0.662040
#
#     rank_test_score
# 0                11
# 1                12
# 2                 9
# 3                10
# 4                 5
# ...

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)

# %%
get_evaluation(y_test, custom_prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[38951     4]
#  [ 9754     2]]
# 정확도: 0.7997, 정밀도: 0.3333, 재현율: 0.0002, F1: 0.0004, ROC-AUC: 0.5001
# ################################################################################

# %% [markdown]
# #### 2 Cycle
# 오버 샘플링을 한 뒤 훈련한 결과, 정확도를 제외한 나머지 성능이 대폭 감소하였다.
# 전체 스케일링을 해보고자한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.5042  | 0.5065  | 0.4522  | 0.4778   | 0.5044   |
# | 2 Cycle| 0.7997  | 0.3333  | 0.0002  | 0.0004   | 0.5001   |

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.pipeline import Pipeline

# features와 targets 설정
features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

# train_test_split을 사용하여 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=124)

# SMOTE를 사용하여 데이터 오버샘플링
smote = SMOTE(random_state=124)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# 파이프라인 정의
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # StandardScaler를 스케일링 단계로 추가
    ('rfc', RandomForestClassifier(n_estimators=100))  # RandomForestClassifier를 모델 단계로 추가
])

parameters = {
    'rfc__max_depth': [3, 4, 5],
    'rfc__min_samples_split': [6, 12, 18, 24]
}

g_rfc = GridSearchCV(pipeline, param_grid=parameters, cv=5, n_jobs=-1)

# 모델 훈련
g_rfc.fit(X_train_resampled, y_train_resampled)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('rfc', RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'rfc__max_depth': [3, 4, 5],
#                          'rfc__min_samples_split': [6, 12, 18, 24]})

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                                params  mean_test_score  \
# 0   {'rfc__max_depth': 3, 'rfc__min_samples_split'...         0.654237
# 1   {'rfc__max_depth': 3, 'rfc__min_samples_split'...         0.655100
# 2   {'rfc__max_depth': 3, 'rfc__min_samples_split'...         0.655103
# 3   {'rfc__max_depth': 3, 'rfc__min_samples_split'...         0.654111
# 4   {'rfc__max_depth': 4, 'rfc__min_samples_split'...         0.658666
# 5   {'rfc__max_depth': 4, 'rfc__min_samples_split'...         0.658791
# 6   {'rfc__max_depth': 4, 'rfc__min_samples_split'...         0.658037
# 7   {'rfc__max_depth': 4, 'rfc__min_samples_split'...         0.656329
# 8   {'rfc__max_depth': 5, 'rfc__min_samples_split'...         0.661757
# 9   {'rfc__max_depth': 5, 'rfc__min_samples_split'...         0.661334
# 10  {'rfc__max_depth': 5, 'rfc__min_samples_split'...         0.662319
# 11  {'rfc__max_depth': 5, 'rfc__min_samples_split'...         0.661099
#
#     rank_test_score
# 0                11
# ...

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)

# %%
get_evaluation(y_test, custom_prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[38951     4]
#  [ 9754     2]]
# 정확도: 0.7997, 정밀도: 0.3333, 재현율: 0.0002, F1: 0.0004, ROC-AUC: 0.5001
# ################################################################################

# %% [markdown]
# #### 3 Cycle (Last Cycle)
# 스케일링 및 오버 샘플링을 한 뒤 훈련하였으나 전혀 변화가 없었다.
# 다음으로는 AdaBoosting 방법을 사용해보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.5042  | 0.5065  | 0.4522  | 0.4778   | 0.5044   |
# | 2 Cycle| 0.7997  | 0.3333  | 0.0002  | 0.0004   | 0.5001   |
# | 3 Cycle| 0.7997  | 0.3333  | 0.0002  | 0.0004   | 0.5001   |

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 각 모델에서 얻은 성능 지표
model_names = ['DTC', 'KNN', 'RF']
accuracy_scores = [0.7887, 0.7787, 0.5042]
prediction_scores = [0.2070, 0.2004, 0.5065]
recall_scores = [0.0189, 0.4161, 0.4522]
f1_scores = [0.0347, 0.2705, 0.4778]
roc_auc = [0.5004, 0.4998, 0.5044]

# 데이터프레임 생성
import pandas as pd
df = pd.DataFrame({
    'Model': model_names,
    'Accuracy': accuracy_scores,
    'Prediction': prediction_scores,
    'Recall': recall_scores,
    'F1 Score': f1_scores,
    'ROC Score': roc_auc
})

# 데이터프레임 재구성
df = pd.melt(df, id_vars='Model', var_name='Metric', value_name='Score')

# seaborn을 사용하여 barplot 생성
plt.figure(figsize=(8, 6))
ax = sns.barplot(data=df, x='Metric', y='Score', hue='Model')

# 각 막대 위에 수치 표시
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.4f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 5), 
                textcoords = 'offset points',
                fontsize=7)

plt.xlabel('Metrics')
plt.ylabel('Scores')
plt.title('Performance of Boosting Models')
plt.ylim(0, 1)  # y축 범위 설정
plt.legend(title='Models')
plt.show()

# %% [markdown]
# ### 🆕 AdaBoosting

# %%
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 243548                0   28     16     4               3            130580
# 243549                2   52      2     4               0             82393
# 243550                2   59     24     4               4             51298
# 243551                1   49     12     4               2             83981
# 243552                1   37     23     3               0            144297
#
# ...

# %%
# train, test 나누기
from sklearn.model_selection import train_test_split

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier

parameters = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_ada = GridSearchCV(AdaBoostClassifier(), param_grid=parameters, cv=5, n_jobs=-1)
g_ada.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
result_df = pd.DataFrame(g_ada.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.671439
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.674894
# 2   {'learning_rate': 0.3, 'n_estimators': 150}         0.675332
# 3   {'learning_rate': 0.3, 'n_estimators': 200}         0.675646
# 4    {'learning_rate': 0.5, 'n_estimators': 50}         0.673839
# 5   {'learning_rate': 0.5, 'n_estimators': 100}         0.674299
# 6   {'learning_rate': 0.5, 'n_estimators': 150}         0.674587
# 7   {'learning_rate': 0.5, 'n_estimators': 200}         0.674651
# 8    {'learning_rate': 0.7, 'n_estimators': 50}         0.671782
# 9   {'learning_rate': 0.7, 'n_estimators': 100}         0.673589
# 10  {'learning_rate': 0.7, 'n_estimators': 150}         0.674273
# 11  {'learning_rate': 0.7, 'n_estimators': 200}         0.674794
# 12     {'learning_rate': 1, 'n_estimators': 50}         0.671261
# ...

# %%
ada = g_ada.best_estimator_
prediction = ada.predict(X_test)

# %%
get_evaluation(y_test, prediction, ada, X_test)
# Out:
# 오차 행렬
# [[24486 14460]
#  [ 6088  3677]]
# 정확도: 0.5782, 정밀도: 0.2027, 재현율: 0.3765, F1: 0.2636, ROC-AUC: 0.5026
# ################################################################################

# %% [markdown]
# #### 1 Cycle
# 이상치 제거 및 스케일링 없이 훈련을 진행한 결과, 모델의 성능이 전체적으로 낮은 것을 확인하였다.
# 이상치 제거와 타겟 데이터의 비중을 맞춰서 훈련을 해보고자한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.5782 | 0.2027  | 0.3765  | 0.2636   | 0.5026   |

# %%
pre_t_df = t_df.copy()

# %%
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 243548                0   28     16     4               3            130580
# 243549                2   52      2     4               0             82393
# 243550                2   59     24     4               4             51298
# 243551                1   49     12     4               2             83981
# 243552                1   37     23     3               0            144297
#
# ...

# %%
# 이상치 제거
pre_t_df = pre_t_df.iloc[std_pre_t_df.index].reset_index(drop=True)
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 241225                0   28     16     4               3            130580
# 241226                2   52      2     4               0             82393
# 241227                2   59     24     4               4             51298
# 241228                1   49     12     4               2             83981
# 241229                1   37     23     3               0            144297
#
# ...

# %%
# train, test 나누기
from sklearn.model_selection import train_test_split

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# %%
# 타겟 데이터 비중 맞추기
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# %%
y_train_over.value_counts()
# Out:
# churn
# 0    154283
# 1    154283
# Name: count, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier

parameters = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_ada = GridSearchCV(AdaBoostClassifier(), param_grid=parameters, cv=5, n_jobs=-1)
g_ada.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
result_df = pd.DataFrame(g_ada.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.670473
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.673727
# 2   {'learning_rate': 0.3, 'n_estimators': 150}         0.674530
# 3   {'learning_rate': 0.3, 'n_estimators': 200}         0.674605
# 4    {'learning_rate': 0.5, 'n_estimators': 50}         0.672408
# 5   {'learning_rate': 0.5, 'n_estimators': 100}         0.673636
# 6   {'learning_rate': 0.5, 'n_estimators': 150}         0.674070
# 7   {'learning_rate': 0.5, 'n_estimators': 200}         0.674255
# 8    {'learning_rate': 0.7, 'n_estimators': 50}         0.670833
# 9   {'learning_rate': 0.7, 'n_estimators': 100}         0.673137
# 10  {'learning_rate': 0.7, 'n_estimators': 150}         0.673798
# 11  {'learning_rate': 0.7, 'n_estimators': 200}         0.674038
# 12     {'learning_rate': 1, 'n_estimators': 50}         0.670000
# ...

# %%
ada = g_ada.best_estimator_
prediction = ada.predict(X_test)

# %%
get_evaluation(y_test, prediction, ada, X_test)
# Out:
# 오차 행렬
# [[24060 14511]
#  [ 5984  3691]]
# 정확도: 0.5752, 정밀도: 0.2028, 재현율: 0.3815, F1: 0.2648, ROC-AUC: 0.5026
# ################################################################################

# %% [markdown]
# #### 2 Cycle
# 이상치 제거 및 타켓 데이터의 비중을 맞춘 뒤 훈련을 진행하였더니, 큰 차이가 없었다.
# 전체 스케일링을 진행해보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.5782 | 0.2027  | 0.3765  | 0.2636   | 0.5026   |
# | 2 Cycle| 0.5752 | 0.2028  | 0.3815  | 0.2648   | 0.5026   |

# %%
pre_t_df = t_df.copy()

# %%
# 이상치 제거
pre_t_df = pre_t_df.iloc[std_pre_t_df.index].reset_index(drop=True)
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 241225                0   28     16     4               3            130580
# 241226                2   52      2     4               0             82393
# 241227                2   59     24     4               4             51298
# 241228                1   49     12     4               2             83981
# 241229                1   37     23     3               0            144297
#
# ...

# %%
# train, test 나누기
from sklearn.model_selection import train_test_split

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# %%
# 타겟 데이터 비중 맞추기
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# 파이프라인 정의
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # StandardScaler를 사용하여 스케일링
    ('ada', AdaBoostClassifier())  # AdaBoostClassifier
])

# 파라미터 그리드 설정
parameters = {
    'ada__n_estimators': [50, 100, 150, 200],
    'ada__learning_rate': [0.3, 0.5, 0.7, 1]
}

# GridSearchCV 객체 초기화
g_ada = GridSearchCV(pipeline, param_grid=parameters, cv=5, n_jobs=-1)

# 모델 훈련
g_ada.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('ada', AdaBoostClassifier())]),
#              n_jobs=-1,
#              param_grid={'ada__learning_rate': [0.3, 0.5, 0.7, 1],
#                          'ada__n_estimators': [50, 100, 150, 200]})

# %%
result_df = pd.DataFrame(g_ada.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                                params  mean_test_score  \
# 0   {'ada__learning_rate': 0.3, 'ada__n_estimators...         0.670911
# 1   {'ada__learning_rate': 0.3, 'ada__n_estimators...         0.673536
# 2   {'ada__learning_rate': 0.3, 'ada__n_estimators...         0.674501
# 3   {'ada__learning_rate': 0.3, 'ada__n_estimators...         0.674696
# 4   {'ada__learning_rate': 0.5, 'ada__n_estimators...         0.672087
# 5   {'ada__learning_rate': 0.5, 'ada__n_estimators...         0.673542
# 6   {'ada__learning_rate': 0.5, 'ada__n_estimators...         0.673772
# 7   {'ada__learning_rate': 0.5, 'ada__n_estimators...         0.674048
# 8   {'ada__learning_rate': 0.7, 'ada__n_estimators...         0.670541
# 9   {'ada__learning_rate': 0.7, 'ada__n_estimators...         0.672797
# 10  {'ada__learning_rate': 0.7, 'ada__n_estimators...         0.673762
# 11  {'ada__learning_rate': 0.7, 'ada__n_estimators...         0.674161
# ...

# %%
ada = g_ada.best_estimator_
prediction = ada.predict(X_test)

# %%
get_evaluation(y_test, prediction, ada, X_test)
# Out:
# 오차 행렬
# [[24078 14493]
#  [ 6015  3660]]
# 정확도: 0.5749, 정밀도: 0.2016, 재현율: 0.3783, F1: 0.2630, ROC-AUC: 0.5013
# ################################################################################

# %% [markdown]
# #### 3 Cycle (Last Cycle)
# 이상치 제거, 타켓 데이터의 비중맞추기, 전체 스케일링을 한 뒤 훈련을 진행하였으나 거의 변화가 없었다.
# 다음으로는 GBM Boosting 방식을 사용하고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.5782 | 0.2027  | 0.3765  | 0.2636   | 0.5026   |
# | 2 Cycle| 0.5752 | 0.2028  | 0.3815  | 0.2648   | 0.5026   |
# | 3 Cycle| 0.5749 | 0.2016  | 0.3783  | 0.2630   | 0.5013   |

# %% [markdown]
# ### 🆕 GBM Boosting

# %%
pre_t_df = t_df.copy()

# %%
# 이상치 제거
pre_t_df = pre_t_df.iloc[std_pre_t_df.index].reset_index(drop=True)
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 241225                0   28     16     4               3            130580
# 241226                2   52      2     4               0             82393
# 241227                2   59     24     4               4             51298
# 241228                1   49     12     4               2             83981
# 241229                1   37     23     3               0            144297
#
# ...

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import GradientBoostingClassifier

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.churn

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

parameters = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_gbc = GridSearchCV(GradientBoostingClassifier(loss='log_loss'), param_grid=parameters, cv=5, n_jobs=-1)
g_gbc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
result_df = pd.DataFrame(g_gbc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.799273
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.799160
# 2   {'learning_rate': 0.3, 'n_estimators': 150}         0.798981
# 3   {'learning_rate': 0.3, 'n_estimators': 200}         0.798837
# 4    {'learning_rate': 0.5, 'n_estimators': 50}         0.798924
# 5   {'learning_rate': 0.5, 'n_estimators': 100}         0.798401
# 6   {'learning_rate': 0.5, 'n_estimators': 150}         0.797934
# 7   {'learning_rate': 0.5, 'n_estimators': 200}         0.797585
# 8    {'learning_rate': 0.7, 'n_estimators': 50}         0.798385
# 9   {'learning_rate': 0.7, 'n_estimators': 100}         0.797585
# 10  {'learning_rate': 0.7, 'n_estimators': 150}         0.796758
# 11  {'learning_rate': 0.7, 'n_estimators': 200}         0.795814
# 12     {'learning_rate': 1, 'n_estimators': 50}         0.797800
# ...

# %%
gbc = g_gbc.best_estimator_
prediction = gbc.predict(X_test)

# %%
get_evaluation(y_test, prediction, gbc, X_test)
# Out:
# 오차 행렬
# [[38554    17]
#  [ 9667     8]]
# 정확도: 0.7993, 정밀도: 0.3200, 재현율: 0.0008, F1: 0.0016, ROC-AUC: 0.5002
# ################################################################################

# %% [markdown]
# #### 1 Cycle
# 이상치만 제거한 뒤 모델을 훈련을 진행한 결과, 전체적인 성능이 안좋았다.
# 이상치 제거 없이 타켓 데이터의 비중을 맞춰 보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.7993  | 0.3200  | 0.0008  | 0.0016   | 0.5002   |

# %%
pre_t_df = t_df.copy()

# %%
# 타겟 데이터 비중 맞추기
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# %%
y_train_over.value_counts()
# Out:
# churn
# 0    154283
# 1    154283
# Name: count, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import GradientBoostingClassifier

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.churn

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

parameters = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_gbc = GridSearchCV(GradientBoostingClassifier(loss='log_loss'), param_grid=parameters, cv=5, n_jobs=-1)
g_gbc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
result_df = pd.DataFrame(g_gbc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.680837
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.682153
# 2   {'learning_rate': 0.3, 'n_estimators': 150}         0.682850
# 3   {'learning_rate': 0.3, 'n_estimators': 200}         0.683371
# 4    {'learning_rate': 0.5, 'n_estimators': 50}         0.680870
# 5   {'learning_rate': 0.5, 'n_estimators': 100}         0.682480
# 6   {'learning_rate': 0.5, 'n_estimators': 150}         0.683232
# 7   {'learning_rate': 0.5, 'n_estimators': 200}         0.683569
# 8    {'learning_rate': 0.7, 'n_estimators': 50}         0.680633
# 9   {'learning_rate': 0.7, 'n_estimators': 100}         0.682137
# 10  {'learning_rate': 0.7, 'n_estimators': 150}         0.682464
# 11  {'learning_rate': 0.7, 'n_estimators': 200}         0.682691
# 12     {'learning_rate': 1, 'n_estimators': 50}         0.680335
# ...

# %%
gbc = g_gbc.best_estimator_
prediction = gbc.predict(X_test)

# %%
get_evaluation(y_test, prediction, gbc, X_test)
# Out:
# 오차 행렬
# [[26887 12059]
#  [ 6539  3226]]
# 정확도: 0.6182, 정밀도: 0.2111, 재현율: 0.3304, F1: 0.2576, ROC-AUC: 0.5104
# ################################################################################

# %% [markdown]
# #### 2 Cycle
# 이상치 제거없이 타겟 데이터의 비중을 맞춘 뒤 훈련을 진행한 결과, 전체적인 성능이 소폭 상승하였다.
# 전체 스케일링을 진행해보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.7993  | 0.3200  | 0.0008  | 0.0016   | 0.5002   |
# | 2 Cycle| 0.6182  | 0.2111  | 0.3304  | 0.2576   | 0.5104   |

# %%
y_train_over.value_counts()
# Out:
# churn
# 0    154283
# 1    154283
# Name: count, dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV, train_test_split

# 데이터 분할
features, targets = pre_t_df.iloc[:, :-1], pre_t_df.churn
X_train, X_test, y_train, y_test = train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# 스케일링과 분류기를 포함한 파이프라인 설정
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # 데이터 스케일링
    ('gbc', GradientBoostingClassifier(loss='log_loss'))  # 분류기
])

# 그리드 서치를 위한 매개변수 설정
parameters = {
    'gbc__n_estimators': [50, 100, 150, 200],
    'gbc__learning_rate': [0.3, 0.5, 0.7, 1]
}

# 그리드 서치 객체 초기화
g_gbc = GridSearchCV(pipeline, param_grid=parameters, cv=5, n_jobs=-1)

# 모델 훈련
g_gbc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('gbc', GradientBoostingClassifier())]),
#              n_jobs=-1,
#              param_grid={'gbc__learning_rate': [0.3, 0.5, 0.7, 1],
#                          'gbc__n_estimators': [50, 100, 150, 200]})

# %%
result_df = pd.DataFrame(g_gbc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                                params  mean_test_score  \
# 0   {'gbc__learning_rate': 0.3, 'gbc__n_estimators...         0.680837
# 1   {'gbc__learning_rate': 0.3, 'gbc__n_estimators...         0.682156
# 2   {'gbc__learning_rate': 0.3, 'gbc__n_estimators...         0.682843
# 3   {'gbc__learning_rate': 0.3, 'gbc__n_estimators...         0.683368
# 4   {'gbc__learning_rate': 0.5, 'gbc__n_estimators...         0.680870
# 5   {'gbc__learning_rate': 0.5, 'gbc__n_estimators...         0.682483
# 6   {'gbc__learning_rate': 0.5, 'gbc__n_estimators...         0.683232
# 7   {'gbc__learning_rate': 0.5, 'gbc__n_estimators...         0.683559
# 8   {'gbc__learning_rate': 0.7, 'gbc__n_estimators...         0.680633
# 9   {'gbc__learning_rate': 0.7, 'gbc__n_estimators...         0.682140
# 10  {'gbc__learning_rate': 0.7, 'gbc__n_estimators...         0.682448
# 11  {'gbc__learning_rate': 0.7, 'gbc__n_estimators...         0.682701
# ...

# %%
gbc = g_gbc.best_estimator_
prediction = gbc.predict(X_test)

# %%
get_evaluation(y_test, prediction, gbc, X_test)
# Out:
# 오차 행렬
# [[26887 12059]
#  [ 6539  3226]]
# 정확도: 0.6182, 정밀도: 0.2111, 재현율: 0.3304, F1: 0.2576, ROC-AUC: 0.5104
# ################################################################################

# %% [markdown]
# #### 3 Cycle (Last Cycle)
# Standard Scaler를 사용하여 스케일링을 한 뒤 훈련을 진행하였으나 변화가 없었다.
# 다음으로는 XGBoost 방식을 사용하여 훈련하고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.7993  | 0.3200  | 0.0008  | 0.0016   | 0.5002   |
# | 2 Cycle| 0.6182  | 0.2111  | 0.3304  | 0.2576   | 0.5104   |
# | 3 Cycle| 0.6182  | 0.2111  | 0.3304  | 0.2576   | 0.5104   |

# %% [markdown]
# ### 🆕 XGBoost

# %%
pre_t_df = t_df.copy()

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.churn

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

y_train_over.value_counts()
# Out:
# churn
# 0    155780
# 1    155780
# Name: count, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

parameters = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

xgb = XGBClassifier()

g_xgb = GridSearchCV(xgb, 
                     param_grid=parameters, 
                     cv=5, 
                     refit=True, 
                     return_train_score=True, 
                     n_jobs=-1)

g_xgb.fit(X_train_over, y_train_over, early_stopping_rounds=50, eval_set=evals)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\joblib\externals\loky\process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [0]	validation_0-logloss:0.67765	validation_1-logloss:0.67760
# [1]	validation_0-logloss:0.67146	validation_1-logloss:0.67137
# [2]	validation_0-logloss:0.66941	validation_1-logloss:0.66927
# [3]	validation_0-logloss:0.66814	validation_1-logloss:0.66757
# [4]	validation_0-logloss:0.66666	validation_1-logloss:0.66596
# [5]	validation_0-logloss:0.66549	validation_1-logloss:0.66454
# [6]	validation_0-logloss:0.66555	validation_1-logloss:0.66463
# [7]	validation_0-logloss:0.66498	validation_1-logloss:0.66424
# ...

# %%
result_df = pd.DataFrame(g_xgb.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.684603
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.688407
# 2   {'learning_rate': 0.3, 'n_estimators': 150}         0.691007
# 3   {'learning_rate': 0.3, 'n_estimators': 200}         0.693131
# 4    {'learning_rate': 0.5, 'n_estimators': 50}         0.684529
# 5   {'learning_rate': 0.5, 'n_estimators': 100}         0.686812
# 6   {'learning_rate': 0.5, 'n_estimators': 150}         0.688153
# 7   {'learning_rate': 0.5, 'n_estimators': 200}         0.690323
# 8    {'learning_rate': 0.7, 'n_estimators': 50}         0.680675
# 9   {'learning_rate': 0.7, 'n_estimators': 100}         0.682283
# 10  {'learning_rate': 0.7, 'n_estimators': 150}         0.684026
# 11  {'learning_rate': 0.7, 'n_estimators': 200}         0.685114
# 12     {'learning_rate': 1, 'n_estimators': 50}         0.677565
# ...

# %%
xgb = g_xgb.best_estimator_
prediction = xgb.predict(X_test)

# %%
get_evaluation(y_test, prediction, xgb, X_test)
# Out:
# 오차 행렬
# [[27160 11786]
#  [ 6790  2975]]
# 정확도: 0.6186, 정밀도: 0.2015, 재현율: 0.3047, F1: 0.2426, ROC-AUC: 0.5010
# ################################################################################

# %% [markdown]
# #### 1 Cycle
# 오버 샘플링을 통해 타겟 데이터의 비중만 맞춘 뒤 훈련을 진행한 결과, 성능이 우수한 모델이 나오지는 않았다.
# 전체 스케일링을 진행해 보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.6186  | 0.2015  | 0.3047  | 0.2426   | 0.5010   |

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.churn

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

y_train_over.value_counts()
# Out:
# churn
# 0    155780
# 1    155780
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.churn

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

y_train_over.value_counts()
# Out:
# churn
# 0    155780
# 1    155780
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline

parameters = {
    'xgb__n_estimators': [50, 100, 150, 200],
    'xgb__learning_rate': [0.3, 0.5, 0.7, 1]
}

xgb_pipe = Pipeline([('standard_scaler', StandardScaler()), ('xgb', XGBClassifier())])

g_xgb = GridSearchCV(xgb_pipe, param_grid=parameters, cv=5, n_jobs=-1)
g_xgb.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('xgb',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
# ...

# %%
result_df = pd.DataFrame(g_xgb.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                                params  mean_test_score  \
# 0   {'xgb__learning_rate': 0.3, 'xgb__n_estimators...         0.685367
# 1   {'xgb__learning_rate': 0.3, 'xgb__n_estimators...         0.689861
# 2   {'xgb__learning_rate': 0.3, 'xgb__n_estimators...         0.693536
# 3   {'xgb__learning_rate': 0.3, 'xgb__n_estimators...         0.696270
# 4   {'xgb__learning_rate': 0.5, 'xgb__n_estimators...         0.685531
# 5   {'xgb__learning_rate': 0.5, 'xgb__n_estimators...         0.689501
# 6   {'xgb__learning_rate': 0.5, 'xgb__n_estimators...         0.692146
# 7   {'xgb__learning_rate': 0.5, 'xgb__n_estimators...         0.695263
# 8   {'xgb__learning_rate': 0.7, 'xgb__n_estimators...         0.682424
# 9   {'xgb__learning_rate': 0.7, 'xgb__n_estimators...         0.685383
# 10  {'xgb__learning_rate': 0.7, 'xgb__n_estimators...         0.689196
# 11  {'xgb__learning_rate': 0.7, 'xgb__n_estimators...         0.691806
# ...

# %%
xgb = g_xgb.best_estimator_
prediction = xgb.predict(X_test)

# %%
get_evaluation(y_test, prediction, xgb, X_test)
# Out:
# 오차 행렬
# [[27160 11786]
#  [ 6790  2975]]
# 정확도: 0.6186, 정밀도: 0.2015, 재현율: 0.3047, F1: 0.2426, ROC-AUC: 0.5010
# ################################################################################

# %% [markdown]
# #### 2 Cycle
# 전체 스케일링을 한 후 훈련을 진행하였으나 변화가 없었다.
# 이상치를 제거해 보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.6186  | 0.2015  | 0.3047  | 0.2426   | 0.5010   |
# | 2 Cycle| 0.6186  | 0.2015  | 0.3047  | 0.2426   | 0.5010   |

# %%
# 이상치 제거
pre_t_df = pre_t_df.iloc[std_pre_t_df.index].reset_index(drop=True)
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 241225                0   28     16     4               3            130580
# 241226                2   52      2     4               0             82393
# 241227                2   59     24     4               4             51298
# 241228                1   49     12     4               2             83981
# 241229                1   37     23     3               0            144297
#
# ...

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.churn

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

y_train_over.value_counts()
# Out:
# churn
# 0    154283
# 1    154283
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.churn

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

y_train_over.value_counts()
# Out:
# churn
# 0    154283
# 1    154283
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline

parameters = {
    'xgb__n_estimators': [50, 100, 150, 200],
    'xgb__learning_rate': [0.3, 0.5, 0.7, 1]
}

xgb_pipe = Pipeline([('standard_scaler', StandardScaler()), ('xgb', XGBClassifier())])

g_xgb = GridSearchCV(xgb_pipe, param_grid=parameters, cv=5, n_jobs=-1)
g_xgb.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('xgb',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
# ...

# %%
result_df = pd.DataFrame(g_xgb.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                                params  mean_test_score  \
# 0   {'xgb__learning_rate': 0.3, 'xgb__n_estimators...         0.685799
# 1   {'xgb__learning_rate': 0.3, 'xgb__n_estimators...         0.690067
# 2   {'xgb__learning_rate': 0.3, 'xgb__n_estimators...         0.694047
# 3   {'xgb__learning_rate': 0.3, 'xgb__n_estimators...         0.697119
# 4   {'xgb__learning_rate': 0.5, 'xgb__n_estimators...         0.685945
# 5   {'xgb__learning_rate': 0.5, 'xgb__n_estimators...         0.689957
# 6   {'xgb__learning_rate': 0.5, 'xgb__n_estimators...         0.693505
# 7   {'xgb__learning_rate': 0.5, 'xgb__n_estimators...         0.696691
# 8   {'xgb__learning_rate': 0.7, 'xgb__n_estimators...         0.683439
# 9   {'xgb__learning_rate': 0.7, 'xgb__n_estimators...         0.686363
# 10  {'xgb__learning_rate': 0.7, 'xgb__n_estimators...         0.688803
# 11  {'xgb__learning_rate': 0.7, 'xgb__n_estimators...         0.692183
# ...

# %%
xgb = g_xgb.best_estimator_
prediction = xgb.predict(X_test)

# %%
get_evaluation(y_test, prediction, xgb, X_test)
# Out:
# 오차 행렬
# [[27064 11507]
#  [ 6739  2936]]
# 정확도: 0.6218, 정밀도: 0.2033, 재현율: 0.3035, F1: 0.2435, ROC-AUC: 0.5026
# ################################################################################

# %% [markdown]
# #### 3 Cycle (Last Cycle)
# 이상치 제거, 전체 스케일링, 타겟 데이터 비중을 맞춘 후 훈련을 진행하더니, 미세한 성능 상승이 있었다.
# 다음으로는 LGBM 방식을 사용하고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.6186  | 0.2015  | 0.3047  | 0.2426   | 0.5010   |
# | 2 Cycle| 0.6186  | 0.2015  | 0.3047  | 0.2426   | 0.5010   |
# | 3 Cycle| 0.6218  | 0.2033  | 0.3035  | 0.2435   | 0.5026   |

# %% [markdown]
# ### 🆕 LightGBM

# %%
pre_t_df = t_df.copy()

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from imblearn.over_sampling import SMOTE
from lightgbm import LGBMClassifier

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

parameters = {
    'n_estimators': [50, 100, 200, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

g_lgbm = GridSearchCV(LGBMClassifier(), param_grid=parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)
g_lgbm.fit(X_train_over, y_train_over, eval_set=evals)
# Out:
# [LightGBM] [Info] Number of positive: 155780, number of negative: 155780
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001528 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1037
# [LightGBM] [Info] Number of data points in the train set: 311560, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# GridSearchCV(cv=5, estimator=LGBMClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 200, 500]},
#              return_train_score=True)

# %%
result_df = pd.DataFrame(g_lgbm.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)

lgbm = g_lgbm.best_estimator_
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.683865
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.687120
# 2   {'learning_rate': 0.3, 'n_estimators': 200}         0.691908
# 3   {'learning_rate': 0.3, 'n_estimators': 500}         0.702369
# 4    {'learning_rate': 0.5, 'n_estimators': 50}         0.683502
# 5   {'learning_rate': 0.5, 'n_estimators': 100}         0.685502
# 6   {'learning_rate': 0.5, 'n_estimators': 200}         0.689145
# 7   {'learning_rate': 0.5, 'n_estimators': 500}         0.699397
# 8    {'learning_rate': 0.7, 'n_estimators': 50}         0.681817
# 9   {'learning_rate': 0.7, 'n_estimators': 100}         0.682562
# 10  {'learning_rate': 0.7, 'n_estimators': 200}         0.685107
# 11  {'learning_rate': 0.7, 'n_estimators': 500}         0.692961
# 12     {'learning_rate': 1, 'n_estimators': 50}         0.675696
# ...

# %%
prediction = lgbm.predict(X_test)

# %%
get_evaluation(y_test, prediction, lgbm, X_test)
# Out:
# 오차 행렬
# [[27902 11044]
#  [ 6967  2798]]
# 정확도: 0.6302, 정밀도: 0.2021, 재현율: 0.2865, F1: 0.2370, ROC-AUC: 0.5015
# ################################################################################

# %% [markdown]
# #### 1 Cycle
# 타겟 데이터 비중만 맞춘 후 훈련을 진행하더니, 모델의 성능이 좋지 않았다.
# 전체 스케일링을 하고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.6302  | 0.2021  | 0.2865  | 0.2370   | 0.5015   |

# %%
pre_t_df = t_df.copy()

# %%
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

# SMOTE를 사용하여 클래스 불균형 해결
smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# 검증 데이터의 세트 추가
evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

# 파이프라인 정의
xgb_pipe = Pipeline([('standard_scaler', StandardScaler()), ('lgbm', LGBMClassifier())])

# 그리드 서치를 사용하여 모델 튜닝
parameters = {
    'lgbm__n_estimators': [50, 100, 200, 500],
    'lgbm__learning_rate': [0.3, 0.5, 0.7, 1]
}
g_lgbm = GridSearchCV(xgb_pipe, param_grid=parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)
g_lgbm.fit(X_train_over, y_train_over)
# Out:
# [LightGBM] [Info] Number of positive: 155780, number of negative: 155780
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001042 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1050
# [LightGBM] [Info] Number of data points in the train set: 311560, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('lgbm', LGBMClassifier())]),
#              n_jobs=-1,
#              param_grid={'lgbm__learning_rate': [0.3, 0.5, 0.7, 1],
#                          'lgbm__n_estimators': [50, 100, 200, 500]},
#              return_train_score=True)

# %%
result_df = pd.DataFrame(g_lgbm.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)

lgbm = g_lgbm.best_estimator_
# Out:
#                                                params  mean_test_score  \
# 0   {'lgbm__learning_rate': 0.3, 'lgbm__n_estimato...         0.684347
# 1   {'lgbm__learning_rate': 0.3, 'lgbm__n_estimato...         0.687447
# 2   {'lgbm__learning_rate': 0.3, 'lgbm__n_estimato...         0.692152
# 3   {'lgbm__learning_rate': 0.3, 'lgbm__n_estimato...         0.703149
# 4   {'lgbm__learning_rate': 0.5, 'lgbm__n_estimato...         0.683592
# 5   {'lgbm__learning_rate': 0.5, 'lgbm__n_estimato...         0.685894
# 6   {'lgbm__learning_rate': 0.5, 'lgbm__n_estimato...         0.689427
# 7   {'lgbm__learning_rate': 0.5, 'lgbm__n_estimato...         0.699172
# 8   {'lgbm__learning_rate': 0.7, 'lgbm__n_estimato...         0.680229
# 9   {'lgbm__learning_rate': 0.7, 'lgbm__n_estimato...         0.682231
# 10  {'lgbm__learning_rate': 0.7, 'lgbm__n_estimato...         0.684334
# 11  {'lgbm__learning_rate': 0.7, 'lgbm__n_estimato...         0.693298
# ...

# %%
prediction = lgbm.predict(X_test)

# %%
get_evaluation(y_test, prediction, lgbm, X_test)
# Out:
# 오차 행렬
# [[27740 11206]
#  [ 6974  2791]]
# 정확도: 0.6268, 정밀도: 0.1994, 재현율: 0.2858, F1: 0.2349, ROC-AUC: 0.4990
# ################################################################################

# %% [markdown]
# #### 2 Cycle
# 전체 스케일링을 진행하였으나, 미세하게 성능이 감소하였으며 큰 차이는 없었다.
# 이상치를 제거해 보고자 한다.
#
# | 구분   | 정확도  | 정밀도  | 재현율  | F1 score | ROC-AUC |
# |--------|---------|---------|---------|----------|----------|
# | 1 Cycle| 0.6302  | 0.2021  | 0.2865  | 0.2370   | 0.5015   |
# | 2 Cycle| 0.6268  | 0.1994  | 0.2858  | 0.2349   | 0.4990   |

# %%
pre_t_df = t_df.copy()

# %%
# 이상치 제거
pre_t_df = pre_t_df.iloc[std_pre_t_df.index].reset_index(drop=True)
pre_t_df
# Out:
#         telecom_partner  age  state  city  num_dependents  estimated_salary  \
# 0                     2   25     10     4               4            124962
# 1                     2   55     16     5               2            130556
# 2                     3   57      1     2               0            148828
# 3                     1   46     22     4               1             38722
# 4                     1   26     24     2               2             55098
# ...                 ...  ...    ...   ...             ...               ...
# 241225                0   28     16     4               3            130580
# 241226                2   52      2     4               0             82393
# 241227                2   59     24     4               4             51298
# 241228                1   49     12     4               2             83981
# 241229                1   37     23     3               0            144297
#
# ...

# %%
# 타겟 데이터 비중 맞추기
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# %%
y_train_over.value_counts()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

parameters = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_gbc = GridSearchCV(GradientBoostingClassifier(), param_grid=parameters, cv=5, n_jobs=-1)
g_gbc.fit(X_train_over, y_train_over)

# %%
result_df = pd.DataFrame(g_gbc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)

# %%
gbc = g_gbc.best_estimator_
prediction = gbc.predict(X_test)

# %%
get_evaluation(y_test, prediction, gbc, X_test)

# %% [markdown]
# #### 2 Cycle
