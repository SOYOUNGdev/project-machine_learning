# %% [markdown]
# ### 🆕 심장병 예측
# - 심장병의 특성을 회귀분석하여, 향후 10년간 심장병의 발병을 예측한다. (분류-logistic regression / 차원 축소)
#
# 1. male: 성별
# 2. age: 나이
# 3. education: 교육 수준
# 4. currentSmoker: 현재 흡연자 여부
# 5. cigsPerDay: 하루에 흡연하는 평균 담배 개수
# 6. BPMeds: 혈압약 복용 여부
# 7. prevalentStroke: 뇌졸중 여부
# 8. prevalentHyp: 고혈압 여부
# 9. diabetes: 당뇨병 여부
# 10. totChol: 총 콜레스테롤 수치
# 11. sysBP: 수축기 혈압
# 12. diaBP: 확장기 혈압
# 13. BMI: body mass 지수
# 14. heartRate: 심박수
# 15. glucose: 포도당 수치
# 16. TenYearCHD: 타겟 데이터

# %%
import pandas as pd

h_df = pd.read_csv('./datasets/heart_disease.csv')
h_df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB

# %%
h_df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
pre_h_df = h_df.drop(labels=['education'], axis=1)

# %%
pre_h_df = pre_h_df.dropna(subset=['glucose', 'cigsPerDay', 'totChol', 'BMI', 'BPMeds', 'heartRate'])
pre_h_df = pre_h_df.reset_index(drop=True)

# %%
pre_h_df
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 3744     1   58              0         0.0     0.0                0
# 3745     1   68              0         0.0     0.0                0
# 3746     1   50              1         1.0     0.0                0
# 3747     1   51              1        43.0     0.0                0
# 3748     0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 3744             1         0    187.0  141.0   81.0  24.96       80.0
# 3745             1         0    176.0  168.0   97.0  23.14       60.0
# 3746             1         0    313.0  179.0   92.0  25.97       66.0
# 3747             0         0    207.0  126.5   80.0  19.71       65.0
# 3748             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose  TenYearCHD
# 0        77.0           0
# 1        76.0           0
# 2        70.0           0
# 3       103.0           1
# 4        85.0           0
# ...       ...         ...
# 3744     81.0           0
# 3745     79.0           1
# 3746     86.0           1
# 3747     68.0           0
# 3748    107.0           0
#
# [3749 rows x 15 columns]

# %%
pre_h_df['targets'] = pre_h_df['diabetes']
pre_h_df = pre_h_df.drop(labels=['diabetes'], axis=1)
pre_h_df
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 3744     1   58              0         0.0     0.0                0
# 3745     1   68              0         0.0     0.0                0
# 3746     1   50              1         1.0     0.0                0
# 3747     1   51              1        43.0     0.0                0
# 3748     0   52              0         0.0     0.0                0
#
#       prevalentHyp  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0                0    195.0  106.0   70.0  26.97       80.0     77.0
# 1                0    250.0  121.0   81.0  28.73       95.0     76.0
# 2                0    245.0  127.5   80.0  25.34       75.0     70.0
# 3                1    225.0  150.0   95.0  28.58       65.0    103.0
# 4                0    285.0  130.0   84.0  23.10       85.0     85.0
# ...            ...      ...    ...    ...    ...        ...      ...
# 3744             1    187.0  141.0   81.0  24.96       80.0     81.0
# 3745             1    176.0  168.0   97.0  23.14       60.0     79.0
# 3746             1    313.0  179.0   92.0  25.97       66.0     86.0
# 3747             0    207.0  126.5   80.0  19.71       65.0     68.0
# 3748             0    269.0  133.5   83.0  21.47       80.0    107.0
#
#       TenYearCHD  targets
# 0              0        0
# 1              0        0
# 2              0        0
# 3              1        0
# 4              0        0
# ...          ...      ...
# 3744           0        0
# 3745           1        0
# 3746           1        0
# 3747           0        0
# 3748           0        0
#
# [3749 rows x 15 columns]

# %%
pre_h_df.duplicated().sum()
# Out:
# 0

# %%
pre_h_df.targets.value_counts()
# Out:
# targets
# 0    3647
# 1     102
# Name: count, dtype: int64

# %%
pre_h_df.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'male'}>,
#         <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'currentSmoker'}>,
#         <Axes: title={'center': 'cigsPerDay'}>],
#        [<Axes: title={'center': 'BPMeds'}>,
#         <Axes: title={'center': 'prevalentStroke'}>,
#         <Axes: title={'center': 'prevalentHyp'}>,
#         <Axes: title={'center': 'totChol'}>],
#        [<Axes: title={'center': 'sysBP'}>,
#         <Axes: title={'center': 'diaBP'}>,
#         <Axes: title={'center': 'BMI'}>,
#         <Axes: title={'center': 'heartRate'}>],
#        [<Axes: title={'center': 'glucose'}>,
#         <Axes: title={'center': 'TenYearCHD'}>,
#         <Axes: title={'center': 'targets'}>, <Axes: >]], dtype=object)

# %%
pre_h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3749 entries, 0 to 3748
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             3749 non-null   int64
#  1   age              3749 non-null   int64
#  2   currentSmoker    3749 non-null   int64
#  3   cigsPerDay       3749 non-null   float64
#  4   BPMeds           3749 non-null   float64
#  5   prevalentStroke  3749 non-null   int64
#  6   prevalentHyp     3749 non-null   int64
#  7   totChol          3749 non-null   float64
#  8   sysBP            3749 non-null   float64
#  9   diaBP            3749 non-null   float64
#  10  BMI              3749 non-null   float64
#  11  heartRate        3749 non-null   float64
#  12  glucose          3749 non-null   float64
#  13  TenYearCHD       3749 non-null   int64
#  14  targets          3749 non-null   int64
# dtypes: float64(8), int64(7)
# memory usage: 439.5 KB

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split

features, targets = pre_h_df.iloc[:, :-1], pre_h_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

# lda에서의 n_components = 분류-1
# 분류란? 타겟 데이터의 value_counts() 수 
for i in range(1):
    lda = LinearDiscriminantAnalysis(n_components=(i + 1))
    
    lda_train = lda.fit_transform(X_train, y_train)
    # 보존율 확인
    print(lda.explained_variance_ratio_.sum())
# Out:
# 1.0

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# 1차원으로 훈련 진행
lda = LinearDiscriminantAnalysis(n_components=1)

lda_train = lda.fit_transform(X_train, y_train)

lda_columns = [f'lda{i + 1}' for i in range(lda_train.shape[1])]
lda_train_df = pd.DataFrame(lda_train, columns=lda_columns)
lda_train_df.loc[:, 'target'] = y_train

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split

# 파이프라인 구축
pipe = Pipeline([('std', StandardScaler()),
                 ('lda', LinearDiscriminantAnalysis(n_components=1)),
                 ('log_reg', LogisticRegression())])

# LogisticRegression의 매개변수 설정
parameters = {'log_reg__C': [0.001, 0.01, 0.1, 1, 10, 100]}

# 그리드서치를 사용하여 최적의 매개변수 탐색
g_log_reg = GridSearchCV(pipe, param_grid=parameters, cv=10, scoring='accuracy')

# 훈련
g_log_reg.fit(X_train, y_train)
prediction = g_log_reg.predict(X_test)

# %%
result_df = pd.DataFrame(g_log_reg.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                   params  mean_test_score  rank_test_score
# 0  {'log_reg__C': 0.001}         0.973324                6
# 1   {'log_reg__C': 0.01}         0.981327                5
# 2    {'log_reg__C': 0.1}         0.984328                1
# 3      {'log_reg__C': 1}         0.984328                1
# 4     {'log_reg__C': 10}         0.984328                1
# 5    {'log_reg__C': 100}         0.984328                1

# %%
from sklearn.metrics import accuracy_score, precision_score , recall_score , confusion_matrix, ConfusionMatrixDisplay, f1_score, roc_auc_score
import matplotlib.pyplot as plt

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    roc_auc = roc_auc_score(y_test, prediction)

    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1:{3:.4f}, AUC:{4:.4f}'.format(accuracy , precision ,recall, f1, roc_auc))
    print("#" * 75)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
get_evaluation(y_test, prediction, g_log_reg, X_test)
# Out:
# 오차 행렬
# [[730   0]
#  [  6  14]]
# 정확도: 0.9920, 정밀도: 1.0000, 재현율: 0.7000, F1:0.8235, AUC:0.8500
# ###########################################################################

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.metrics import precision_recall_curve
import numpy as np

def precision_recall_curve_plot(y_test , prediction_proba_class1):

    precisions, recalls, thresholds = precision_recall_curve(y_test, prediction_proba_class1)
    
    # X축: threshold
    # Y축: 정밀도, 재현율 
    # 정밀도는 점선으로 표시
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    # X축(threshold)의 Scale을 0 ~ 1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend()
    plt.grid()
    plt.show()
    
precision_recall_curve_plot(y_test, g_log_reg.predict_proba(X_test)[:, 1] )

# %%
_, _, thresholds = precision_recall_curve(y_test, g_log_reg.predict_proba(X_test)[:, 1])
thresholds
# Out:
# array([5.83640332e-04, 9.64465967e-04, 9.86358419e-04, 1.26730681e-03,
#        1.29716819e-03, 1.38601175e-03, 1.45083992e-03, 1.45241403e-03,
#        1.54530187e-03, 1.66969950e-03, 1.67932784e-03, 1.70648980e-03,
#        1.74930918e-03, 1.78634651e-03, 1.80656491e-03, 1.83069550e-03,
#        1.92680785e-03, 1.93427295e-03, 1.95727572e-03, 1.96065576e-03,
#        1.97816675e-03, 2.01202998e-03, 2.03494031e-03, 2.04331053e-03,
#        2.04412204e-03, 2.06416265e-03, 2.06660095e-03, 2.08229352e-03,
#        2.11054773e-03, 2.14193853e-03, 2.18568089e-03, 2.18643249e-03,
#        2.19484125e-03, 2.21675202e-03, 2.25733053e-03, 2.26868945e-03,
#        2.28856021e-03, 2.30291968e-03, 2.30945674e-03, 2.31234009e-03,
#        2.31498139e-03, 2.31852460e-03, 2.32906868e-03, 2.33248550e-03,
#        2.34140803e-03, 2.38862226e-03, 2.39383142e-03, 2.43919301e-03,
#        2.44362857e-03, 2.44897420e-03, 2.45678531e-03, 2.45878935e-03,
#        2.46392738e-03, 2.47071073e-03, 2.48275070e-03, 2.52182615e-03,
#        2.54083342e-03, 2.56984067e-03, 2.58649314e-03, 2.58942101e-03,
#        2.60143076e-03, 2.60492163e-03, 2.61652238e-03, 2.61745462e-03,
#        2.66169710e-03, 2.66602205e-03, 2.66971551e-03, 2.70870299e-03,
#        2.78031906e-03, 2.78565424e-03, 2.81200948e-03, 2.81588841e-03,
#        2.82603089e-03, 2.83882901e-03, 2.86459368e-03, 2.89416993e-03,
#        2.92048423e-03, 2.95446032e-03, 2.95904728e-03, 2.96413657e-03,
#        2.96462984e-03, 2.97610391e-03, 2.97821468e-03, 3.00610689e-03,
#        3.03425335e-03, 3.07490358e-03, 3.11463282e-03, 3.13193928e-03,
#        3.13864459e-03, 3.18325113e-03, 3.19673345e-03, 3.22338817e-03,
#        3.25709810e-03, 3.25772383e-03, 3.25980414e-03, 3.26614234e-03,
#        3.27535418e-03, 3.27549372e-03, 3.28237555e-03, 3.29363619e-03,
#        3.29434958e-03, 3.30126420e-03, 3.33206209e-03, 3.35405018e-03,
#        3.38650842e-03, 3.40807856e-03, 3.41692148e-03, 3.43982377e-03,
#        3.45896197e-03, 3.48129480e-03, 3.48534529e-03, 3.49846654e-03,
#        3.50766523e-03, 3.51272049e-03, 3.51297790e-03, 3.51610665e-03,
#        3.52477506e-03, 3.55321367e-03, 3.57164213e-03, 3.58569169e-03,
#        3.58846155e-03, 3.58974733e-03, 3.59206414e-03, 3.59468534e-03,
#        3.59589528e-03, 3.59614979e-03, 3.60208054e-03, 3.60973972e-03,
#        3.62184381e-03, 3.63708312e-03, 3.64030503e-03, 3.64184150e-03,
#        3.64995304e-03, 3.65994201e-03, 3.66644864e-03, 3.68296411e-03,
#        3.69070477e-03, 3.69446749e-03, 3.70193593e-03, 3.70676725e-03,
#        3.72682031e-03, 3.73029558e-03, 3.73102880e-03, 3.77617612e-03,
#        3.86405662e-03, 3.88954369e-03, 3.89711452e-03, 3.90385110e-03,
#        3.91774372e-03, 3.94652075e-03, 3.94774777e-03, 3.96635000e-03,
#        3.97777103e-03, 3.97987420e-03, 3.99485444e-03, 4.01639123e-03,
#        4.01935985e-03, 4.01955559e-03, 4.02980012e-03, 4.03348944e-03,
#        4.04608219e-03, 4.09005903e-03, 4.09175763e-03, 4.10133519e-03,
#        4.10948320e-03, 4.12812910e-03, 4.12968647e-03, 4.15447285e-03,
#        4.16897121e-03, 4.19121259e-03, 4.19894958e-03, 4.22155215e-03,
#        4.23634656e-03, 4.28834895e-03, 4.29216001e-03, 4.33333013e-03,
#        4.37777131e-03, 4.38878116e-03, 4.42337160e-03, 4.43135003e-03,
#        4.43965180e-03, 4.44184098e-03, 4.44204105e-03, 4.47631599e-03,
#        4.48580778e-03, 4.49855455e-03, 4.52131248e-03, 4.53426823e-03,
#        4.55225191e-03, 4.57549635e-03, 4.59011487e-03, 4.60442309e-03,
#        4.60484409e-03, 4.60670298e-03, 4.61512192e-03, 4.62859368e-03,
#        4.63783900e-03, 4.64446554e-03, 4.64471228e-03, 4.65760624e-03,
#        4.66433748e-03, 4.68579299e-03, 4.70145835e-03, 4.73220985e-03,
#        4.73411000e-03, 4.73480384e-03, 4.75061338e-03, 4.75344269e-03,
#        4.75691773e-03, 4.75825188e-03, 4.77561483e-03, 4.79010471e-03,
#        4.81524340e-03, 4.83984305e-03, 4.88270568e-03, 4.88425799e-03,
#        4.91824600e-03, 4.92175596e-03, 4.93589263e-03, 4.95002253e-03,
#        4.98159162e-03, 5.00361623e-03, 5.01785664e-03, 5.02954898e-03,
#        5.04433783e-03, 5.10275518e-03, 5.10284434e-03, 5.11448260e-03,
#        5.11646581e-03, 5.12015852e-03, 5.13043144e-03, 5.13316622e-03,
#        5.15063775e-03, 5.18684142e-03, 5.20292873e-03, 5.21827577e-03,
#        5.26271922e-03, 5.28503842e-03, 5.29426218e-03, 5.31356014e-03,
#        5.31671123e-03, 5.32839411e-03, 5.33803642e-03, 5.34015825e-03,
#        5.37262430e-03, 5.39295896e-03, 5.41916936e-03, 5.43076220e-03,
#        5.45003892e-03, 5.45020617e-03, 5.45049230e-03, 5.45589763e-03,
#        5.46567011e-03, 5.49742217e-03, 5.50443071e-03, 5.50555414e-03,
#        5.52170140e-03, 5.52514491e-03, 5.53365758e-03, 5.54545551e-03,
#        5.58157079e-03, 5.59769832e-03, 5.63312559e-03, 5.66120807e-03,
#        5.66349202e-03, 5.69654566e-03, 5.76379748e-03, 5.79637824e-03,
#        5.81274904e-03, 5.82073675e-03, 5.82362946e-03, 5.84008277e-03,
#        5.85307342e-03, 5.85867804e-03, 5.94995092e-03, 6.00369820e-03,
#        6.01477283e-03, 6.01689551e-03, 6.04919660e-03, 6.05949744e-03,
#        6.06269773e-03, 6.11971910e-03, 6.12468742e-03, 6.14099249e-03,
#        6.15022933e-03, 6.15186872e-03, 6.16656462e-03, 6.16664375e-03,
#        6.18012551e-03, 6.22183777e-03, 6.23689439e-03, 6.28592140e-03,
#        6.28677676e-03, 6.31928572e-03, 6.32037969e-03, 6.32789954e-03,
#        6.34275857e-03, 6.34559075e-03, 6.37374378e-03, 6.37791808e-03,
#        6.37818540e-03, 6.38400185e-03, 6.38959105e-03, 6.38965628e-03,
#        6.41286986e-03, 6.43731285e-03, 6.44292009e-03, 6.49460957e-03,
#        6.50254704e-03, 6.51136449e-03, 6.51410523e-03, 6.51622225e-03,
#        6.53016296e-03, 6.54196259e-03, 6.54468370e-03, 6.55449693e-03,
#        6.55454587e-03, 6.60291684e-03, 6.60884435e-03, 6.61074665e-03,
#        6.62014077e-03, 6.62409773e-03, 6.72638032e-03, 6.75004325e-03,
#        6.75635681e-03, 6.82682020e-03, 6.84747456e-03, 6.84847976e-03,
#        6.85931157e-03, 6.86883966e-03, 6.87080450e-03, 6.87365272e-03,
#        6.87903895e-03, 6.94247999e-03, 6.94314763e-03, 6.95274263e-03,
#        6.95634846e-03, 6.98182281e-03, 6.99129030e-03, 7.00621597e-03,
#        7.01337782e-03, 7.04621997e-03, 7.05607254e-03, 7.05629486e-03,
#        7.05915347e-03, 7.06169679e-03, 7.09645012e-03, 7.11156634e-03,
#        7.12354017e-03, 7.13512036e-03, 7.17503454e-03, 7.19598024e-03,
#        7.20207677e-03, 7.20985306e-03, 7.22868817e-03, 7.26836899e-03,
#        7.29042363e-03, 7.29384788e-03, 7.34638100e-03, 7.36418417e-03,
#        7.37226067e-03, 7.40084737e-03, 7.43144056e-03, 7.43369175e-03,
#        7.46869954e-03, 7.47475262e-03, 7.49730274e-03, 7.50872516e-03,
#        7.52191775e-03, 7.52516099e-03, 7.52855084e-03, 7.53894435e-03,
#        7.55415418e-03, 7.57160259e-03, 7.60578215e-03, 7.63108984e-03,
#        7.67355371e-03, 7.69755026e-03, 7.69881298e-03, 7.70861720e-03,
#        7.71817251e-03, 7.72606524e-03, 7.73208718e-03, 7.74414186e-03,
#        7.75343432e-03, 7.77486052e-03, 7.79190654e-03, 7.89972640e-03,
#        7.93788850e-03, 7.94858998e-03, 7.95585283e-03, 7.95679287e-03,
#        7.98676100e-03, 7.99198506e-03, 8.05564608e-03, 8.07148980e-03,
#        8.08079308e-03, 8.09241332e-03, 8.11129805e-03, 8.15511191e-03,
#        8.19644645e-03, 8.20900575e-03, 8.21018829e-03, 8.23744323e-03,
#        8.28206157e-03, 8.31811053e-03, 8.33616948e-03, 8.40294426e-03,
#        8.40976191e-03, 8.45017987e-03, 8.50077567e-03, 8.53449914e-03,
#        8.57948446e-03, 8.59455904e-03, 8.59824263e-03, 8.63321236e-03,
#        8.66144494e-03, 8.66723319e-03, 8.68632155e-03, 8.69669236e-03,
#        8.71363200e-03, 8.74851420e-03, 8.75296352e-03, 8.75615922e-03,
#        8.76102807e-03, 8.77608714e-03, 8.84109290e-03, 8.91746796e-03,
#        8.93911598e-03, 8.94107046e-03, 8.95991915e-03, 8.96250000e-03,
#        8.96531361e-03, 8.96737841e-03, 9.05309119e-03, 9.07426380e-03,
#        9.09720470e-03, 9.10443075e-03, 9.16524113e-03, 9.17328779e-03,
#        9.20015450e-03, 9.21538600e-03, 9.22043580e-03, 9.23985363e-03,
#        9.24849084e-03, 9.32646595e-03, 9.36338105e-03, 9.38364759e-03,
#        9.40051446e-03, 9.41446530e-03, 9.44164049e-03, 9.45169699e-03,
#        9.47324065e-03, 9.47624917e-03, 9.47905398e-03, 9.51930221e-03,
#        9.57412294e-03, 9.62958783e-03, 9.63663906e-03, 9.64368985e-03,
#        9.65120669e-03, 9.65171790e-03, 9.66433310e-03, 9.69466692e-03,
#        9.70336949e-03, 9.75550146e-03, 9.77829581e-03, 9.82676349e-03,
#        9.83426899e-03, 9.97484315e-03, 9.97761562e-03, 9.98747635e-03,
#        1.00430128e-02, 1.00667494e-02, 1.01046890e-02, 1.01268311e-02,
#        1.01340445e-02, 1.02152821e-02, 1.02356843e-02, 1.02598117e-02,
#        1.02837365e-02, 1.03314582e-02, 1.03564044e-02, 1.04271610e-02,
#        1.04429419e-02, 1.04436364e-02, 1.04655408e-02, 1.04864191e-02,
#        1.05066901e-02, 1.05847831e-02, 1.06205888e-02, 1.06262803e-02,
#        1.07202207e-02, 1.07403143e-02, 1.07956265e-02, 1.09130201e-02,
#        1.09451753e-02, 1.10465925e-02, 1.10517243e-02, 1.10576538e-02,
#        1.10605030e-02, 1.10710399e-02, 1.10989929e-02, 1.11326461e-02,
#        1.11464360e-02, 1.11599132e-02, 1.11607110e-02, 1.12141432e-02,
#        1.12194376e-02, 1.12865837e-02, 1.12998852e-02, 1.13021735e-02,
#        1.13119563e-02, 1.13352914e-02, 1.13571153e-02, 1.13742094e-02,
#        1.13921001e-02, 1.14311411e-02, 1.14467980e-02, 1.14523831e-02,
#        1.14543774e-02, 1.14626932e-02, 1.15479030e-02, 1.15899640e-02,
#        1.16847513e-02, 1.17018066e-02, 1.17049901e-02, 1.18446741e-02,
#        1.18648419e-02, 1.18924989e-02, 1.19805491e-02, 1.19968389e-02,
#        1.20286023e-02, 1.20557346e-02, 1.20595131e-02, 1.20613889e-02,
#        1.21050111e-02, 1.21082813e-02, 1.21231391e-02, 1.21241502e-02,
#        1.22189222e-02, 1.22974305e-02, 1.23225586e-02, 1.23412811e-02,
#        1.23590238e-02, 1.23797056e-02, 1.23814573e-02, 1.24101690e-02,
#        1.24657326e-02, 1.25058031e-02, 1.25599367e-02, 1.25635437e-02,
#        1.26454236e-02, 1.26589519e-02, 1.27909741e-02, 1.29113662e-02,
#        1.29610628e-02, 1.30138926e-02, 1.30403355e-02, 1.30572146e-02,
#        1.30900285e-02, 1.32013755e-02, 1.33205024e-02, 1.33300998e-02,
#        1.33414708e-02, 1.33948060e-02, 1.34847980e-02, 1.35710377e-02,
#        1.36629311e-02, 1.39014582e-02, 1.39135992e-02, 1.39394938e-02,
#        1.39509078e-02, 1.40391164e-02, 1.41346110e-02, 1.41868358e-02,
#        1.42050381e-02, 1.42666882e-02, 1.42687651e-02, 1.42987812e-02,
#        1.43446275e-02, 1.44096531e-02, 1.44645125e-02, 1.44776102e-02,
#        1.46576666e-02, 1.46612803e-02, 1.46902402e-02, 1.48418997e-02,
#        1.50856867e-02, 1.51534474e-02, 1.52232500e-02, 1.52435465e-02,
#        1.53986766e-02, 1.55732592e-02, 1.56169751e-02, 1.56374334e-02,
#        1.57165712e-02, 1.58778001e-02, 1.58928891e-02, 1.59116278e-02,
#        1.59167132e-02, 1.59221793e-02, 1.60119752e-02, 1.62982895e-02,
#        1.63195914e-02, 1.65468521e-02, 1.66228752e-02, 1.66266693e-02,
#        1.66281199e-02, 1.67009948e-02, 1.67920558e-02, 1.67999950e-02,
#        1.68638547e-02, 1.69871813e-02, 1.70708013e-02, 1.74060436e-02,
#        1.74564102e-02, 1.74956145e-02, 1.76004379e-02, 1.83251635e-02,
#        1.83361036e-02, 1.84223792e-02, 1.84684318e-02, 1.86425420e-02,
#        1.86781436e-02, 1.87652366e-02, 1.88007399e-02, 1.92233044e-02,
#        1.92371406e-02, 1.92990801e-02, 1.94823286e-02, 1.95469595e-02,
#        1.98253444e-02, 1.99058911e-02, 1.99370353e-02, 2.01435450e-02,
#        2.04479692e-02, 2.05158302e-02, 2.09369464e-02, 2.09447142e-02,
#        2.10476293e-02, 2.10900523e-02, 2.16548073e-02, 2.17173632e-02,
#        2.18013633e-02, 2.19671568e-02, 2.21274292e-02, 2.21813742e-02,
#        2.24362406e-02, 2.24551627e-02, 2.27050564e-02, 2.28522427e-02,
#        2.29236894e-02, 2.29792515e-02, 2.30504706e-02, 2.33471396e-02,
#        2.36499844e-02, 2.36923562e-02, 2.37185569e-02, 2.40693445e-02,
#        2.42984256e-02, 2.43551126e-02, 2.46293420e-02, 2.47257078e-02,
#        2.50028665e-02, 2.55557248e-02, 2.57426423e-02, 2.58307028e-02,
#        2.62724937e-02, 2.63281212e-02, 2.73086794e-02, 2.77224757e-02,
#        2.78094557e-02, 2.82783491e-02, 2.83196674e-02, 2.85046281e-02,
#        2.86140675e-02, 2.88915027e-02, 2.96376741e-02, 2.97430695e-02,
#        3.01271036e-02, 3.02175724e-02, 3.02218279e-02, 3.10171144e-02,
#        3.15581760e-02, 3.19372708e-02, 3.21185596e-02, 3.25996026e-02,
#        3.26003636e-02, 3.26872067e-02, 3.27040470e-02, 3.38003514e-02,
#        3.45211626e-02, 3.48037888e-02, 3.55552176e-02, 3.57888747e-02,
#        3.57895896e-02, 3.57979980e-02, 3.67430249e-02, 3.70988483e-02,
#        3.85045683e-02, 4.01847220e-02, 4.07875044e-02, 4.11888852e-02,
#        4.23739793e-02, 4.32962517e-02, 4.68132752e-02, 4.75960793e-02,
#        5.08175575e-02, 5.19272539e-02, 5.22577224e-02, 5.97263270e-02,
#        6.25774880e-02, 6.90695607e-02, 6.95453213e-02, 7.94461502e-02,
#        8.05435786e-02, 8.40609643e-02, 8.45223884e-02, 8.92770120e-02,
#        9.08433462e-02, 9.27051467e-02, 9.54875380e-02, 1.11235712e-01,
#        1.22471774e-01, 1.26484613e-01, 1.26490306e-01, 1.30641222e-01,
#        1.38732777e-01, 1.41938999e-01, 1.44844010e-01, 1.50445443e-01,
#        2.22309242e-01, 2.51981230e-01, 4.13376600e-01, 4.88506734e-01,
#        5.27197146e-01, 5.56245434e-01, 6.59574240e-01, 7.86421772e-01,
#        8.74951862e-01, 9.73092167e-01, 9.77737358e-01, 9.92728141e-01,
#        9.98518898e-01, 9.99487752e-01, 9.99558353e-01, 9.99999837e-01,
#        9.99999958e-01, 9.99999971e-01])

# %%
from sklearn.preprocessing import Binarizer
def get_evaluation_by_thresholds(y_test, prediction_proba_class1, thresholds):
    
    for threshold in thresholds:
        binarizer = Binarizer(threshold=threshold).fit(prediction_proba_class1) 
        custom_prediction = binarizer.transform(prediction_proba_class1)
        print('임곗값:', threshold)
        get_evaluation(y_test, custom_prediction)

# %%
get_evaluation_by_thresholds(y_test, g_log_reg.predict_proba(X_test)[:, 1].reshape(-1, 1), thresholds)
# Out:
# 임곗값: 0.0005836403318812993
# 오차 행렬
# [[  1 729]
#  [  0  20]]
# 정확도: 0.0280, 정밀도: 0.0267, 재현율: 1.0000, F1:0.0520, AUC:0.5007
# ###########################################################################
# 임곗값: 0.0009644659670294332
# 오차 행렬
# [[  2 728]
#  [  0  20]]
# 정확도: 0.0293, 정밀도: 0.0267, 재현율: 1.0000, F1:0.0521, AUC:0.5014
# ###########################################################################
# 임곗값: 0.0009863584188361453
# 오차 행렬
# [[  3 727]
#  [  0  20]]
# 정확도: 0.0307, 정밀도: 0.0268, 재현율: 1.0000, F1:0.0522, AUC:0.5021
# ###########################################################################
# 임곗값: 0.0012673068073453103
# 오차 행렬
# [[  4 726]
#  [  0  20]]
# 정확도: 0.0320, 정밀도: 0.0268, 재현율: 1.0000, F1:0.0522, AUC:0.5027
# ###########################################################################
# 임곗값: 0.0012971681858054205
# 오차 행렬
# [[  5 725]
#  [  0  20]]
# 정확도: 0.0333, 정밀도: 0.0268, 재현율: 1.0000, F1:0.0523, AUC:0.5034
# ###########################################################################
# 임곗값: 0.0013860117481423052
# 오차 행렬
# [[  6 724]
#  [  0  20]]
# 정확도: 0.0347, 정밀도: 0.0269, 재현율: 1.0000, F1:0.0524, AUC:0.5041
# ###########################################################################
# 임곗값: 0.00145083992483276
# 오차 행렬
# [[  7 723]
#  [  0  20]]
# 정확도: 0.0360, 정밀도: 0.0269, 재현율: 1.0000, F1:0.0524, AUC:0.5048
# ###########################################################################
# 임곗값: 0.0014524140280042033
# 오차 행렬
# [[  8 722]
#  [  0  20]]
# 정확도: 0.0373, 정밀도: 0.0270, 재현율: 1.0000, F1:0.0525, AUC:0.5055
# ###########################################################################
# 임곗값: 0.0015453018675874897
# 오차 행렬
# [[  9 721]
#  [  0  20]]
# 정확도: 0.0387, 정밀도: 0.0270, 재현율: 1.0000, F1:0.0526, AUC:0.5062
# ###########################################################################
# 임곗값: 0.0016696995008905304
# 오차 행렬
# [[ 10 720]
#  [  0  20]]
# 정확도: 0.0400, 정밀도: 0.0270, 재현율: 1.0000, F1:0.0526, AUC:0.5068
# ###########################################################################
# 임곗값: 0.0016793278441199467
# 오차 행렬
# [[ 11 719]
#  [  0  20]]
# 정확도: 0.0413, 정밀도: 0.0271, 재현율: 1.0000, F1:0.0527, AUC:0.5075
# ###########################################################################
# 임곗값: 0.0017064898018157324
# 오차 행렬
# [[ 12 718]
#  [  0  20]]
# 정확도: 0.0427, 정밀도: 0.0271, 재현율: 1.0000, F1:0.0528, AUC:0.5082
# ###########################################################################
# 임곗값: 0.0017493091809806481
# 오차 행렬
# [[ 13 717]
#  [  0  20]]
# 정확도: 0.0440, 정밀도: 0.0271, 재현율: 1.0000, F1:0.0528, AUC:0.5089
# ###########################################################################
# 임곗값: 0.0017863465066884218
# 오차 행렬
# [[ 14 716]
#  [  0  20]]
# 정확도: 0.0453, 정밀도: 0.0272, 재현율: 1.0000, F1:0.0529, AUC:0.5096
# ###########################################################################
# 임곗값: 0.0018065649122351074
# 오차 행렬
# [[ 15 715]
#  [  0  20]]
# 정확도: 0.0467, 정밀도: 0.0272, 재현율: 1.0000, F1:0.0530, AUC:0.5103
# ###########################################################################
# 임곗값: 0.001830695499883802
# 오차 행렬
# [[ 16 714]
#  [  0  20]]
# 정확도: 0.0480, 정밀도: 0.0272, 재현율: 1.0000, F1:0.0531, AUC:0.5110
# ###########################################################################
# 임곗값: 0.0019268078536706045
# 오차 행렬
# [[ 17 713]
#  [  0  20]]
# 정확도: 0.0493, 정밀도: 0.0273, 재현율: 1.0000, F1:0.0531, AUC:0.5116
# ###########################################################################
# 임곗값: 0.0019342729523801946
# 오차 행렬
# [[ 18 712]
#  [  0  20]]
# 정확도: 0.0507, 정밀도: 0.0273, 재현율: 1.0000, F1:0.0532, AUC:0.5123
# ###########################################################################
# 임곗값: 0.0019572757190806805
# 오차 행렬
# [[ 19 711]
#  [  0  20]]
# 정확도: 0.0520, 정밀도: 0.0274, 재현율: 1.0000, F1:0.0533, AUC:0.5130
# ###########################################################################
# 임곗값: 0.0019606557586102926
# 오차 행렬
# [[ 20 710]
#  [  0  20]]
# 정확도: 0.0533, 정밀도: 0.0274, 재현율: 1.0000, F1:0.0533, AUC:0.5137
# ###########################################################################
# 임곗값: 0.0019781667459762707
# 오차 행렬
# [[ 21 709]
#  [  0  20]]
# 정확도: 0.0547, 정밀도: 0.0274, 재현율: 1.0000, F1:0.0534, AUC:0.5144
# ###########################################################################
# 임곗값: 0.002012029975664402
# 오차 행렬
# [[ 22 708]
#  [  0  20]]
# 정확도: 0.0560, 정밀도: 0.0275, 재현율: 1.0000, F1:0.0535, AUC:0.5151
# ###########################################################################
# 임곗값: 0.0020349403141048153
# 오차 행렬
# [[ 23 707]
#  [  0  20]]
# 정확도: 0.0573, 정밀도: 0.0275, 재현율: 1.0000, F1:0.0535, AUC:0.5158
# ###########################################################################
# 임곗값: 0.002043310525483055
# 오차 행렬
# [[ 24 706]
#  [  0  20]]
# 정확도: 0.0587, 정밀도: 0.0275, 재현율: 1.0000, F1:0.0536, AUC:0.5164
# ###########################################################################
# 임곗값: 0.002044122035393442
# 오차 행렬
# [[ 25 705]
#  [  0  20]]
# 정확도: 0.0600, 정밀도: 0.0276, 재현율: 1.0000, F1:0.0537, AUC:0.5171
# ###########################################################################
# 임곗값: 0.0020641626541848383
# 오차 행렬
# [[ 26 704]
#  [  0  20]]
# 정확도: 0.0613, 정밀도: 0.0276, 재현율: 1.0000, F1:0.0538, AUC:0.5178
# ###########################################################################
# 임곗값: 0.0020666009529839973
# 오차 행렬
# [[ 27 703]
#  [  0  20]]
# 정확도: 0.0627, 정밀도: 0.0277, 재현율: 1.0000, F1:0.0538, AUC:0.5185
# ###########################################################################
# 임곗값: 0.002082293519678689
# 오차 행렬
# [[ 28 702]
#  [  0  20]]
# 정확도: 0.0640, 정밀도: 0.0277, 재현율: 1.0000, F1:0.0539, AUC:0.5192
# ###########################################################################
# 임곗값: 0.0021105477256524643
# 오차 행렬
# [[ 29 701]
#  [  0  20]]
# 정확도: 0.0653, 정밀도: 0.0277, 재현율: 1.0000, F1:0.0540, AUC:0.5199
# ###########################################################################
# 임곗값: 0.0021419385291392133
# 오차 행렬
# [[ 30 700]
#  [  0  20]]
# 정확도: 0.0667, 정밀도: 0.0278, 재현율: 1.0000, F1:0.0541, AUC:0.5205
# ###########################################################################
# 임곗값: 0.0021856808945507743
# 오차 행렬
# [[ 31 699]
#  [  0  20]]
# 정확도: 0.0680, 정밀도: 0.0278, 재현율: 1.0000, F1:0.0541, AUC:0.5212
# ###########################################################################
# 임곗값: 0.0021864324913428565
# 오차 행렬
# [[ 32 698]
#  [  0  20]]
# 정확도: 0.0693, 정밀도: 0.0279, 재현율: 1.0000, F1:0.0542, AUC:0.5219
# ###########################################################################
# 임곗값: 0.0021948412500208208
# 오차 행렬
# [[ 33 697]
#  [  0  20]]
# 정확도: 0.0707, 정밀도: 0.0279, 재현율: 1.0000, F1:0.0543, AUC:0.5226
# ###########################################################################
# 임곗값: 0.002216752020855559
# 오차 행렬
# [[ 34 696]
#  [  0  20]]
# 정확도: 0.0720, 정밀도: 0.0279, 재현율: 1.0000, F1:0.0543, AUC:0.5233
# ###########################################################################
# 임곗값: 0.0022573305250618
# 오차 행렬
# [[ 35 695]
#  [  0  20]]
# 정확도: 0.0733, 정밀도: 0.0280, 재현율: 1.0000, F1:0.0544, AUC:0.5240
# ###########################################################################
# 임곗값: 0.0022686894481170447
# 오차 행렬
# [[ 36 694]
#  [  0  20]]
# 정확도: 0.0747, 정밀도: 0.0280, 재현율: 1.0000, F1:0.0545, AUC:0.5247
# ###########################################################################
# 임곗값: 0.0022885602105475176
# 오차 행렬
# [[ 37 693]
#  [  0  20]]
# 정확도: 0.0760, 정밀도: 0.0281, 재현율: 1.0000, F1:0.0546, AUC:0.5253
# ###########################################################################
# 임곗값: 0.0023029196800408
# 오차 행렬
# [[ 38 692]
#  [  0  20]]
# 정확도: 0.0773, 정밀도: 0.0281, 재현율: 1.0000, F1:0.0546, AUC:0.5260
# ###########################################################################
# 임곗값: 0.0023094567399028786
# 오차 행렬
# [[ 39 691]
#  [  0  20]]
# 정확도: 0.0787, 정밀도: 0.0281, 재현율: 1.0000, F1:0.0547, AUC:0.5267
# ###########################################################################
# 임곗값: 0.0023123400947518543
# 오차 행렬
# [[ 40 690]
#  [  0  20]]
# 정확도: 0.0800, 정밀도: 0.0282, 재현율: 1.0000, F1:0.0548, AUC:0.5274
# ###########################################################################
# 임곗값: 0.0023149813949849937
# 오차 행렬
# [[ 41 689]
#  [  0  20]]
# 정확도: 0.0813, 정밀도: 0.0282, 재현율: 1.0000, F1:0.0549, AUC:0.5281
# ###########################################################################
# 임곗값: 0.0023185245973375078
# 오차 행렬
# [[ 42 688]
#  [  0  20]]
# 정확도: 0.0827, 정밀도: 0.0282, 재현율: 1.0000, F1:0.0549, AUC:0.5288
# ###########################################################################
# 임곗값: 0.00232906868370658
# 오차 행렬
# [[ 43 687]
#  [  0  20]]
# 정확도: 0.0840, 정밀도: 0.0283, 재현율: 1.0000, F1:0.0550, AUC:0.5295
# ###########################################################################
# 임곗값: 0.0023324854998181513
# 오차 행렬
# [[ 44 686]
#  [  0  20]]
# 정확도: 0.0853, 정밀도: 0.0283, 재현율: 1.0000, F1:0.0551, AUC:0.5301
# ###########################################################################
# 임곗값: 0.0023414080311037933
# 오차 행렬
# [[ 45 685]
#  [  0  20]]
# 정확도: 0.0867, 정밀도: 0.0284, 재현율: 1.0000, F1:0.0552, AUC:0.5308
# ###########################################################################
# 임곗값: 0.0023886222621083046
# 오차 행렬
# [[ 46 684]
#  [  0  20]]
# 정확도: 0.0880, 정밀도: 0.0284, 재현율: 1.0000, F1:0.0552, AUC:0.5315
# ###########################################################################
# 임곗값: 0.002393831423168417
# 오차 행렬
# [[ 47 683]
#  [  0  20]]
# 정확도: 0.0893, 정밀도: 0.0284, 재현율: 1.0000, F1:0.0553, AUC:0.5322
# ###########################################################################
# 임곗값: 0.002439193009513257
# 오차 행렬
# [[ 48 682]
#  [  0  20]]
# 정확도: 0.0907, 정밀도: 0.0285, 재현율: 1.0000, F1:0.0554, AUC:0.5329
# ###########################################################################
# 임곗값: 0.002443628565165394
# 오차 행렬
# [[ 49 681]
#  [  0  20]]
# 정확도: 0.0920, 정밀도: 0.0285, 재현율: 1.0000, F1:0.0555, AUC:0.5336
# ###########################################################################
# 임곗값: 0.002448974204982615
# 오차 행렬
# [[ 50 680]
#  [  0  20]]
# 정확도: 0.0933, 정밀도: 0.0286, 재현율: 1.0000, F1:0.0556, AUC:0.5342
# ###########################################################################
# 임곗값: 0.002456785310577741
# 오차 행렬
# [[ 51 679]
#  [  0  20]]
# 정확도: 0.0947, 정밀도: 0.0286, 재현율: 1.0000, F1:0.0556, AUC:0.5349
# ###########################################################################
# 임곗값: 0.002458789346217265
# 오차 행렬
# [[ 52 678]
#  [  0  20]]
# 정확도: 0.0960, 정밀도: 0.0287, 재현율: 1.0000, F1:0.0557, AUC:0.5356
# ###########################################################################
# 임곗값: 0.0024639273814436083
# 오차 행렬
# [[ 53 677]
#  [  0  20]]
# 정확도: 0.0973, 정밀도: 0.0287, 재현율: 1.0000, F1:0.0558, AUC:0.5363
# ###########################################################################
# 임곗값: 0.0024707107262524662
# 오차 행렬
# [[ 54 676]
#  [  0  20]]
# 정확도: 0.0987, 정밀도: 0.0287, 재현율: 1.0000, F1:0.0559, AUC:0.5370
# ###########################################################################
# 임곗값: 0.0024827506987417495
# 오차 행렬
# [[ 55 675]
#  [  0  20]]
# 정확도: 0.1000, 정밀도: 0.0288, 재현율: 1.0000, F1:0.0559, AUC:0.5377
# ###########################################################################
# 임곗값: 0.0025218261510016595
# 오차 행렬
# [[ 56 674]
#  [  0  20]]
# 정확도: 0.1013, 정밀도: 0.0288, 재현율: 1.0000, F1:0.0560, AUC:0.5384
# ###########################################################################
# 임곗값: 0.0025408334170746332
# 오차 행렬
# [[ 57 673]
#  [  0  20]]
# 정확도: 0.1027, 정밀도: 0.0289, 재현율: 1.0000, F1:0.0561, AUC:0.5390
# ###########################################################################
# 임곗값: 0.0025698406655616543
# 오차 행렬
# [[ 58 672]
#  [  0  20]]
# 정확도: 0.1040, 정밀도: 0.0289, 재현율: 1.0000, F1:0.0562, AUC:0.5397
# ###########################################################################
# 임곗값: 0.002586493144473618
# 오차 행렬
# [[ 59 671]
#  [  0  20]]
# 정확도: 0.1053, 정밀도: 0.0289, 재현율: 1.0000, F1:0.0563, AUC:0.5404
# ###########################################################################
# 임곗값: 0.0025894210096461907
# 오차 행렬
# [[ 60 670]
#  [  0  20]]
# 정확도: 0.1067, 정밀도: 0.0290, 재현율: 1.0000, F1:0.0563, AUC:0.5411
# ###########################################################################
# 임곗값: 0.0026014307591868094
# 오차 행렬
# [[ 61 669]
#  [  0  20]]
# 정확도: 0.1080, 정밀도: 0.0290, 재현율: 1.0000, F1:0.0564, AUC:0.5418
# ###########################################################################
# 임곗값: 0.0026049216251627966
# 오차 행렬
# [[ 62 668]
#  [  0  20]]
# 정확도: 0.1093, 정밀도: 0.0291, 재현율: 1.0000, F1:0.0565, AUC:0.5425
# ###########################################################################
# 임곗값: 0.0026165223785580604
# 오차 행렬
# [[ 63 667]
#  [  0  20]]
# 정확도: 0.1107, 정밀도: 0.0291, 재현율: 1.0000, F1:0.0566, AUC:0.5432
# ###########################################################################
# 임곗값: 0.002617454620719929
# 오차 행렬
# [[ 64 666]
#  [  0  20]]
# 정확도: 0.1120, 정밀도: 0.0292, 재현율: 1.0000, F1:0.0567, AUC:0.5438
# ###########################################################################
# 임곗값: 0.0026616970968783103
# 오차 행렬
# [[ 65 665]
#  [  0  20]]
# 정확도: 0.1133, 정밀도: 0.0292, 재현율: 1.0000, F1:0.0567, AUC:0.5445
# ###########################################################################
# 임곗값: 0.0026660220536546798
# 오차 행렬
# [[ 66 664]
#  [  0  20]]
# 정확도: 0.1147, 정밀도: 0.0292, 재현율: 1.0000, F1:0.0568, AUC:0.5452
# ###########################################################################
# 임곗값: 0.0026697155145744256
# 오차 행렬
# [[ 67 663]
#  [  0  20]]
# 정확도: 0.1160, 정밀도: 0.0293, 재현율: 1.0000, F1:0.0569, AUC:0.5459
# ###########################################################################
# 임곗값: 0.0027087029862468514
# 오차 행렬
# [[ 68 662]
#  [  0  20]]
# 정확도: 0.1173, 정밀도: 0.0293, 재현율: 1.0000, F1:0.0570, AUC:0.5466
# ###########################################################################
# 임곗값: 0.0027803190611290604
# 오차 행렬
# [[ 69 661]
#  [  0  20]]
# 정확도: 0.1187, 정밀도: 0.0294, 재현율: 1.0000, F1:0.0571, AUC:0.5473
# ###########################################################################
# 임곗값: 0.0027856542413774096
# 오차 행렬
# [[ 70 660]
#  [  0  20]]
# 정확도: 0.1200, 정밀도: 0.0294, 재현율: 1.0000, F1:0.0571, AUC:0.5479
# ###########################################################################
# 임곗값: 0.0028120094830724795
# 오차 행렬
# [[ 71 659]
#  [  0  20]]
# 정확도: 0.1213, 정밀도: 0.0295, 재현율: 1.0000, F1:0.0572, AUC:0.5486
# ###########################################################################
# 임곗값: 0.002815888412635804
# 오차 행렬
# [[ 72 658]
#  [  0  20]]
# 정확도: 0.1227, 정밀도: 0.0295, 재현율: 1.0000, F1:0.0573, AUC:0.5493
# ###########################################################################
# 임곗값: 0.0028260308865865015
# 오차 행렬
# [[ 73 657]
#  [  0  20]]
# 정확도: 0.1240, 정밀도: 0.0295, 재현율: 1.0000, F1:0.0574, AUC:0.5500
# ###########################################################################
# 임곗값: 0.0028388290123000795
# 오차 행렬
# [[ 74 656]
#  [  0  20]]
# 정확도: 0.1253, 정밀도: 0.0296, 재현율: 1.0000, F1:0.0575, AUC:0.5507
# ###########################################################################
# 임곗값: 0.002864593679517834
# 오차 행렬
# [[ 75 655]
#  [  0  20]]
# 정확도: 0.1267, 정밀도: 0.0296, 재현율: 1.0000, F1:0.0576, AUC:0.5514
# ###########################################################################
# 임곗값: 0.002894169929638058
# 오차 행렬
# [[ 76 654]
#  [  0  20]]
# 정확도: 0.1280, 정밀도: 0.0297, 재현율: 1.0000, F1:0.0576, AUC:0.5521
# ###########################################################################
# 임곗값: 0.0029204842259154752
# 오차 행렬
# [[ 77 653]
#  [  0  20]]
# 정확도: 0.1293, 정밀도: 0.0297, 재현율: 1.0000, F1:0.0577, AUC:0.5527
# ###########################################################################
# 임곗값: 0.002954460315469349
# 오차 행렬
# [[ 78 652]
#  [  0  20]]
# 정확도: 0.1307, 정밀도: 0.0298, 재현율: 1.0000, F1:0.0578, AUC:0.5534
# ###########################################################################
# 임곗값: 0.0029590472848668218
# 오차 행렬
# [[ 79 651]
#  [  0  20]]
# 정확도: 0.1320, 정밀도: 0.0298, 재현율: 1.0000, F1:0.0579, AUC:0.5541
# ###########################################################################
# 임곗값: 0.002964136566079706
# 오차 행렬
# [[ 80 650]
#  [  0  20]]
# 정확도: 0.1333, 정밀도: 0.0299, 재현율: 1.0000, F1:0.0580, AUC:0.5548
# ###########################################################################
# 임곗값: 0.0029646298387292504
# 오차 행렬
# [[ 81 649]
#  [  0  20]]
# 정확도: 0.1347, 정밀도: 0.0299, 재현율: 1.0000, F1:0.0581, AUC:0.5555
# ###########################################################################
# 임곗값: 0.0029761039144655
# 오차 행렬
# [[ 82 648]
#  [  0  20]]
# 정확도: 0.1360, 정밀도: 0.0299, 재현율: 1.0000, F1:0.0581, AUC:0.5562
# ###########################################################################
# 임곗값: 0.0029782146761334243
# 오차 행렬
# [[ 83 647]
#  [  0  20]]
# 정확도: 0.1373, 정밀도: 0.0300, 재현율: 1.0000, F1:0.0582, AUC:0.5568
# ###########################################################################
# 임곗값: 0.0030061068936312664
# 오차 행렬
# [[ 84 646]
#  [  0  20]]
# 정확도: 0.1387, 정밀도: 0.0300, 재현율: 1.0000, F1:0.0583, AUC:0.5575
# ###########################################################################
# 임곗값: 0.0030342533467443674
# 오차 행렬
# [[ 85 645]
#  [  0  20]]
# 정확도: 0.1400, 정밀도: 0.0301, 재현율: 1.0000, F1:0.0584, AUC:0.5582
# ###########################################################################
# 임곗값: 0.0030749035844012665
# 오차 행렬
# [[ 86 644]
#  [  0  20]]
# 정확도: 0.1413, 정밀도: 0.0301, 재현율: 1.0000, F1:0.0585, AUC:0.5589
# ###########################################################################
# 임곗값: 0.0031146328172557466
# 오차 행렬
# [[ 87 643]
#  [  0  20]]
# 정확도: 0.1427, 정밀도: 0.0302, 재현율: 1.0000, F1:0.0586, AUC:0.5596
# ###########################################################################
# 임곗값: 0.0031319392815337445
# 오차 행렬
# [[ 88 642]
#  [  0  20]]
# 정확도: 0.1440, 정밀도: 0.0302, 재현율: 1.0000, F1:0.0587, AUC:0.5603
# ###########################################################################
# 임곗값: 0.0031386445876905433
# 오차 행렬
# [[ 89 641]
#  [  0  20]]
# 정확도: 0.1453, 정밀도: 0.0303, 재현율: 1.0000, F1:0.0587, AUC:0.5610
# ###########################################################################
# 임곗값: 0.00318325112622768
# 오차 행렬
# [[ 90 640]
#  [  0  20]]
# 정확도: 0.1467, 정밀도: 0.0303, 재현율: 1.0000, F1:0.0588, AUC:0.5616
# ###########################################################################
# 임곗값: 0.0031967334479997196
# 오차 행렬
# [[ 91 639]
#  [  0  20]]
# 정확도: 0.1480, 정밀도: 0.0303, 재현율: 1.0000, F1:0.0589, AUC:0.5623
# ###########################################################################
# 임곗값: 0.0032233881652099067
# 오차 행렬
# [[ 92 638]
#  [  0  20]]
# 정확도: 0.1493, 정밀도: 0.0304, 재현율: 1.0000, F1:0.0590, AUC:0.5630
# ###########################################################################
# 임곗값: 0.0032570980983963427
# 오차 행렬
# [[ 93 637]
#  [  0  20]]
# 정확도: 0.1507, 정밀도: 0.0304, 재현율: 1.0000, F1:0.0591, AUC:0.5637
# ###########################################################################
# 임곗값: 0.0032577238261237646
# 오차 행렬
# [[ 94 636]
#  [  0  20]]
# 정확도: 0.1520, 정밀도: 0.0305, 재현율: 1.0000, F1:0.0592, AUC:0.5644
# ###########################################################################
# 임곗값: 0.003259804141893701
# 오차 행렬
# [[ 95 635]
#  [  0  20]]
# 정확도: 0.1533, 정밀도: 0.0305, 재현율: 1.0000, F1:0.0593, AUC:0.5651
# ###########################################################################
# 임곗값: 0.0032661423428314807
# 오차 행렬
# [[ 96 634]
#  [  0  20]]
# 정확도: 0.1547, 정밀도: 0.0306, 재현율: 1.0000, F1:0.0593, AUC:0.5658
# ###########################################################################
# 임곗값: 0.0032753541827250966
# 오차 행렬
# [[ 97 633]
#  [  0  20]]
# 정확도: 0.1560, 정밀도: 0.0306, 재현율: 1.0000, F1:0.0594, AUC:0.5664
# ###########################################################################
# 임곗값: 0.0032754937165221784
# 오차 행렬
# [[ 98 632]
#  [  0  20]]
# 정확도: 0.1573, 정밀도: 0.0307, 재현율: 1.0000, F1:0.0595, AUC:0.5671
# ###########################################################################
# 임곗값: 0.0032823755546262275
# 오차 행렬
# [[ 99 631]
#  [  0  20]]
# 정확도: 0.1587, 정밀도: 0.0307, 재현율: 1.0000, F1:0.0596, AUC:0.5678
# ###########################################################################
# 임곗값: 0.0032936361938606107
# 오차 행렬
# [[100 630]
#  [  0  20]]
# 정확도: 0.1600, 정밀도: 0.0308, 재현율: 1.0000, F1:0.0597, AUC:0.5685
# ###########################################################################
# 임곗값: 0.0032943495810238916
# 오차 행렬
# [[101 629]
#  [  0  20]]
# 정확도: 0.1613, 정밀도: 0.0308, 재현율: 1.0000, F1:0.0598, AUC:0.5692
# ###########################################################################
# 임곗값: 0.003301264195755317
# 오차 행렬
# [[102 628]
#  [  0  20]]
# 정확도: 0.1627, 정밀도: 0.0309, 재현율: 1.0000, F1:0.0599, AUC:0.5699
# ###########################################################################
# 임곗값: 0.003332062087475548
# 오차 행렬
# [[103 627]
#  [  0  20]]
# 정확도: 0.1640, 정밀도: 0.0309, 재현율: 1.0000, F1:0.0600, AUC:0.5705
# ###########################################################################
# 임곗값: 0.003354050176941836
# 오차 행렬
# [[104 626]
#  [  0  20]]
# 정확도: 0.1653, 정밀도: 0.0310, 재현율: 1.0000, F1:0.0601, AUC:0.5712
# ###########################################################################
# 임곗값: 0.0033865084233421134
# 오차 행렬
# [[105 625]
#  [  0  20]]
# 정확도: 0.1667, 정밀도: 0.0310, 재현율: 1.0000, F1:0.0602, AUC:0.5719
# ###########################################################################
# 임곗값: 0.003408078556733683
# 오차 행렬
# [[106 624]
#  [  0  20]]
# 정확도: 0.1680, 정밀도: 0.0311, 재현율: 1.0000, F1:0.0602, AUC:0.5726
# ###########################################################################
# 임곗값: 0.003416921479695708
# 오차 행렬
# [[107 623]
#  [  0  20]]
# 정확도: 0.1693, 정밀도: 0.0311, 재현율: 1.0000, F1:0.0603, AUC:0.5733
# ###########################################################################
# 임곗값: 0.0034398237651908324
# 오차 행렬
# [[108 622]
#  [  0  20]]
# 정확도: 0.1707, 정밀도: 0.0312, 재현율: 1.0000, F1:0.0604, AUC:0.5740
# ###########################################################################
# 임곗값: 0.0034589619749655206
# 오차 행렬
# [[109 621]
#  [  0  20]]
# 정확도: 0.1720, 정밀도: 0.0312, 재현율: 1.0000, F1:0.0605, AUC:0.5747
# ###########################################################################
# 임곗값: 0.0034812948024606277
# 오차 행렬
# [[110 620]
#  [  0  20]]
# 정확도: 0.1733, 정밀도: 0.0312, 재현율: 1.0000, F1:0.0606, AUC:0.5753
# ###########################################################################
# 임곗값: 0.003485345285715606
# 오차 행렬
# [[111 619]
#  [  0  20]]
# 정확도: 0.1747, 정밀도: 0.0313, 재현율: 1.0000, F1:0.0607, AUC:0.5760
# ###########################################################################
# 임곗값: 0.003498466540039775
# 오차 행렬
# [[112 618]
#  [  0  20]]
# 정확도: 0.1760, 정밀도: 0.0313, 재현율: 1.0000, F1:0.0608, AUC:0.5767
# ###########################################################################
# 임곗값: 0.003507665225470541
# 오차 행렬
# [[113 617]
#  [  0  20]]
# 정확도: 0.1773, 정밀도: 0.0314, 재현율: 1.0000, F1:0.0609, AUC:0.5774
# ###########################################################################
# 임곗값: 0.0035127204859537902
# 오차 행렬
# [[114 616]
#  [  0  20]]
# 정확도: 0.1787, 정밀도: 0.0314, 재현율: 1.0000, F1:0.0610, AUC:0.5781
# ###########################################################################
# 임곗값: 0.0035129779038857983
# 오차 행렬
# [[115 615]
#  [  0  20]]
# 정확도: 0.1800, 정밀도: 0.0315, 재현율: 1.0000, F1:0.0611, AUC:0.5788
# ###########################################################################
# 임곗값: 0.0035161066488952203
# 오차 행렬
# [[116 614]
#  [  0  20]]
# 정확도: 0.1813, 정밀도: 0.0315, 재현율: 1.0000, F1:0.0612, AUC:0.5795
# ###########################################################################
# 임곗값: 0.0035247750559932326
# 오차 행렬
# [[117 613]
#  [  0  20]]
# 정확도: 0.1827, 정밀도: 0.0316, 재현율: 1.0000, F1:0.0613, AUC:0.5801
# ###########################################################################
# 임곗값: 0.0035532136715399187
# 오차 행렬
# [[118 612]
#  [  0  20]]
# 정확도: 0.1840, 정밀도: 0.0316, 재현율: 1.0000, F1:0.0613, AUC:0.5808
# ###########################################################################
# 임곗값: 0.0035716421253748267
# 오차 행렬
# [[119 611]
#  [  0  20]]
# 정확도: 0.1853, 정밀도: 0.0317, 재현율: 1.0000, F1:0.0614, AUC:0.5815
# ###########################################################################
# 임곗값: 0.003585691686048055
# 오차 행렬
# [[120 610]
#  [  0  20]]
# 정확도: 0.1867, 정밀도: 0.0317, 재현율: 1.0000, F1:0.0615, AUC:0.5822
# ###########################################################################
# 임곗값: 0.0035884615476234473
# 오차 행렬
# [[121 609]
#  [  0  20]]
# 정확도: 0.1880, 정밀도: 0.0318, 재현율: 1.0000, F1:0.0616, AUC:0.5829
# ###########################################################################
# 임곗값: 0.003589747326529567
# 오차 행렬
# [[122 608]
#  [  0  20]]
# 정확도: 0.1893, 정밀도: 0.0318, 재현율: 1.0000, F1:0.0617, AUC:0.5836
# ###########################################################################
# 임곗값: 0.003592064140296371
# 오차 행렬
# [[123 607]
#  [  0  20]]
# 정확도: 0.1907, 정밀도: 0.0319, 재현율: 1.0000, F1:0.0618, AUC:0.5842
# ###########################################################################
# 임곗값: 0.0035946853401462196
# 오차 행렬
# [[124 606]
#  [  0  20]]
# 정확도: 0.1920, 정밀도: 0.0319, 재현율: 1.0000, F1:0.0619, AUC:0.5849
# ###########################################################################
# 임곗값: 0.0035958952808163446
# 오차 행렬
# [[125 605]
#  [  0  20]]
# 정확도: 0.1933, 정밀도: 0.0320, 재현율: 1.0000, F1:0.0620, AUC:0.5856
# ###########################################################################
# 임곗값: 0.0035961497902610353
# 오차 행렬
# [[126 604]
#  [  0  20]]
# 정확도: 0.1947, 정밀도: 0.0321, 재현율: 1.0000, F1:0.0621, AUC:0.5863
# ###########################################################################
# 임곗값: 0.003602080543632824
# 오차 행렬
# [[127 603]
#  [  0  20]]
# 정확도: 0.1960, 정밀도: 0.0321, 재현율: 1.0000, F1:0.0622, AUC:0.5870
# ###########################################################################
# 임곗값: 0.0036097397244228458
# 오차 행렬
# [[128 602]
#  [  0  20]]
# 정확도: 0.1973, 정밀도: 0.0322, 재현율: 1.0000, F1:0.0623, AUC:0.5877
# ###########################################################################
# 임곗값: 0.0036218438142311907
# 오차 행렬
# [[129 601]
#  [  0  20]]
# 정확도: 0.1987, 정밀도: 0.0322, 재현율: 1.0000, F1:0.0624, AUC:0.5884
# ###########################################################################
# 임곗값: 0.003637083124742177
# 오차 행렬
# [[130 600]
#  [  0  20]]
# 정확도: 0.2000, 정밀도: 0.0323, 재현율: 1.0000, F1:0.0625, AUC:0.5890
# ###########################################################################
# 임곗값: 0.0036403050328950967
# 오차 행렬
# [[131 599]
#  [  0  20]]
# 정확도: 0.2013, 정밀도: 0.0323, 재현율: 1.0000, F1:0.0626, AUC:0.5897
# ###########################################################################
# 임곗값: 0.0036418415040623854
# 오차 행렬
# [[132 598]
#  [  0  20]]
# 정확도: 0.2027, 정밀도: 0.0324, 재현율: 1.0000, F1:0.0627, AUC:0.5904
# ###########################################################################
# 임곗값: 0.003649953042535403
# 오차 행렬
# [[133 597]
#  [  0  20]]
# 정확도: 0.2040, 정밀도: 0.0324, 재현율: 1.0000, F1:0.0628, AUC:0.5911
# ###########################################################################
# 임곗값: 0.003659942009282291
# 오차 행렬
# [[134 596]
#  [  0  20]]
# 정확도: 0.2053, 정밀도: 0.0325, 재현율: 1.0000, F1:0.0629, AUC:0.5918
# ###########################################################################
# 임곗값: 0.0036664486379361385
# 오차 행렬
# [[135 595]
#  [  0  20]]
# 정확도: 0.2067, 정밀도: 0.0325, 재현율: 1.0000, F1:0.0630, AUC:0.5925
# ###########################################################################
# 임곗값: 0.0036829641145953588
# 오차 행렬
# [[136 594]
#  [  0  20]]
# 정확도: 0.2080, 정밀도: 0.0326, 재현율: 1.0000, F1:0.0631, AUC:0.5932
# ###########################################################################
# 임곗값: 0.0036907047740133902
# 오차 행렬
# [[137 593]
#  [  0  20]]
# 정확도: 0.2093, 정밀도: 0.0326, 재현율: 1.0000, F1:0.0632, AUC:0.5938
# ###########################################################################
# 임곗값: 0.0036944674887475974
# 오차 행렬
# [[138 592]
#  [  0  20]]
# 정확도: 0.2107, 정밀도: 0.0327, 재현율: 1.0000, F1:0.0633, AUC:0.5945
# ###########################################################################
# 임곗값: 0.0037019359281426903
# 오차 행렬
# [[139 591]
#  [  0  20]]
# 정확도: 0.2120, 정밀도: 0.0327, 재현율: 1.0000, F1:0.0634, AUC:0.5952
# ###########################################################################
# 임곗값: 0.003706767250050106
# 오차 행렬
# [[140 590]
#  [  0  20]]
# 정확도: 0.2133, 정밀도: 0.0328, 재현율: 1.0000, F1:0.0635, AUC:0.5959
# ###########################################################################
# 임곗값: 0.0037268203137267183
# 오차 행렬
# [[141 589]
#  [  0  20]]
# 정확도: 0.2147, 정밀도: 0.0328, 재현율: 1.0000, F1:0.0636, AUC:0.5966
# ###########################################################################
# 임곗값: 0.003730295577333811
# 오차 행렬
# [[142 588]
#  [  0  20]]
# 정확도: 0.2160, 정밀도: 0.0329, 재현율: 1.0000, F1:0.0637, AUC:0.5973
# ###########################################################################
# 임곗값: 0.003731028796774059
# 오차 행렬
# [[143 587]
#  [  0  20]]
# 정확도: 0.2173, 정밀도: 0.0329, 재현율: 1.0000, F1:0.0638, AUC:0.5979
# ###########################################################################
# 임곗값: 0.0037761761196556795
# 오차 행렬
# [[144 586]
#  [  0  20]]
# 정확도: 0.2187, 정밀도: 0.0330, 재현율: 1.0000, F1:0.0639, AUC:0.5986
# ###########################################################################
# 임곗값: 0.0038640566193337187
# 오차 행렬
# [[145 585]
#  [  0  20]]
# 정확도: 0.2200, 정밀도: 0.0331, 재현율: 1.0000, F1:0.0640, AUC:0.5993
# ###########################################################################
# 임곗값: 0.003889543686597702
# 오차 행렬
# [[146 584]
#  [  0  20]]
# 정확도: 0.2213, 정밀도: 0.0331, 재현율: 1.0000, F1:0.0641, AUC:0.6000
# ###########################################################################
# 임곗값: 0.003897114521951839
# 오차 행렬
# [[147 583]
#  [  0  20]]
# 정확도: 0.2227, 정밀도: 0.0332, 재현율: 1.0000, F1:0.0642, AUC:0.6007
# ###########################################################################
# 임곗값: 0.003903851096666553
# 오차 행렬
# [[148 582]
#  [  0  20]]
# 정확도: 0.2240, 정밀도: 0.0332, 재현율: 1.0000, F1:0.0643, AUC:0.6014
# ###########################################################################
# 임곗값: 0.003917743720284113
# 오차 행렬
# [[149 581]
#  [  0  20]]
# 정확도: 0.2253, 정밀도: 0.0333, 재현율: 1.0000, F1:0.0644, AUC:0.6021
# ###########################################################################
# 임곗값: 0.003946520753032023
# 오차 행렬
# [[150 580]
#  [  0  20]]
# 정확도: 0.2267, 정밀도: 0.0333, 재현율: 1.0000, F1:0.0645, AUC:0.6027
# ###########################################################################
# 임곗값: 0.003947747765567101
# 오차 행렬
# [[151 579]
#  [  0  20]]
# 정확도: 0.2280, 정밀도: 0.0334, 재현율: 1.0000, F1:0.0646, AUC:0.6034
# ###########################################################################
# 임곗값: 0.003966350004022765
# 오차 행렬
# [[152 578]
#  [  0  20]]
# 정확도: 0.2293, 정밀도: 0.0334, 재현율: 1.0000, F1:0.0647, AUC:0.6041
# ###########################################################################
# 임곗값: 0.003977771025274816
# 오차 행렬
# [[153 577]
#  [  0  20]]
# 정확도: 0.2307, 정밀도: 0.0335, 재현율: 1.0000, F1:0.0648, AUC:0.6048
# ###########################################################################
# 임곗값: 0.00397987419514204
# 오차 행렬
# [[154 576]
#  [  0  20]]
# 정확도: 0.2320, 정밀도: 0.0336, 재현율: 1.0000, F1:0.0649, AUC:0.6055
# ###########################################################################
# 임곗값: 0.0039948544418932684
# 오차 행렬
# [[155 575]
#  [  0  20]]
# 정확도: 0.2333, 정밀도: 0.0336, 재현율: 1.0000, F1:0.0650, AUC:0.6062
# ###########################################################################
# 임곗값: 0.004016391232945699
# 오차 행렬
# [[156 574]
#  [  0  20]]
# 정확도: 0.2347, 정밀도: 0.0337, 재현율: 1.0000, F1:0.0651, AUC:0.6068
# ###########################################################################
# 임곗값: 0.004019359845057093
# 오차 행렬
# [[157 573]
#  [  0  20]]
# 정확도: 0.2360, 정밀도: 0.0337, 재현율: 1.0000, F1:0.0653, AUC:0.6075
# ###########################################################################
# 임곗값: 0.004019555590702697
# 오차 행렬
# [[158 572]
#  [  0  20]]
# 정확도: 0.2373, 정밀도: 0.0338, 재현율: 1.0000, F1:0.0654, AUC:0.6082
# ###########################################################################
# 임곗값: 0.004029800122100998
# 오차 행렬
# [[159 571]
#  [  0  20]]
# 정확도: 0.2387, 정밀도: 0.0338, 재현율: 1.0000, F1:0.0655, AUC:0.6089
# ###########################################################################
# 임곗값: 0.0040334894374317014
# 오차 행렬
# [[160 570]
#  [  0  20]]
# 정확도: 0.2400, 정밀도: 0.0339, 재현율: 1.0000, F1:0.0656, AUC:0.6096
# ###########################################################################
# 임곗값: 0.004046082190910387
# 오차 행렬
# [[161 569]
#  [  0  20]]
# 정확도: 0.2413, 정밀도: 0.0340, 재현율: 1.0000, F1:0.0657, AUC:0.6103
# ###########################################################################
# 임곗값: 0.004090059027894372
# 오차 행렬
# [[162 568]
#  [  0  20]]
# 정확도: 0.2427, 정밀도: 0.0340, 재현율: 1.0000, F1:0.0658, AUC:0.6110
# ###########################################################################
# 임곗값: 0.004091757629389641
# 오차 행렬
# [[163 567]
#  [  0  20]]
# 정확도: 0.2440, 정밀도: 0.0341, 재현율: 1.0000, F1:0.0659, AUC:0.6116
# ###########################################################################
# 임곗값: 0.004101335190397471
# 오차 행렬
# [[164 566]
#  [  0  20]]
# 정확도: 0.2453, 정밀도: 0.0341, 재현율: 1.0000, F1:0.0660, AUC:0.6123
# ###########################################################################
# 임곗값: 0.004109483203556759
# 오차 행렬
# [[165 565]
#  [  0  20]]
# 정확도: 0.2467, 정밀도: 0.0342, 재현율: 1.0000, F1:0.0661, AUC:0.6130
# ###########################################################################
# 임곗값: 0.004128129097617924
# 오차 행렬
# [[166 564]
#  [  0  20]]
# 정확도: 0.2480, 정밀도: 0.0342, 재현율: 1.0000, F1:0.0662, AUC:0.6137
# ###########################################################################
# 임곗값: 0.004129686471173895
# 오차 행렬
# [[167 563]
#  [  0  20]]
# 정확도: 0.2493, 정밀도: 0.0343, 재현율: 1.0000, F1:0.0663, AUC:0.6144
# ###########################################################################
# 임곗값: 0.004154472851765942
# 오차 행렬
# [[168 562]
#  [  0  20]]
# 정확도: 0.2507, 정밀도: 0.0344, 재현율: 1.0000, F1:0.0664, AUC:0.6151
# ###########################################################################
# 임곗값: 0.004168971213761447
# 오차 행렬
# [[169 561]
#  [  0  20]]
# 정확도: 0.2520, 정밀도: 0.0344, 재현율: 1.0000, F1:0.0666, AUC:0.6158
# ###########################################################################
# 임곗값: 0.004191212593056143
# 오차 행렬
# [[170 560]
#  [  0  20]]
# 정확도: 0.2533, 정밀도: 0.0345, 재현율: 1.0000, F1:0.0667, AUC:0.6164
# ###########################################################################
# 임곗값: 0.0041989495792762776
# 오차 행렬
# [[171 559]
#  [  0  20]]
# 정확도: 0.2547, 정밀도: 0.0345, 재현율: 1.0000, F1:0.0668, AUC:0.6171
# ###########################################################################
# 임곗값: 0.004221552153969949
# 오차 행렬
# [[172 558]
#  [  0  20]]
# 정확도: 0.2560, 정밀도: 0.0346, 재현율: 1.0000, F1:0.0669, AUC:0.6178
# ###########################################################################
# 임곗값: 0.004236346562855619
# 오차 행렬
# [[173 557]
#  [  0  20]]
# 정확도: 0.2573, 정밀도: 0.0347, 재현율: 1.0000, F1:0.0670, AUC:0.6185
# ###########################################################################
# 임곗값: 0.004288348947878866
# 오차 행렬
# [[174 556]
#  [  0  20]]
# 정확도: 0.2587, 정밀도: 0.0347, 재현율: 1.0000, F1:0.0671, AUC:0.6192
# ###########################################################################
# 임곗값: 0.00429216001339922
# 오차 행렬
# [[175 555]
#  [  0  20]]
# 정확도: 0.2600, 정밀도: 0.0348, 재현율: 1.0000, F1:0.0672, AUC:0.6199
# ###########################################################################
# 임곗값: 0.004333330131415376
# 오차 행렬
# [[176 554]
#  [  0  20]]
# 정확도: 0.2613, 정밀도: 0.0348, 재현율: 1.0000, F1:0.0673, AUC:0.6205
# ###########################################################################
# 임곗값: 0.004377771308208823
# 오차 행렬
# [[177 553]
#  [  0  20]]
# 정확도: 0.2627, 정밀도: 0.0349, 재현율: 1.0000, F1:0.0675, AUC:0.6212
# ###########################################################################
# 임곗값: 0.004388781158427909
# 오차 행렬
# [[178 552]
#  [  0  20]]
# 정확도: 0.2640, 정밀도: 0.0350, 재현율: 1.0000, F1:0.0676, AUC:0.6219
# ###########################################################################
# 임곗값: 0.004423371597951283
# 오차 행렬
# [[179 551]
#  [  0  20]]
# 정확도: 0.2653, 정밀도: 0.0350, 재현율: 1.0000, F1:0.0677, AUC:0.6226
# ###########################################################################
# 임곗값: 0.004431350025861554
# 오차 행렬
# [[180 550]
#  [  0  20]]
# 정확도: 0.2667, 정밀도: 0.0351, 재현율: 1.0000, F1:0.0678, AUC:0.6233
# ###########################################################################
# 임곗값: 0.004439651801555246
# 오차 행렬
# [[181 549]
#  [  0  20]]
# 정확도: 0.2680, 정밀도: 0.0351, 재현율: 1.0000, F1:0.0679, AUC:0.6240
# ###########################################################################
# 임곗값: 0.004441840984084843
# 오차 행렬
# [[182 548]
#  [  0  20]]
# 정확도: 0.2693, 정밀도: 0.0352, 재현율: 1.0000, F1:0.0680, AUC:0.6247
# ###########################################################################
# 임곗값: 0.004442041049249955
# 오차 행렬
# [[183 547]
#  [  0  20]]
# 정확도: 0.2707, 정밀도: 0.0353, 재현율: 1.0000, F1:0.0681, AUC:0.6253
# ###########################################################################
# 임곗값: 0.004476315992892554
# 오차 행렬
# [[184 546]
#  [  0  20]]
# 정확도: 0.2720, 정밀도: 0.0353, 재현율: 1.0000, F1:0.0683, AUC:0.6260
# ###########################################################################
# 임곗값: 0.004485807781079547
# 오차 행렬
# [[185 545]
#  [  0  20]]
# 정확도: 0.2733, 정밀도: 0.0354, 재현율: 1.0000, F1:0.0684, AUC:0.6267
# ###########################################################################
# 임곗값: 0.004498554551089465
# 오차 행렬
# [[186 544]
#  [  0  20]]
# 정확도: 0.2747, 정밀도: 0.0355, 재현율: 1.0000, F1:0.0685, AUC:0.6274
# ###########################################################################
# 임곗값: 0.004521312483021234
# 오차 행렬
# [[187 543]
#  [  0  20]]
# 정확도: 0.2760, 정밀도: 0.0355, 재현율: 1.0000, F1:0.0686, AUC:0.6281
# ###########################################################################
# 임곗값: 0.004534268229010664
# 오차 행렬
# [[188 542]
#  [  0  20]]
# 정확도: 0.2773, 정밀도: 0.0356, 재현율: 1.0000, F1:0.0687, AUC:0.6288
# ###########################################################################
# 임곗값: 0.004552251913864008
# 오차 행렬
# [[189 541]
#  [  0  20]]
# 정확도: 0.2787, 정밀도: 0.0357, 재현율: 1.0000, F1:0.0688, AUC:0.6295
# ###########################################################################
# 임곗값: 0.004575496345934438
# 오차 행렬
# [[190 540]
#  [  0  20]]
# 정확도: 0.2800, 정밀도: 0.0357, 재현율: 1.0000, F1:0.0690, AUC:0.6301
# ###########################################################################
# 임곗값: 0.00459011486562165
# 오차 행렬
# [[191 539]
#  [  0  20]]
# 정확도: 0.2813, 정밀도: 0.0358, 재현율: 1.0000, F1:0.0691, AUC:0.6308
# ###########################################################################
# 임곗값: 0.004604423091364915
# 오차 행렬
# [[192 538]
#  [  0  20]]
# 정확도: 0.2827, 정밀도: 0.0358, 재현율: 1.0000, F1:0.0692, AUC:0.6315
# ###########################################################################
# 임곗값: 0.004604844086788842
# 오차 행렬
# [[193 537]
#  [  0  20]]
# 정확도: 0.2840, 정밀도: 0.0359, 재현율: 1.0000, F1:0.0693, AUC:0.6322
# ###########################################################################
# 임곗값: 0.004606702976673105
# 오차 행렬
# [[194 536]
#  [  0  20]]
# 정확도: 0.2853, 정밀도: 0.0360, 재현율: 1.0000, F1:0.0694, AUC:0.6329
# ###########################################################################
# 임곗값: 0.004615121923753021
# 오차 행렬
# [[195 535]
#  [  0  20]]
# 정확도: 0.2867, 정밀도: 0.0360, 재현율: 1.0000, F1:0.0696, AUC:0.6336
# ###########################################################################
# 임곗값: 0.004628593675455298
# 오차 행렬
# [[196 534]
#  [  0  20]]
# 정확도: 0.2880, 정밀도: 0.0361, 재현율: 1.0000, F1:0.0697, AUC:0.6342
# ###########################################################################
# 임곗값: 0.00463783899896626
# 오차 행렬
# [[197 533]
#  [  0  20]]
# 정확도: 0.2893, 정밀도: 0.0362, 재현율: 1.0000, F1:0.0698, AUC:0.6349
# ###########################################################################
# 임곗값: 0.004644465540150657
# 오차 행렬
# [[198 532]
#  [  0  20]]
# 정확도: 0.2907, 정밀도: 0.0362, 재현율: 1.0000, F1:0.0699, AUC:0.6356
# ###########################################################################
# 임곗값: 0.0046447122757715875
# 오차 행렬
# [[199 531]
#  [  0  20]]
# 정확도: 0.2920, 정밀도: 0.0363, 재현율: 1.0000, F1:0.0701, AUC:0.6363
# ###########################################################################
# 임곗값: 0.004657606244997803
# 오차 행렬
# [[200 530]
#  [  0  20]]
# 정확도: 0.2933, 정밀도: 0.0364, 재현율: 1.0000, F1:0.0702, AUC:0.6370
# ###########################################################################
# 임곗값: 0.004664337475628667
# 오차 행렬
# [[201 529]
#  [  0  20]]
# 정확도: 0.2947, 정밀도: 0.0364, 재현율: 1.0000, F1:0.0703, AUC:0.6377
# ###########################################################################
# 임곗값: 0.004685792985607659
# 오차 행렬
# [[202 528]
#  [  0  20]]
# 정확도: 0.2960, 정밀도: 0.0365, 재현율: 1.0000, F1:0.0704, AUC:0.6384
# ###########################################################################
# 임곗값: 0.004701458346173098
# 오차 행렬
# [[203 527]
#  [  0  20]]
# 정확도: 0.2973, 정밀도: 0.0366, 재현율: 1.0000, F1:0.0705, AUC:0.6390
# ###########################################################################
# 임곗값: 0.004732209850620094
# 오차 행렬
# [[204 526]
#  [  0  20]]
# 정확도: 0.2987, 정밀도: 0.0366, 재현율: 1.0000, F1:0.0707, AUC:0.6397
# ###########################################################################
# 임곗값: 0.004734110001214725
# 오차 행렬
# [[205 525]
#  [  0  20]]
# 정확도: 0.3000, 정밀도: 0.0367, 재현율: 1.0000, F1:0.0708, AUC:0.6404
# ###########################################################################
# 임곗값: 0.004734803843210504
# 오차 행렬
# [[206 524]
#  [  0  20]]
# 정확도: 0.3013, 정밀도: 0.0368, 재현율: 1.0000, F1:0.0709, AUC:0.6411
# ###########################################################################
# 임곗값: 0.00475061337511317
# 오차 행렬
# [[207 523]
#  [  0  20]]
# 정확도: 0.3027, 정밀도: 0.0368, 재현율: 1.0000, F1:0.0710, AUC:0.6418
# ###########################################################################
# 임곗값: 0.004753442688730902
# 오차 행렬
# [[208 522]
#  [  0  20]]
# 정확도: 0.3040, 정밀도: 0.0369, 재현율: 1.0000, F1:0.0712, AUC:0.6425
# ###########################################################################
# 임곗값: 0.004756917729139998
# 오차 행렬
# [[209 521]
#  [  0  20]]
# 정확도: 0.3053, 정밀도: 0.0370, 재현율: 1.0000, F1:0.0713, AUC:0.6432
# ###########################################################################
# 임곗값: 0.004758251877372045
# 오차 행렬
# [[210 520]
#  [  0  20]]
# 정확도: 0.3067, 정밀도: 0.0370, 재현율: 1.0000, F1:0.0714, AUC:0.6438
# ###########################################################################
# 임곗값: 0.004775614825224774
# 오차 행렬
# [[211 519]
#  [  0  20]]
# 정확도: 0.3080, 정밀도: 0.0371, 재현율: 1.0000, F1:0.0716, AUC:0.6445
# ###########################################################################
# 임곗값: 0.004790104707638552
# 오차 행렬
# [[212 518]
#  [  0  20]]
# 정확도: 0.3093, 정밀도: 0.0372, 재현율: 1.0000, F1:0.0717, AUC:0.6452
# ###########################################################################
# 임곗값: 0.004815243397549071
# 오차 행렬
# [[213 517]
#  [  0  20]]
# 정확도: 0.3107, 정밀도: 0.0372, 재현율: 1.0000, F1:0.0718, AUC:0.6459
# ###########################################################################
# 임곗값: 0.004839843046577964
# 오차 행렬
# [[214 516]
#  [  0  20]]
# 정확도: 0.3120, 정밀도: 0.0373, 재현율: 1.0000, F1:0.0719, AUC:0.6466
# ###########################################################################
# 임곗값: 0.004882705682457158
# 오차 행렬
# [[215 515]
#  [  0  20]]
# 정확도: 0.3133, 정밀도: 0.0374, 재현율: 1.0000, F1:0.0721, AUC:0.6473
# ###########################################################################
# 임곗값: 0.004884257994042342
# 오차 행렬
# [[216 514]
#  [  0  20]]
# 정확도: 0.3147, 정밀도: 0.0375, 재현율: 1.0000, F1:0.0722, AUC:0.6479
# ###########################################################################
# 임곗값: 0.004918245999053164
# 오차 행렬
# [[217 513]
#  [  0  20]]
# 정확도: 0.3160, 정밀도: 0.0375, 재현율: 1.0000, F1:0.0723, AUC:0.6486
# ###########################################################################
# 임곗값: 0.004921755964176613
# 오차 행렬
# [[218 512]
#  [  0  20]]
# 정확도: 0.3173, 정밀도: 0.0376, 재현율: 1.0000, F1:0.0725, AUC:0.6493
# ###########################################################################
# 임곗값: 0.0049358926271147316
# 오차 행렬
# [[219 511]
#  [  0  20]]
# 정확도: 0.3187, 정밀도: 0.0377, 재현율: 1.0000, F1:0.0726, AUC:0.6500
# ###########################################################################
# 임곗값: 0.004950022534924025
# 오차 행렬
# [[220 510]
#  [  0  20]]
# 정확도: 0.3200, 정밀도: 0.0377, 재현율: 1.0000, F1:0.0727, AUC:0.6507
# ###########################################################################
# 임곗값: 0.004981591615773839
# 오차 행렬
# [[221 509]
#  [  0  20]]
# 정확도: 0.3213, 정밀도: 0.0378, 재현율: 1.0000, F1:0.0729, AUC:0.6514
# ###########################################################################
# 임곗값: 0.005003616227940895
# 오차 행렬
# [[222 508]
#  [  0  20]]
# 정확도: 0.3227, 정밀도: 0.0379, 재현율: 1.0000, F1:0.0730, AUC:0.6521
# ###########################################################################
# 임곗값: 0.005017856638786152
# 오차 행렬
# [[223 507]
#  [  0  20]]
# 정확도: 0.3240, 정밀도: 0.0380, 재현율: 1.0000, F1:0.0731, AUC:0.6527
# ###########################################################################
# 임곗값: 0.0050295489820518175
# 오차 행렬
# [[224 506]
#  [  0  20]]
# 정확도: 0.3253, 정밀도: 0.0380, 재현율: 1.0000, F1:0.0733, AUC:0.6534
# ###########################################################################
# 임곗값: 0.005044337830651021
# 오차 행렬
# [[225 505]
#  [  0  20]]
# 정확도: 0.3267, 정밀도: 0.0381, 재현율: 1.0000, F1:0.0734, AUC:0.6541
# ###########################################################################
# 임곗값: 0.005102755182184688
# 오차 행렬
# [[226 504]
#  [  0  20]]
# 정확도: 0.3280, 정밀도: 0.0382, 재현율: 1.0000, F1:0.0735, AUC:0.6548
# ###########################################################################
# 임곗값: 0.005102844337759131
# 오차 행렬
# [[227 503]
#  [  0  20]]
# 정확도: 0.3293, 정밀도: 0.0382, 재현율: 1.0000, F1:0.0737, AUC:0.6555
# ###########################################################################
# 임곗값: 0.005114482603125665
# 오차 행렬
# [[228 502]
#  [  0  20]]
# 정확도: 0.3307, 정밀도: 0.0383, 재현율: 1.0000, F1:0.0738, AUC:0.6562
# ###########################################################################
# 임곗값: 0.005116465811932319
# 오차 행렬
# [[229 501]
#  [  0  20]]
# 정확도: 0.3320, 정밀도: 0.0384, 재현율: 1.0000, F1:0.0739, AUC:0.6568
# ###########################################################################
# 임곗값: 0.005120158515447909
# 오차 행렬
# [[230 500]
#  [  0  20]]
# 정확도: 0.3333, 정밀도: 0.0385, 재현율: 1.0000, F1:0.0741, AUC:0.6575
# ###########################################################################
# 임곗값: 0.005130431435792636
# 오차 행렬
# [[231 499]
#  [  0  20]]
# 정확도: 0.3347, 정밀도: 0.0385, 재현율: 1.0000, F1:0.0742, AUC:0.6582
# ###########################################################################
# 임곗값: 0.005133166219749379
# 오차 행렬
# [[232 498]
#  [  0  20]]
# 정확도: 0.3360, 정밀도: 0.0386, 재현율: 1.0000, F1:0.0743, AUC:0.6589
# ###########################################################################
# 임곗값: 0.005150637748972517
# 오차 행렬
# [[233 497]
#  [  0  20]]
# 정확도: 0.3373, 정밀도: 0.0387, 재현율: 1.0000, F1:0.0745, AUC:0.6596
# ###########################################################################
# 임곗값: 0.005186841417953932
# 오차 행렬
# [[234 496]
#  [  0  20]]
# 정확도: 0.3387, 정밀도: 0.0388, 재현율: 1.0000, F1:0.0746, AUC:0.6603
# ###########################################################################
# 임곗값: 0.005202928732190202
# 오차 행렬
# [[235 495]
#  [  0  20]]
# 정확도: 0.3400, 정밀도: 0.0388, 재현율: 1.0000, F1:0.0748, AUC:0.6610
# ###########################################################################
# 임곗값: 0.005218275773389594
# 오차 행렬
# [[236 494]
#  [  0  20]]
# 정확도: 0.3413, 정밀도: 0.0389, 재현율: 1.0000, F1:0.0749, AUC:0.6616
# ###########################################################################
# 임곗값: 0.005262719219476968
# 오차 행렬
# [[237 493]
#  [  0  20]]
# 정확도: 0.3427, 정밀도: 0.0390, 재현율: 1.0000, F1:0.0750, AUC:0.6623
# ###########################################################################
# 임곗값: 0.005285038424953647
# 오차 행렬
# [[238 492]
#  [  0  20]]
# 정확도: 0.3440, 정밀도: 0.0391, 재현율: 1.0000, F1:0.0752, AUC:0.6630
# ###########################################################################
# 임곗값: 0.005294262184162992
# 오차 행렬
# [[239 491]
#  [  0  20]]
# 정확도: 0.3453, 정밀도: 0.0391, 재현율: 1.0000, F1:0.0753, AUC:0.6637
# ###########################################################################
# 임곗값: 0.005313560135888662
# 오차 행렬
# [[240 490]
#  [  0  20]]
# 정확도: 0.3467, 정밀도: 0.0392, 재현율: 1.0000, F1:0.0755, AUC:0.6644
# ###########################################################################
# 임곗값: 0.005316711230631252
# 오차 행렬
# [[241 489]
#  [  0  20]]
# 정확도: 0.3480, 정밀도: 0.0393, 재현율: 1.0000, F1:0.0756, AUC:0.6651
# ###########################################################################
# 임곗값: 0.00532839410653828
# 오차 행렬
# [[242 488]
#  [  0  20]]
# 정확도: 0.3493, 정밀도: 0.0394, 재현율: 1.0000, F1:0.0758, AUC:0.6658
# ###########################################################################
# 임곗값: 0.0053380364169375505
# 오차 행렬
# [[243 487]
#  [  0  20]]
# 정확도: 0.3507, 정밀도: 0.0394, 재현율: 1.0000, F1:0.0759, AUC:0.6664
# ###########################################################################
# 임곗값: 0.005340158246901934
# 오차 행렬
# [[244 486]
#  [  0  20]]
# 정확도: 0.3520, 정밀도: 0.0395, 재현율: 1.0000, F1:0.0760, AUC:0.6671
# ###########################################################################
# 임곗값: 0.005372624301592268
# 오차 행렬
# [[245 485]
#  [  0  20]]
# 정확도: 0.3533, 정밀도: 0.0396, 재현율: 1.0000, F1:0.0762, AUC:0.6678
# ###########################################################################
# 임곗값: 0.005392958957635702
# 오차 행렬
# [[246 484]
#  [  0  20]]
# 정확도: 0.3547, 정밀도: 0.0397, 재현율: 1.0000, F1:0.0763, AUC:0.6685
# ###########################################################################
# 임곗값: 0.00541916936087211
# 오차 행렬
# [[247 483]
#  [  0  20]]
# 정확도: 0.3560, 정밀도: 0.0398, 재현율: 1.0000, F1:0.0765, AUC:0.6692
# ###########################################################################
# 임곗값: 0.005430762196276159
# 오차 행렬
# [[248 482]
#  [  0  20]]
# 정확도: 0.3573, 정밀도: 0.0398, 재현율: 1.0000, F1:0.0766, AUC:0.6699
# ###########################################################################
# 임곗값: 0.0054500389162754626
# 오차 행렬
# [[249 481]
#  [  0  20]]
# 정확도: 0.3587, 정밀도: 0.0399, 재현율: 1.0000, F1:0.0768, AUC:0.6705
# ###########################################################################
# 임곗값: 0.005450206171474651
# 오차 행렬
# [[250 480]
#  [  0  20]]
# ...
# 임곗값: 0.026272493673833473
# 오차 행렬
# [[668  62]
#  [  1  19]]
# 정확도: 0.9160, 정밀도: 0.2346, 재현율: 0.9500, F1:0.3762, AUC:0.9325
# ###########################################################################
# 임곗값: 0.026328121214900864
# 오차 행렬
# [[669  61]
#  [  1  19]]
# 정확도: 0.9173, 정밀도: 0.2375, 재현율: 0.9500, F1:0.3800, AUC:0.9332
# ###########################################################################
# 임곗값: 0.027308679352687246
# 오차 행렬
# [[670  60]
#  [  1  19]]
# 정확도: 0.9187, 정밀도: 0.2405, 재현율: 0.9500, F1:0.3838, AUC:0.9339
# ###########################################################################
# 임곗값: 0.027722475660091974
# 오차 행렬
# [[671  59]
#  [  1  19]]
# 정확도: 0.9200, 정밀도: 0.2436, 재현율: 0.9500, F1:0.3878, AUC:0.9346
# ###########################################################################
# 임곗값: 0.02780945572627085
# 오차 행렬
# [[672  58]
#  [  1  19]]
# 정확도: 0.9213, 정밀도: 0.2468, 재현율: 0.9500, F1:0.3918, AUC:0.9353
# ###########################################################################
# 임곗값: 0.028278349076261255
# 오차 행렬
# [[673  57]
#  [  1  19]]
# 정확도: 0.9227, 정밀도: 0.2500, 재현율: 0.9500, F1:0.3958, AUC:0.9360
# ###########################################################################
# 임곗값: 0.02831966739637189
# 오차 행렬
# [[674  56]
#  [  1  19]]
# 정확도: 0.9240, 정밀도: 0.2533, 재현율: 0.9500, F1:0.4000, AUC:0.9366
# ###########################################################################
# 임곗값: 0.02850462807064038
# 오차 행렬
# [[675  55]
#  [  1  19]]
# 정확도: 0.9253, 정밀도: 0.2568, 재현율: 0.9500, F1:0.4043, AUC:0.9373
# ###########################################################################
# 임곗값: 0.028614067521791665
# 오차 행렬
# [[676  54]
#  [  1  19]]
# 정확도: 0.9267, 정밀도: 0.2603, 재현율: 0.9500, F1:0.4086, AUC:0.9380
# ###########################################################################
# 임곗값: 0.02889150269417913
# 오차 행렬
# [[677  53]
#  [  1  19]]
# 정확도: 0.9280, 정밀도: 0.2639, 재현율: 0.9500, F1:0.4130, AUC:0.9387
# ###########################################################################
# 임곗값: 0.029637674141248623
# 오차 행렬
# [[678  52]
#  [  1  19]]
# 정확도: 0.9293, 정밀도: 0.2676, 재현율: 0.9500, F1:0.4176, AUC:0.9394
# ###########################################################################
# 임곗값: 0.029743069500209007
# 오차 행렬
# [[679  51]
#  [  1  19]]
# 정확도: 0.9307, 정밀도: 0.2714, 재현율: 0.9500, F1:0.4222, AUC:0.9401
# ###########################################################################
# 임곗값: 0.03012710361718475
# 오차 행렬
# [[680  50]
#  [  1  19]]
# 정확도: 0.9320, 정밀도: 0.2754, 재현율: 0.9500, F1:0.4270, AUC:0.9408
# ###########################################################################
# 임곗값: 0.030217572387659174
# 오차 행렬
# [[681  49]
#  [  1  19]]
# 정확도: 0.9333, 정밀도: 0.2794, 재현율: 0.9500, F1:0.4318, AUC:0.9414
# ###########################################################################
# 임곗값: 0.030221827907142163
# 오차 행렬
# [[682  48]
#  [  1  19]]
# 정확도: 0.9347, 정밀도: 0.2836, 재현율: 0.9500, F1:0.4368, AUC:0.9421
# ###########################################################################
# 임곗값: 0.03101711438700289
# 오차 행렬
# [[683  47]
#  [  1  19]]
# 정확도: 0.9360, 정밀도: 0.2879, 재현율: 0.9500, F1:0.4419, AUC:0.9428
# ###########################################################################
# 임곗값: 0.03155817602859472
# 오차 행렬
# [[684  46]
#  [  1  19]]
# 정확도: 0.9373, 정밀도: 0.2923, 재현율: 0.9500, F1:0.4471, AUC:0.9435
# ###########################################################################
# 임곗값: 0.03193727079824534
# 오차 행렬
# [[685  45]
#  [  1  19]]
# 정확도: 0.9387, 정밀도: 0.2969, 재현율: 0.9500, F1:0.4524, AUC:0.9442
# ###########################################################################
# 임곗값: 0.03211855964893249
# 오차 행렬
# [[686  44]
#  [  1  19]]
# 정확도: 0.9400, 정밀도: 0.3016, 재현율: 0.9500, F1:0.4578, AUC:0.9449
# ###########################################################################
# 임곗값: 0.032599602582293725
# 오차 행렬
# [[687  43]
#  [  1  19]]
# 정확도: 0.9413, 정밀도: 0.3065, 재현율: 0.9500, F1:0.4634, AUC:0.9455
# ###########################################################################
# 임곗값: 0.03260036355839183
# 오차 행렬
# [[688  42]
#  [  1  19]]
# 정확도: 0.9427, 정밀도: 0.3115, 재현율: 0.9500, F1:0.4691, AUC:0.9462
# ###########################################################################
# 임곗값: 0.03268720674518622
# 오차 행렬
# [[689  41]
#  [  1  19]]
# 정확도: 0.9440, 정밀도: 0.3167, 재현율: 0.9500, F1:0.4750, AUC:0.9469
# ###########################################################################
# 임곗값: 0.032704047018293436
# 오차 행렬
# [[690  40]
#  [  1  19]]
# 정확도: 0.9453, 정밀도: 0.3220, 재현율: 0.9500, F1:0.4810, AUC:0.9476
# ###########################################################################
# 임곗값: 0.03380035141756551
# 오차 행렬
# [[691  39]
#  [  1  19]]
# 정확도: 0.9467, 정밀도: 0.3276, 재현율: 0.9500, F1:0.4872, AUC:0.9483
# ###########################################################################
# 임곗값: 0.03452116264653147
# 오차 행렬
# [[692  38]
#  [  1  19]]
# 정확도: 0.9480, 정밀도: 0.3333, 재현율: 0.9500, F1:0.4935, AUC:0.9490
# ###########################################################################
# 임곗값: 0.034803788751616584
# 오차 행렬
# [[693  37]
#  [  1  19]]
# 정확도: 0.9493, 정밀도: 0.3393, 재현율: 0.9500, F1:0.5000, AUC:0.9497
# ###########################################################################
# 임곗값: 0.03555521763502054
# 오차 행렬
# [[694  36]
#  [  1  19]]
# 정확도: 0.9507, 정밀도: 0.3455, 재현율: 0.9500, F1:0.5067, AUC:0.9503
# ###########################################################################
# 임곗값: 0.03578887468827399
# 오차 행렬
# [[695  35]
#  [  1  19]]
# 정확도: 0.9520, 정밀도: 0.3519, 재현율: 0.9500, F1:0.5135, AUC:0.9510
# ###########################################################################
# 임곗값: 0.03578958962945785
# 오차 행렬
# [[696  34]
#  [  1  19]]
# 정확도: 0.9533, 정밀도: 0.3585, 재현율: 0.9500, F1:0.5205, AUC:0.9517
# ###########################################################################
# 임곗값: 0.0357979980009648
# 오차 행렬
# [[697  33]
#  [  1  19]]
# 정확도: 0.9547, 정밀도: 0.3654, 재현율: 0.9500, F1:0.5278, AUC:0.9524
# ###########################################################################
# 임곗값: 0.03674302485985668
# 오차 행렬
# [[698  32]
#  [  1  19]]
# 정확도: 0.9560, 정밀도: 0.3725, 재현율: 0.9500, F1:0.5352, AUC:0.9531
# ###########################################################################
# 임곗값: 0.0370988483056643
# 오차 행렬
# [[699  31]
#  [  1  19]]
# 정확도: 0.9573, 정밀도: 0.3800, 재현율: 0.9500, F1:0.5429, AUC:0.9538
# ###########################################################################
# 임곗값: 0.03850456833650143
# 오차 행렬
# [[700  30]
#  [  1  19]]
# 정확도: 0.9587, 정밀도: 0.3878, 재현율: 0.9500, F1:0.5507, AUC:0.9545
# ###########################################################################
# 임곗값: 0.04018472199579108
# 오차 행렬
# [[701  29]
#  [  1  19]]
# 정확도: 0.9600, 정밀도: 0.3958, 재현율: 0.9500, F1:0.5588, AUC:0.9551
# ###########################################################################
# 임곗값: 0.040787504393569714
# 오차 행렬
# [[702  28]
#  [  1  19]]
# 정확도: 0.9613, 정밀도: 0.4043, 재현율: 0.9500, F1:0.5672, AUC:0.9558
# ###########################################################################
# 임곗값: 0.04118888518840804
# 오차 행렬
# [[703  27]
#  [  1  19]]
# 정확도: 0.9627, 정밀도: 0.4130, 재현율: 0.9500, F1:0.5758, AUC:0.9565
# ###########################################################################
# 임곗값: 0.04237397931070764
# 오차 행렬
# [[704  26]
#  [  1  19]]
# 정확도: 0.9640, 정밀도: 0.4222, 재현율: 0.9500, F1:0.5846, AUC:0.9572
# ###########################################################################
# 임곗값: 0.04329625168467162
# 오차 행렬
# [[705  25]
#  [  1  19]]
# 정확도: 0.9653, 정밀도: 0.4318, 재현율: 0.9500, F1:0.5938, AUC:0.9579
# ###########################################################################
# 임곗값: 0.04681327520074933
# 오차 행렬
# [[706  24]
#  [  1  19]]
# 정확도: 0.9667, 정밀도: 0.4419, 재현율: 0.9500, F1:0.6032, AUC:0.9586
# ###########################################################################
# 임곗값: 0.047596079250686325
# 오차 행렬
# [[707  23]
#  [  1  19]]
# 정확도: 0.9680, 정밀도: 0.4524, 재현율: 0.9500, F1:0.6129, AUC:0.9592
# ###########################################################################
# 임곗값: 0.050817557493531174
# 오차 행렬
# [[708  22]
#  [  1  19]]
# 정확도: 0.9693, 정밀도: 0.4634, 재현율: 0.9500, F1:0.6230, AUC:0.9599
# ###########################################################################
# 임곗값: 0.051927253871689096
# 오차 행렬
# [[709  21]
#  [  1  19]]
# 정확도: 0.9707, 정밀도: 0.4750, 재현율: 0.9500, F1:0.6333, AUC:0.9606
# ###########################################################################
# 임곗값: 0.05225772235550961
# 오차 행렬
# [[710  20]
#  [  1  19]]
# 정확도: 0.9720, 정밀도: 0.4872, 재현율: 0.9500, F1:0.6441, AUC:0.9613
# ###########################################################################
# 임곗값: 0.059726327004947774
# 오차 행렬
# [[711  19]
#  [  1  19]]
# 정확도: 0.9733, 정밀도: 0.5000, 재현율: 0.9500, F1:0.6552, AUC:0.9620
# ###########################################################################
# 임곗값: 0.06257748798400714
# 오차 행렬
# [[712  18]
#  [  1  19]]
# 정확도: 0.9747, 정밀도: 0.5135, 재현율: 0.9500, F1:0.6667, AUC:0.9627
# ###########################################################################
# 임곗값: 0.06906956069057124
# 오차 행렬
# [[713  17]
#  [  1  19]]
# 정확도: 0.9760, 정밀도: 0.5278, 재현율: 0.9500, F1:0.6786, AUC:0.9634
# ###########################################################################
# 임곗값: 0.06954532134520673
# 오차 행렬
# [[714  16]
#  [  1  19]]
# 정확도: 0.9773, 정밀도: 0.5429, 재현율: 0.9500, F1:0.6909, AUC:0.9640
# ###########################################################################
# 임곗값: 0.07944615024359691
# 오차 행렬
# [[715  15]
#  [  1  19]]
# 정확도: 0.9787, 정밀도: 0.5588, 재현율: 0.9500, F1:0.7037, AUC:0.9647
# ###########################################################################
# 임곗값: 0.08054357864728662
# 오차 행렬
# [[716  14]
#  [  1  19]]
# 정확도: 0.9800, 정밀도: 0.5758, 재현율: 0.9500, F1:0.7170, AUC:0.9654
# ###########################################################################
# 임곗값: 0.08406096431510533
# 오차 행렬
# [[717  13]
#  [  1  19]]
# 정확도: 0.9813, 정밀도: 0.5938, 재현율: 0.9500, F1:0.7308, AUC:0.9661
# ###########################################################################
# 임곗값: 0.08452238839908097
# 오차 행렬
# [[718  12]
#  [  1  19]]
# 정확도: 0.9827, 정밀도: 0.6129, 재현율: 0.9500, F1:0.7451, AUC:0.9668
# ###########################################################################
# 임곗값: 0.08927701201394943
# 오차 행렬
# [[719  11]
#  [  1  19]]
# 정확도: 0.9840, 정밀도: 0.6333, 재현율: 0.9500, F1:0.7600, AUC:0.9675
# ###########################################################################
# 임곗값: 0.09084334624540259
# 오차 행렬
# [[720  10]
#  [  1  19]]
# 정확도: 0.9853, 정밀도: 0.6552, 재현율: 0.9500, F1:0.7755, AUC:0.9682
# ###########################################################################
# 임곗값: 0.09270514671655188
# 오차 행렬
# [[721   9]
#  [  1  19]]
# 정확도: 0.9867, 정밀도: 0.6786, 재현율: 0.9500, F1:0.7917, AUC:0.9688
# ###########################################################################
# 임곗값: 0.09548753800880315
# 오차 행렬
# [[722   8]
#  [  1  19]]
# 정확도: 0.9880, 정밀도: 0.7037, 재현율: 0.9500, F1:0.8085, AUC:0.9695
# ###########################################################################
# 임곗값: 0.11123571152019195
# 오차 행렬
# [[723   7]
#  [  1  19]]
# 정확도: 0.9893, 정밀도: 0.7308, 재현율: 0.9500, F1:0.8261, AUC:0.9702
# ###########################################################################
# 임곗값: 0.12247177425738583
# 오차 행렬
# [[723   7]
#  [  2  18]]
# 정확도: 0.9880, 정밀도: 0.7200, 재현율: 0.9000, F1:0.8000, AUC:0.9452
# ###########################################################################
# 임곗값: 0.12648461332517713
# 오차 행렬
# [[724   6]
#  [  2  18]]
# 정확도: 0.9893, 정밀도: 0.7500, 재현율: 0.9000, F1:0.8182, AUC:0.9459
# ###########################################################################
# 임곗값: 0.1264903060117205
# 오차 행렬
# [[725   5]
#  [  2  18]]
# 정확도: 0.9907, 정밀도: 0.7826, 재현율: 0.9000, F1:0.8372, AUC:0.9466
# ###########################################################################
# 임곗값: 0.1306412217531259
# 오차 행렬
# [[725   5]
#  [  3  17]]
# 정확도: 0.9893, 정밀도: 0.7727, 재현율: 0.8500, F1:0.8095, AUC:0.9216
# ###########################################################################
# 임곗값: 0.13873277650100765
# 오차 행렬
# [[726   4]
#  [  3  17]]
# 정확도: 0.9907, 정밀도: 0.8095, 재현율: 0.8500, F1:0.8293, AUC:0.9223
# ###########################################################################
# 임곗값: 0.1419389991523109
# 오차 행렬
# [[727   3]
#  [  3  17]]
# 정확도: 0.9920, 정밀도: 0.8500, 재현율: 0.8500, F1:0.8500, AUC:0.9229
# ###########################################################################
# 임곗값: 0.1448440098178171
# 오차 행렬
# [[728   2]
#  [  3  17]]
# 정확도: 0.9933, 정밀도: 0.8947, 재현율: 0.8500, F1:0.8718, AUC:0.9236
# ###########################################################################
# 임곗값: 0.1504454429615104
# 오차 행렬
# [[729   1]
#  [  3  17]]
# 정확도: 0.9947, 정밀도: 0.9444, 재현율: 0.8500, F1:0.8947, AUC:0.9243
# ###########################################################################
# 임곗값: 0.22230924180244352
# 오차 행렬
# [[730   0]
#  [  3  17]]
# 정확도: 0.9960, 정밀도: 1.0000, 재현율: 0.8500, F1:0.9189, AUC:0.9250
# ###########################################################################
# 임곗값: 0.2519812302468397
# 오차 행렬
# [[730   0]
#  [  4  16]]
# 정확도: 0.9947, 정밀도: 1.0000, 재현율: 0.8000, F1:0.8889, AUC:0.9000
# ###########################################################################
# 임곗값: 0.4133765996189443
# 오차 행렬
# [[730   0]
#  [  5  15]]
# 정확도: 0.9933, 정밀도: 1.0000, 재현율: 0.7500, F1:0.8571, AUC:0.8750
# ###########################################################################
# 임곗값: 0.4885067344263766
# 오차 행렬
# [[730   0]
#  [  6  14]]
# 정확도: 0.9920, 정밀도: 1.0000, 재현율: 0.7000, F1:0.8235, AUC:0.8500
# ###########################################################################
# 임곗값: 0.5271971455428717
# 오차 행렬
# [[730   0]
#  [  7  13]]
# 정확도: 0.9907, 정밀도: 1.0000, 재현율: 0.6500, F1:0.7879, AUC:0.8250
# ###########################################################################
# 임곗값: 0.5562454344044687
# 오차 행렬
# [[730   0]
#  [  8  12]]
# 정확도: 0.9893, 정밀도: 1.0000, 재현율: 0.6000, F1:0.7500, AUC:0.8000
# ###########################################################################
# 임곗값: 0.65957423959723
# 오차 행렬
# [[730   0]
#  [  9  11]]
# 정확도: 0.9880, 정밀도: 1.0000, 재현율: 0.5500, F1:0.7097, AUC:0.7750
# ###########################################################################
# 임곗값: 0.7864217720895359
# 오차 행렬
# [[730   0]
#  [ 10  10]]
# 정확도: 0.9867, 정밀도: 1.0000, 재현율: 0.5000, F1:0.6667, AUC:0.7500
# ###########################################################################
# 임곗값: 0.8749518618889578
# 오차 행렬
# [[730   0]
#  [ 11   9]]
# 정확도: 0.9853, 정밀도: 1.0000, 재현율: 0.4500, F1:0.6207, AUC:0.7250
# ###########################################################################
# 임곗값: 0.9730921674915631
# 오차 행렬
# [[730   0]
#  [ 12   8]]
# 정확도: 0.9840, 정밀도: 1.0000, 재현율: 0.4000, F1:0.5714, AUC:0.7000
# ###########################################################################
# 임곗값: 0.9777373581722657
# 오차 행렬
# [[730   0]
#  [ 13   7]]
# 정확도: 0.9827, 정밀도: 1.0000, 재현율: 0.3500, F1:0.5185, AUC:0.6750
# ###########################################################################
# 임곗값: 0.9927281410815791
# 오차 행렬
# [[730   0]
#  [ 14   6]]
# 정확도: 0.9813, 정밀도: 1.0000, 재현율: 0.3000, F1:0.4615, AUC:0.6500
# ###########################################################################
# 임곗값: 0.9985188978696776
# 오차 행렬
# [[730   0]
#  [ 15   5]]
# 정확도: 0.9800, 정밀도: 1.0000, 재현율: 0.2500, F1:0.4000, AUC:0.6250
# ###########################################################################
# 임곗값: 0.9994877521277785
# 오차 행렬
# [[730   0]
#  [ 16   4]]
# 정확도: 0.9787, 정밀도: 1.0000, 재현율: 0.2000, F1:0.3333, AUC:0.6000
# ###########################################################################
# 임곗값: 0.9995583532035536
# 오차 행렬
# [[730   0]
#  [ 17   3]]
# 정확도: 0.9773, 정밀도: 1.0000, 재현율: 0.1500, F1:0.2609, AUC:0.5750
# ###########################################################################
# 임곗값: 0.9999998371895439
# 오차 행렬
# [[730   0]
#  [ 18   2]]
# 정확도: 0.9760, 정밀도: 1.0000, 재현율: 0.1000, F1:0.1818, AUC:0.5500
# ###########################################################################
# 임곗값: 0.9999999578090706
# 오차 행렬
# [[730   0]
#  [ 19   1]]
# 정확도: 0.9747, 정밀도: 1.0000, 재현율: 0.0500, F1:0.0952, AUC:0.5250
# ###########################################################################
# 임곗값: 0.999999971435645
# 오차 행렬
# [[730   0]
#  [ 20   0]]
# 정확도: 0.9733, 정밀도: 0.0000, 재현율: 0.0000, F1:0.0000, AUC:0.5000
# ###########################################################################
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# 타겟 데이터와 예측 객체를 전달받는다.
def get_evaluation_by_custom_proba(y_test, prediction, visualize=False):
#     오차 행렬
    confusion = confusion_matrix(y_test, prediction)
#     정확도
    accuracy = accuracy_score(y_test , prediction)
#     정밀도
    precision = precision_score(y_test , prediction)
#     재현율
    recall = recall_score(y_test , prediction)
#     F1 score
    f1 = f1_score(y_test, prediction)
#     ROC-AUC
    roc_auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    print("#" * 80)
    
    if visualize:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_predictions(y_test, prediction, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
binarizer = Binarizer(threshold=0.1387)
custom_prediction = binarizer.fit_transform(g_log_reg.predict_proba(X_test)[:, 1].reshape(-1, 1))
get_evaluation_by_custom_proba(y_test, custom_prediction, True)
# Out:
# 오차 행렬
# [[725   5]
#  [  3  17]]
# 정확도: 0.9893, 정밀도: 0.7727, 재현율: 0.8500, F1: 0.8095, ROC-AUC: 0.9216
# ################################################################################

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 데이터를 훈련 세트와 검증 세트로 나눔
X_train, X_val, y_train, y_val = train_test_split(features, targets, test_size=0.2, random_state=42)

# 모델을 훈련 세트에서 훈련
g_log_reg.fit(X_train, y_train)

# 훈련 세트와 검증 세트에서 모델을 평가하여 성능 지표 계산
train_pred = g_log_reg.predict(X_train)
val_pred = g_log_reg.predict(X_val)

train_accuracy = accuracy_score(y_train, train_pred)
val_accuracy = accuracy_score(y_val, val_pred)

train_precision = precision_score(y_train, train_pred)
val_precision = precision_score(y_val, val_pred)

train_recall = recall_score(y_train, train_pred)
val_recall = recall_score(y_val, val_pred)

train_f1 = f1_score(y_train, train_pred)
val_f1 = f1_score(y_val, val_pred)

print("Training set accuracy:", train_accuracy)
print("Validation set accuracy:", val_accuracy)
print("Training set precision:", train_precision)
print("Validation set precision:", val_precision)
print("Training set recall:", train_recall)
print("Validation set recall:", val_recall)
print("Training set F1 score:", train_f1)
print("Validation set F1 score:", val_f1)
# Out:
# Training set accuracy: 0.9863287762587529
# Validation set accuracy: 0.9866666666666667
# Training set precision: 0.9555555555555556
# Validation set precision: 0.9166666666666666
# Training set recall: 0.524390243902439
# Validation set recall: 0.55
# Training set F1 score: 0.6771653543307087
# Validation set F1 score: 0.6874999999999999

# %% [markdown]
# ### 📍 1 Cycle
# - 임계치를 조정하여 재현율을 올려보았지만, 여전히 낮은 재현율을 보였다.
# - 훈련 데이터와 검증 데이터 사이의 정확도 등의 평가 점수에 큰 차이가 없는 것으로 보아 과적합 문제는 아닌 것 같다.
# - 타겟 데이터의 비중이 한쪽으로 쏠려있어서 이러한 문제가 발생한 것 같다.
# - 다음 사이클에서는 오버 샘플링을 통해 타겟 데이터의 비중을 맞춘 뒤, 차원 축소 및 회귀 훈련을 진행해보고자 한다.

# %% [markdown]
# | 점수         | 훈련 데이터 | 검증 데이터 |
# |----------------|--------------|----------------|
# | Accuracy       | 0.9863       | 0.9867         |
# | Precision      | 0.9556       | 0.9167         |
# | Recall         | 0.5244       | 0.5500         |
# | F1 Score       | 0.6772       | 0.6875         |
