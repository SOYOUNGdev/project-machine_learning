# %% [markdown]
# ### 항공편 가격 예측
# - 항공의 특성을 회귀분석하여, 항공편의 가격을 예측한다. (선형)
#
# 1) airline: 항공사 이름. 6개의 서로 다른 항공사가 있는 범주형
# 2) flight: 비행기의 항공편 코드에 관한 정보를 저장. 범주형
# 3) Source City: 항공편이 이륙하는 도시. 6개의 도시를 갖는 범주형
# 4) Departure Time: 시간대를 그룹화하여 생성된 범주형. 출발 시간에 대한 정보를 저장. 6개의 고유한 시간 라벨.
# 5) departure_time: 출발지와 목적지 도시 사이의 정류장 수를 저장하는 3개의 고유한 값을 갖는 범주형.
# 6) Arrival Time: 시간 간격을 그룹화하여 생성된 범주형. 6개의 고유한 시간 레이블. 도착 시간에 대한 정보.
# 7) destination_city: 항공편이 착륙할 도시. 6개의 도시를 갖는 범주형.
# 8) class: 좌석 클래스에 대한 정보를 포함하는 범주형. bussiness / economy
# 9) duration: 도시간 이동에 소요되는 전체 시간을 시간 단위로 표시하는 연속형 변수
# 10) days_left: 예약일 - 여행일
# 11) price: 티켓 가격

# %%
import pandas as pd

f_df = pd.read_csv('./datasets/flight.csv')
f_df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# 1             Morning           Mumbai   Economy      2.33          1   5953
# 2       Early_Morning           Mumbai   Economy      2.17          1   5956
# 3           Afternoon           Mumbai   Economy      2.25          1   5955
# 4             Morning           Mumbai   Economy      2.33          1   5955
# ...               ...              ...       ...       ...        ...    ...
# 300148        Evening        Hyderabad  Business     10.08         49  69265
# 300149          Night        Hyderabad  Business     10.42         49  77105
# 300150          Night        Hyderabad  Business     13.83         49  79099
# 300151        Evening        Hyderabad  Business     10.00         49  81585
# 300152        Evening        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 12 columns]

# %%
pre_f_df = f_df.drop(labels=['Unnamed: 0'], axis=1)
pre_f_df
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# 0                Mumbai   Economy      2.17          1   5953
# 1                Mumbai   Economy      2.33          1   5953
# 2                Mumbai   Economy      2.17          1   5956
# 3                Mumbai   Economy      2.25          1   5955
# 4                Mumbai   Economy      2.33          1   5955
# ...                 ...       ...       ...        ...    ...
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 11 columns]

# %%
import pandas as pd

f_df = pd.read_csv('./datasets/flight.csv')
f_df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# 1             Morning           Mumbai   Economy      2.33          1   5953
# 2       Early_Morning           Mumbai   Economy      2.17          1   5956
# 3           Afternoon           Mumbai   Economy      2.25          1   5955
# 4             Morning           Mumbai   Economy      2.33          1   5955
# ...               ...              ...       ...       ...        ...    ...
# 300148        Evening        Hyderabad  Business     10.08         49  69265
# 300149          Night        Hyderabad  Business     10.42         49  77105
# 300150          Night        Hyderabad  Business     13.83         49  79099
# 300151        Evening        Hyderabad  Business     10.00         49  81585
# 300152        Evening        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 12 columns]

# %%
pre_f_df = f_df.drop(labels=['Unnamed: 0'], axis=1)
pre_f_df
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# 0                Mumbai   Economy      2.17          1   5953
# 1                Mumbai   Economy      2.33          1   5953
# 2                Mumbai   Economy      2.17          1   5956
# 3                Mumbai   Economy      2.25          1   5955
# 4                Mumbai   Economy      2.33          1   5955
# ...                 ...       ...       ...        ...    ...
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 11 columns]

# %%
pre_f_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
pre_f_df.isna().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
pre_f_df.duplicated().sum()
# Out:
# 0

# %%
pre_f_df['class'].value_counts()
# Out:
# class
# Economy     206666
# Business     93487
# Name: count, dtype: int64

# %%
pre_f_df['departure_time'].value_counts()
# Out:
# departure_time
# Morning          71146
# Early_Morning    66790
# Evening          65102
# Night            48015
# Afternoon        47794
# Late_Night        1306
# Name: count, dtype: int64

# %%
pre_f_df['stops'].value_counts()
# Out:
# stops
# one            250863
# zero            36004
# two_or_more     13286
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

# 순서 정의
class_order = np.array(['Economy', 'Business'])
time_order = np.array(['Early_Morning', 'Morning', 'Afternoon', 'Evening', 'Night', 'Late_Night'])
stops_order = np.array(['zero', 'one', 'two_or_more'])

# 라벨 인코딩할 열 목록
columns_to_encode = ['class', 'departure_time', 'arrival_time', 'stops']

# LabelEncoder 객체 생성
encoder = LabelEncoder()

# 라벨 인코딩 수행
for column in columns_to_encode:
    if column == 'class':
        encoder.classes_ = class_order
    elif column in ['departure_time', 'arrival_time']:
        encoder.classes_ = time_order
    elif column == 'stops':
        encoder.classes_ = stops_order
    result = encoder.transform(pre_f_df[column])
    pre_f_df.loc[:, column] = result
    pre_f_df[column] = pre_f_df[column].astype(np.int16)

pre_f_df
# Out:
#          airline   flight source_city  departure_time  stops  arrival_time  \
# 0       SpiceJet  SG-8709       Delhi               3      0             4
# 1       SpiceJet  SG-8157       Delhi               0      0             1
# 2        AirAsia   I5-764       Delhi               0      0             0
# 3        Vistara   UK-995       Delhi               1      0             2
# 4        Vistara   UK-963       Delhi               1      0             1
# ...          ...      ...         ...             ...    ...           ...
# 300148   Vistara   UK-822     Chennai               1      1             3
# 300149   Vistara   UK-826     Chennai               2      1             4
# 300150   Vistara   UK-832     Chennai               0      1             4
# 300151   Vistara   UK-828     Chennai               0      1             3
# 300152   Vistara   UK-822     Chennai               1      1             3
#
#        destination_city  class  duration  days_left  price
# 0                Mumbai      0      2.17          1   5953
# 1                Mumbai      0      2.33          1   5953
# 2                Mumbai      0      2.17          1   5956
# 3                Mumbai      0      2.25          1   5955
# 4                Mumbai      0      2.33          1   5955
# ...                 ...    ...       ...        ...    ...
# 300148        Hyderabad      1     10.08         49  69265
# 300149        Hyderabad      1     10.42         49  77105
# 300150        Hyderabad      1     13.83         49  79099
# 300151        Hyderabad      1     10.00         49  81585
# 300152        Hyderabad      1     10.08         49  81585
#
# [300153 rows x 11 columns]

# %%
pre_f_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  int16
#  4   stops             300153 non-null  int16
#  5   arrival_time      300153 non-null  int16
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  int16
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int16(4), int64(2), object(4)
# memory usage: 18.3+ MB

# %%
pre_f_df.airline.value_counts()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %%
pre_f_df.flight.value_counts()
# Out:
# flight
# UK-706     3235
# UK-772     2741
# UK-720     2650
# UK-836     2542
# UK-822     2468
#            ...
# SG-9923       1
# 6E-6474       1
# 6E-865        1
# G8-705        1
# G8-107        1
# Name: count, Length: 1561, dtype: int64

# %%
pre_f_df.destination_city.value_counts()
# Out:
# destination_city
# Mumbai       59097
# Delhi        57360
# Bangalore    51068
# Kolkata      49534
# Hyderabad    42726
# Chennai      40368
# Name: count, dtype: int64

# %%
pre_f_df.source_city.value_counts()
# Out:
# source_city
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: count, dtype: int64

# %%
# 삭제할 feature
columns = ['flight', 'destination_city', 'source_city']

pre_f_df = pre_f_df.drop(labels=columns, axis=1)
pre_f_df
# Out:
#          airline  departure_time  stops  arrival_time  class  duration  \
# 0       SpiceJet               3      0             4      0      2.17
# 1       SpiceJet               0      0             1      0      2.33
# 2        AirAsia               0      0             0      0      2.17
# 3        Vistara               1      0             2      0      2.25
# 4        Vistara               1      0             1      0      2.33
# ...          ...             ...    ...           ...    ...       ...
# 300148   Vistara               1      1             3      1     10.08
# 300149   Vistara               2      1             4      1     10.42
# 300150   Vistara               0      1             4      1     13.83
# 300151   Vistara               0      1             3      1     10.00
# 300152   Vistara               1      1             3      1     10.08
#
#         days_left  price
# 0               1   5953
# 1               1   5953
# 2               1   5956
# 3               1   5955
# 4               1   5955
# ...           ...    ...
# 300148         49  69265
# 300149         49  77105
# 300150         49  79099
# 300151         49  81585
# 300152         49  81585
#
# [300153 rows x 8 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# sparse를 False로 설정하면 넘파이 배열, True는 희소 행렬
one_hot_encoder = OneHotEncoder(sparse_output=False)
result = one_hot_encoder.fit_transform(pre_f_df[['airline']])

pre_f_df = pd.concat([pre_f_df, 
                      pd.DataFrame(result, columns=one_hot_encoder.categories_).astype(np.int8)], 
                     axis=1)
pre_f_df
# Out:
#          airline  departure_time  stops  arrival_time  class  duration  \
# 0       SpiceJet               3      0             4      0      2.17
# 1       SpiceJet               0      0             1      0      2.33
# 2        AirAsia               0      0             0      0      2.17
# 3        Vistara               1      0             2      0      2.25
# 4        Vistara               1      0             1      0      2.33
# ...          ...             ...    ...           ...    ...       ...
# 300148   Vistara               1      1             3      1     10.08
# 300149   Vistara               2      1             4      1     10.42
# 300150   Vistara               0      1             4      1     13.83
# 300151   Vistara               0      1             3      1     10.00
# 300152   Vistara               1      1             3      1     10.08
#
#         days_left  price  (AirAsia,)  (Air_India,)  (GO_FIRST,)  (Indigo,)  \
# 0               1   5953           0             0            0          0
# 1               1   5953           0             0            0          0
# 2               1   5956           1             0            0          0
# 3               1   5955           0             0            0          0
# 4               1   5955           0             0            0          0
# ...           ...    ...         ...           ...          ...        ...
# 300148         49  69265           0             0            0          0
# 300149         49  77105           0             0            0          0
# 300150         49  79099           0             0            0          0
# 300151         49  81585           0             0            0          0
# 300152         49  81585           0             0            0          0
#
#         (SpiceJet,)  (Vistara,)
# 0                 1           0
# 1                 1           0
# 2                 0           0
# 3                 0           1
# 4                 0           1
# ...             ...         ...
# 300148            0           1
# 300149            0           1
# 300150            0           1
# 300151            0           1
# 300152            0           1
#
# [300153 rows x 14 columns]

# %%
pre_f_df = pre_f_df.drop(labels=['airline'], axis=1)
pre_f_df
# Out:
#         departure_time  stops  arrival_time  class  duration  days_left  \
# 0                    3      0             4      0      2.17          1
# 1                    0      0             1      0      2.33          1
# 2                    0      0             0      0      2.17          1
# 3                    1      0             2      0      2.25          1
# 4                    1      0             1      0      2.33          1
# ...                ...    ...           ...    ...       ...        ...
# 300148               1      1             3      1     10.08         49
# 300149               2      1             4      1     10.42         49
# 300150               0      1             4      1     13.83         49
# 300151               0      1             3      1     10.00         49
# 300152               1      1             3      1     10.08         49
#
#         price  (AirAsia,)  (Air_India,)  (GO_FIRST,)  (Indigo,)  (SpiceJet,)  \
# 0        5953           0             0            0          0            1
# 1        5953           0             0            0          0            1
# 2        5956           1             0            0          0            0
# 3        5955           0             0            0          0            0
# 4        5955           0             0            0          0            0
# ...       ...         ...           ...          ...        ...          ...
# 300148  69265           0             0            0          0            0
# 300149  77105           0             0            0          0            0
# 300150  79099           0             0            0          0            0
# 300151  81585           0             0            0          0            0
# 300152  81585           0             0            0          0            0
#
#         (Vistara,)
# 0                0
# 1                0
# 2                0
# 3                1
# 4                1
# ...            ...
# 300148           1
# 300149           1
# 300150           1
# 300151           1
# 300152           1
#
# [300153 rows x 13 columns]

# %%
pre_f_df.columns = ['departure_time', 'stops', 'arrival_time', 'class', 'duration', 'days_left',  'price',\
           'AirAsia', 'Air_India', 'GO_FIRST', 'Indigo', 'SpiceJet', 'Vistara']

pre_f_df
# Out:
#         departure_time  stops  arrival_time  class  duration  days_left  \
# 0                    3      0             4      0      2.17          1
# 1                    0      0             1      0      2.33          1
# 2                    0      0             0      0      2.17          1
# 3                    1      0             2      0      2.25          1
# 4                    1      0             1      0      2.33          1
# ...                ...    ...           ...    ...       ...        ...
# 300148               1      1             3      1     10.08         49
# 300149               2      1             4      1     10.42         49
# 300150               0      1             4      1     13.83         49
# 300151               0      1             3      1     10.00         49
# 300152               1      1             3      1     10.08         49
#
#         price  AirAsia  Air_India  GO_FIRST  Indigo  SpiceJet  Vistara
# 0        5953        0          0         0       0         1        0
# 1        5953        0          0         0       0         1        0
# 2        5956        1          0         0       0         0        0
# 3        5955        0          0         0       0         0        1
# 4        5955        0          0         0       0         0        1
# ...       ...      ...        ...       ...     ...       ...      ...
# 300148  69265        0          0         0       0         0        1
# 300149  77105        0          0         0       0         0        1
# 300150  79099        0          0         0       0         0        1
# 300151  81585        0          0         0       0         0        1
# 300152  81585        0          0         0       0         0        1
#
# [300153 rows x 13 columns]

# %%
pre_f_df['target'] = pre_f_df['price']
pre_f_df = pre_f_df.drop(labels=['price'], axis=1)
pre_f_df
# Out:
#         departure_time  stops  arrival_time  class  duration  days_left  \
# 0                    3      0             4      0      2.17          1
# 1                    0      0             1      0      2.33          1
# 2                    0      0             0      0      2.17          1
# 3                    1      0             2      0      2.25          1
# 4                    1      0             1      0      2.33          1
# ...                ...    ...           ...    ...       ...        ...
# 300148               1      1             3      1     10.08         49
# 300149               2      1             4      1     10.42         49
# 300150               0      1             4      1     13.83         49
# 300151               0      1             3      1     10.00         49
# 300152               1      1             3      1     10.08         49
#
#         AirAsia  Air_India  GO_FIRST  Indigo  SpiceJet  Vistara  target
# 0             0          0         0       0         1        0    5953
# 1             0          0         0       0         1        0    5953
# 2             1          0         0       0         0        0    5956
# 3             0          0         0       0         0        1    5955
# 4             0          0         0       0         0        1    5955
# ...         ...        ...       ...     ...       ...      ...     ...
# 300148        0          0         0       0         0        1   69265
# 300149        0          0         0       0         0        1   77105
# 300150        0          0         0       0         0        1   79099
# 300151        0          0         0       0         0        1   81585
# 300152        0          0         0       0         0        1   81585
#
# [300153 rows x 13 columns]

# %%
pre_f_df.corr()['target'].sort_values(ascending=False)[1:]
# Out:
# class             0.937860
# Vistara           0.360816
# duration          0.204222
# stops             0.119648
# Air_India         0.070041
# departure_time    0.020948
# arrival_time     -0.001019
# days_left        -0.091949
# SpiceJet         -0.114019
# AirAsia          -0.176188
# GO_FIRST         -0.194179
# Indigo           -0.280882
# Name: target, dtype: float64

# %%
pre_f_df.hist(figsize=(12, 12))
# Out:
# array([[<Axes: title={'center': 'departure_time'}>,
#         <Axes: title={'center': 'stops'}>,
#         <Axes: title={'center': 'arrival_time'}>,
#         <Axes: title={'center': 'class'}>],
#        [<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'days_left'}>,
#         <Axes: title={'center': 'AirAsia'}>,
#         <Axes: title={'center': 'Air_India'}>],
#        [<Axes: title={'center': 'GO_FIRST'}>,
#         <Axes: title={'center': 'Indigo'}>,
#         <Axes: title={'center': 'SpiceJet'}>,
#         <Axes: title={'center': 'Vistara'}>],
#        [<Axes: title={'center': 'target'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### 선형

# %%
import numpy as np
from sklearn.metrics import mean_squared_log_error, mean_squared_error, r2_score

def get_evaluation(y_test, prediction):
    MSE = mean_squared_error(y_test, prediction)
    RMSE = np.sqrt(MSE)
    # MSLE = mean_squared_log_error(y_test, prediction)
    # RMSLE = np.sqrt(mean_squared_log_error(y_test, prediction))
    R2 = r2_score(y_test, prediction)
    print('MSE: {:.4f}, RMSE: {:.4f}, R2: {:.4f}'\
          .format(MSE, RMSE, R2))
    # print('MSE: {:.4f}, RMSE: {:.4f}, MSLE: {:.4f}, RMSLE: {:.4f}, R2: {:.4f}'\
    #       .format(MSE, RMSE, MSLE, RMSLE, R2))

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

features, targets = pre_f_df.iloc[:, :-1], pre_f_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

l_r = LinearRegression()
l_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 48204787.4606, RMSE: 6942.9668, R2: 0.9062

# %%
import seaborn as sns
import matplotlib.pyplot as plt

l_r.fit(X_train, y_train)
prediction = l_r.predict(X_train)
get_evaluation(y_train, prediction)

sns.set(style='whitegrid')
fig, ax = plt.subplots(ncols=1, figsize=(8, 4))
ax.set_title('Actual vs Predicted')
sns.scatterplot(x=y_train, y=np.ravel(prediction), ax=ax, hue=np.ravel(prediction))
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], linestyle='--', color='red')  # 대각선 추가
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()
# Out:
# MSE: 48205137.3360, RMSE: 6942.9920, R2: 0.9065

# %%
import seaborn as sns
import matplotlib.pyplot as plt

l_r.fit(X_train, y_train)
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)

sns.set(style='whitegrid')
fig, ax = plt.subplots(ncols=1, figsize=(8, 4))
ax.set_title('Actual vs Predicted')
sns.scatterplot(x=y_test, y=np.ravel(prediction), ax=ax, hue=np.ravel(prediction))
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red')  # 대각선 추가
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()
# Out:
# MSE: 48204787.4606, RMSE: 6942.9668, R2: 0.9062

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='whitegrid')
fig, ax = plt.subplots(ncols=1, figsize=(8, 4))
ax.set_title('Actual vs Predicted')
sns.scatterplot(x=np.ravel(prediction), y=y_test, ax=ax, hue=np.ravel(prediction))
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red')  # 대각선 추가
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

features, targets = pre_f_df.iloc[:, :-1], pre_f_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

# LinearRegression 모델 생성
lr = LinearRegression()

# 교차검증 수행
cv_scores_train = cross_val_score(lr, X_train, y_train, cv=10, scoring='neg_mean_squared_error')
cv_scores_test = cross_val_score(lr, X_test, y_test, cv=10, scoring='neg_mean_squared_error')

# 훈련 세트와 테스트 세트 간의 성능 차이 계산
mean_train_score = cv_scores_train.mean()
mean_test_score = cv_scores_test.mean()

mean_train_score = -1 * mean_train_score
mean_test_score = -1 * mean_test_score

print('훈련 데이터세트의 MSE평균:', mean_train_score)
print('테스트 데이터세트의 MSE평균:', mean_test_score)
# Out:
# 훈련 데이터세트의 MSE평균: 48209104.80567177
# 테스트 데이터세트의 MSE평균: 48217849.11845022

# %% [markdown]
# #### 📍 MSE 수치가 너무 크고, 훈련 데이터와 테스트 데이터의 MSE 수치 차이가 큰 것을 보아, 과적합이 발생했을 가능성이 높아보인다.
# 다음 cycle에서 이상치 제거 및 타겟 데이터의 분포 확인을 통한 전처리를 다시 하고자 한다.

# %%
prediction = l_r.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# MSE: 31567584.2654, RMSE: 5618.5037, R2: 0.9386

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# plt.rcParams['font.family'] ='Malgun Gothic'
# plt.rcParams['axes.unicode_minus'] =False

sns.set(style='whitegrid')
fig, ax = plt.subplots(ncols=1, figsize=(8,4))
ax.set_title('Actual vs Predicted')
sns.scatterplot(x = np.ravel(prediction), y = y_test, ax = ax, hue = np.ravel(prediction))
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red')
plt.xlabel('Predict')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split

features, targets = pre_f_df.iloc[:, :-1], pre_f_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

dt_r = DecisionTreeRegressor(random_state=124)
rf_r = RandomForestRegressor(random_state=124, n_estimators=1000)
gb_r = GradientBoostingRegressor(random_state=124)
xgb_r = XGBRegressor()
lgb_r = LGBMRegressor(n_estimators=100)

models = [dt_r, rf_r, gb_r, xgb_r, lgb_r]
for model in models:
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print(model.__class__.__name__)
    get_evaluation(y_test, prediction)
# Out:
# DecisionTreeRegressor
# MSE: 29697876.6610, RMSE: 5449.5758, R2: 0.9422
# RandomForestRegressor
# MSE: 22527126.0110, RMSE: 4746.2750, R2: 0.9562
# GradientBoostingRegressor
# MSE: 27389009.8601, RMSE: 5233.4510, R2: 0.9467
# XGBRegressor
# MSE: 19676232.9959, RMSE: 4435.7900, R2: 0.9617
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006283 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 240122, number of used features: 12
# [LightGBM] [Info] Start training from score 20896.058508
# LGBMRegressor
# MSE: 22480674.7132, RMSE: 4741.3790, R2: 0.9563
